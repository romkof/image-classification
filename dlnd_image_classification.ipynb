# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 1
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 1:
# Image - Min Value: 2 Max Value: 247
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    
    # TODO: Implement Function
    return np.array(
        list(map(lambda image : 
                list(map(lambda pixel : pixel/256 ,image)), x)))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    
    # TODO: Implement Function
    return np.eye(10)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, 32, 32, 3], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, 10], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    tensor_channels =(x_tensor.shape.dims[-1]).value
    batch_size = 1
    pooling_channels =1
    
    weight_shape=[]
    weight_shape.extend(conv_ksize)
    weight_shape.append(tensor_channels)
    weight_shape.append(conv_num_outputs)
    
    weight = tf.Variable(tf.truncated_normal(weight_shape, stddev=0.05))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_stride = [batch_size]
    conv_stride.extend(conv_strides)
    conv_stride.append(pooling_channels)
    
    conv_layer = tf.nn.conv2d(x_tensor, weight, strides=conv_stride, padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    
    
    max_pool_stride = [batch_size]
    max_pool_stride.extend(pool_strides)
    max_pool_stride.append(pooling_channels)
    
    pool_ksize_list = [batch_size]
    pool_ksize_list.extend(pool_ksize)
    pool_ksize_list.append(pooling_channels)
    
    
    conv_layer = tf.nn.max_pool(
        conv_layer,
        ksize=pool_ksize_list,
        strides= max_pool_stride,
        padding='SAME')
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    
    layer_shape = x_tensor.get_shape()
    num_features = layer_shape[1:4].num_elements()
    return tf.reshape(x_tensor, [-1, num_features])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_input = x_tensor.get_shape()[1].value
    weight = tf.Variable(tf.truncated_normal([num_input,num_outputs], stddev =0.05))
    bias = tf.Variable(tf.zeros(num_outputs))
    layer = tf.matmul(x_tensor, weight) + bias   
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_input = x_tensor.get_shape()[1].value
    weight = tf.Variable(tf.truncated_normal([num_input,num_outputs], stddev =0.05))
    bias = tf.Variable(tf.zeros(num_outputs))
    layer = tf.matmul(x_tensor, weight) + bias   
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #
   
    conv_num_outputs_1 =  16
    conv_ksize_1 =       (2,2)
    conv_strides_1 =     (2,2)
    pool_ksize_1 =       (2,2)
    pool_strides_1 =     (2,2)
    
    conv_num_outputs_2 =  256
    conv_ksize_2 =       (2,2)  
    conv_strides_2 =     (2,2)
    pool_ksize_2 =       (2,2)
    pool_strides_2 =     (2,2)
    
    conv_num_outputs_3 =  64
    conv_ksize_3 =       (2,2)  
    conv_strides_3 =     (2,2)
    pool_ksize_3 =       (2,2)
    pool_strides_3 =     (2,2)
    
    
    fully_conn_layer_1_num_outputs = 2048
    fully_conn_layer_2_num_outputs = 2048
    
    
    output_layer_num_outputs = 10
    
    conv_layer_1 = conv2d_maxpool(x, conv_num_outputs_1, conv_ksize_1, conv_strides_1, pool_ksize_1, pool_strides_1)
    conv_layer_2 = conv2d_maxpool(conv_layer_1, conv_num_outputs_2, conv_ksize_2, conv_strides_2, pool_ksize_2, pool_strides_2)
    
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   
    flatten_layer = flatten(conv_layer_2)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #
    
    fully_conn_layer_1 = fully_conn(flatten_layer, fully_conn_layer_1_num_outputs)
    fully_conn_layer_2 = fully_conn(fully_conn_layer_1, fully_conn_layer_2_num_outputs)
    fully_conn_layer_3 = fully_conn(fully_conn_layer_2, fully_conn_layer_3_num_outputs)
    
    fully_conn_layer_2_drop = tf.nn.dropout(fully_conn_layer_3, keep_prob)    
        
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   
    output_layer = output(fully_conn_layer_2_drop, output_layer_num_outputs)
    
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    feed_dict_train = {    x: feature_batch,
                           y: label_batch,
                           keep_prob: keep_probability
                      }
    session.run(optimizer, feed_dict=feed_dict_train)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# # Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    feed_dict_train = {x: feature_batch,
                           y: label_batch,
                           keep_prob: 1.0}
        
    current_cost = sess.run(cost, feed_dict=feed_dict_train)
    valid_accuracy = sess.run(accuracy,feed_dict=feed_dict_train)
    
    print('Cost: {:10.4f} Valid Accuracy: {:<5.3}'.format(current_cost,   valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 250
batch_size = 12288
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost:     3.1815 Valid Accuracy: 0.099
# Epoch  2, CIFAR-10 Batch 1:  Cost:     2.4904 Valid Accuracy: 0.199
# Epoch  3, CIFAR-10 Batch 1:  Cost:     2.2913 Valid Accuracy: 0.116
# Epoch  4, CIFAR-10 Batch 1:  Cost:     2.2465 Valid Accuracy: 0.133
# Epoch  5, CIFAR-10 Batch 1:  Cost:     2.2393 Valid Accuracy: 0.178
# Epoch  6, CIFAR-10 Batch 1:  Cost:     2.2015 Valid Accuracy: 0.156
# Epoch  7, CIFAR-10 Batch 1:  Cost:     2.1538 Valid Accuracy: 0.201
# Epoch  8, CIFAR-10 Batch 1:  Cost:     2.1215 Valid Accuracy: 0.195
# Epoch  9, CIFAR-10 Batch 1:  Cost:     2.0943 Valid Accuracy: 0.251
# Epoch 10, CIFAR-10 Batch 1:  Cost:     2.0736 Valid Accuracy: 0.228
# Epoch 11, CIFAR-10 Batch 1:  Cost:     2.0342 Valid Accuracy: 0.244
# Epoch 12, CIFAR-10 Batch 1:  Cost:     1.9990 Valid Accuracy: 0.296
# Epoch 13, CIFAR-10 Batch 1:  Cost:     1.9788 Valid Accuracy: 0.291
# Epoch 14, CIFAR-10 Batch 1:  Cost:     1.9506 Valid Accuracy: 0.311
# Epoch 15, CIFAR-10 Batch 1:  Cost:     1.9233 Valid Accuracy: 0.294
# Epoch 16, CIFAR-10 Batch 1:  Cost:     1.8990 Valid Accuracy: 0.295
# Epoch 17, CIFAR-10 Batch 1:  Cost:     1.8756 Valid Accuracy: 0.315
# Epoch 18, CIFAR-10 Batch 1:  Cost:     1.8449 Valid Accuracy: 0.33
# Epoch 19, CIFAR-10 Batch 1:  Cost:     1.8185 Valid Accuracy: 0.354
# Epoch 20, CIFAR-10 Batch 1:  Cost:     1.7992 Valid Accuracy: 0.356
# Epoch 21, CIFAR-10 Batch 1:  Cost:     1.7781 Valid Accuracy: 0.359
# Epoch 22, CIFAR-10 Batch 1:  Cost:     1.7555 Valid Accuracy: 0.366
# Epoch 23, CIFAR-10 Batch 1:  Cost:     1.7404 Valid Accuracy: 0.375
# Epoch 24, CIFAR-10 Batch 1:  Cost:     1.7633 Valid Accuracy: 0.355
# Epoch 25, CIFAR-10 Batch 1:  Cost:     1.7652 Valid Accuracy: 0.364
# Epoch 26, CIFAR-10 Batch 1:  Cost:     1.7693 Valid Accuracy: 0.359
# Epoch 27, CIFAR-10 Batch 1:  Cost:     1.7246 Valid Accuracy: 0.376
# Epoch 28, CIFAR-10 Batch 1:  Cost:     1.6969 Valid Accuracy: 0.382
# Epoch 29, CIFAR-10 Batch 1:  Cost:     1.7001 Valid Accuracy: 0.389
# Epoch 30, CIFAR-10 Batch 1:  Cost:     1.6521 Valid Accuracy: 0.407
# Epoch 31, CIFAR-10 Batch 1:  Cost:     1.6840 Valid Accuracy: 0.394
# Epoch 32, CIFAR-10 Batch 1:  Cost:     1.6284 Valid Accuracy: 0.411
# Epoch 33, CIFAR-10 Batch 1:  Cost:     1.6542 Valid Accuracy: 0.4
# Epoch 34, CIFAR-10 Batch 1:  Cost:     1.6220 Valid Accuracy: 0.422
# Epoch 35, CIFAR-10 Batch 1:  Cost:     1.6293 Valid Accuracy: 0.411
# Epoch 36, CIFAR-10 Batch 1:  Cost:     1.5947 Valid Accuracy: 0.424
# Epoch 37, CIFAR-10 Batch 1:  Cost:     1.6120 Valid Accuracy: 0.422
# Epoch 38, CIFAR-10 Batch 1:  Cost:     1.5799 Valid Accuracy: 0.426
# Epoch 39, CIFAR-10 Batch 1:  Cost:     1.5779 Valid Accuracy: 0.43
# Epoch 40, CIFAR-10 Batch 1:  Cost:     1.5668 Valid Accuracy: 0.441
# Epoch 41, CIFAR-10 Batch 1:  Cost:     1.5577 Valid Accuracy: 0.441
# Epoch 42, CIFAR-10 Batch 1:  Cost:     1.5422 Valid Accuracy: 0.444
# Epoch 43, CIFAR-10 Batch 1:  Cost:     1.5329 Valid Accuracy: 0.449
# Epoch 44, CIFAR-10 Batch 1:  Cost:     1.5279 Valid Accuracy: 0.452
# Epoch 45, CIFAR-10 Batch 1:  Cost:     1.5300 Valid Accuracy: 0.454
# Epoch 46, CIFAR-10 Batch 1:  Cost:     1.5400 Valid Accuracy: 0.439
# Epoch 47, CIFAR-10 Batch 1:  Cost:     1.5579 Valid Accuracy: 0.443
# Epoch 48, CIFAR-10 Batch 1:  Cost:     1.5339 Valid Accuracy: 0.445
# Epoch 49, CIFAR-10 Batch 1:  Cost:     1.4888 Valid Accuracy: 0.464
# Epoch 50, CIFAR-10 Batch 1:  Cost:     1.4760 Valid Accuracy: 0.467
# Epoch 51, CIFAR-10 Batch 1:  Cost:     1.4918 Valid Accuracy: 0.46
# Epoch 52, CIFAR-10 Batch 1:  Cost:     1.4674 Valid Accuracy: 0.474
# Epoch 53, CIFAR-10 Batch 1:  Cost:     1.4477 Valid Accuracy: 0.479
# Epoch 54, CIFAR-10 Batch 1:  Cost:     1.4514 Valid Accuracy: 0.477
# Epoch 55, CIFAR-10 Batch 1:  Cost:     1.4451 Valid Accuracy: 0.485
# Epoch 56, CIFAR-10 Batch 1:  Cost:     1.4319 Valid Accuracy: 0.487
# Epoch 57, CIFAR-10 Batch 1:  Cost:     1.4121 Valid Accuracy: 0.496
# Epoch 58, CIFAR-10 Batch 1:  Cost:     1.4157 Valid Accuracy: 0.492
# Epoch 59, CIFAR-10 Batch 1:  Cost:     1.4145 Valid Accuracy: 0.499
# Epoch 60, CIFAR-10 Batch 1:  Cost:     1.3980 Valid Accuracy: 0.504
# Epoch 61, CIFAR-10 Batch 1:  Cost:     1.3913 Valid Accuracy: 0.503
# Epoch 62, CIFAR-10 Batch 1:  Cost:     1.3845 Valid Accuracy: 0.505
# Epoch 63, CIFAR-10 Batch 1:  Cost:     1.3677 Valid Accuracy: 0.512
# Epoch 64, CIFAR-10 Batch 1:  Cost:     1.3588 Valid Accuracy: 0.51
# Epoch 65, CIFAR-10 Batch 1:  Cost:     1.3615 Valid Accuracy: 0.514
# Epoch 66, CIFAR-10 Batch 1:  Cost:     1.3902 Valid Accuracy: 0.502
# Epoch 67, CIFAR-10 Batch 1:  Cost:     1.4249 Valid Accuracy: 0.484
# Epoch 68, CIFAR-10 Batch 1:  Cost:     1.4203 Valid Accuracy: 0.483
# Epoch 69, CIFAR-10 Batch 1:  Cost:     1.3711 Valid Accuracy: 0.513
# Epoch 70, CIFAR-10 Batch 1:  Cost:     1.3821 Valid Accuracy: 0.494
# Epoch 71, CIFAR-10 Batch 1:  Cost:     1.3765 Valid Accuracy: 0.494
# Epoch 72, CIFAR-10 Batch 1:  Cost:     1.3331 Valid Accuracy: 0.517
# Epoch 73, CIFAR-10 Batch 1:  Cost:     1.3512 Valid Accuracy: 0.51
# Epoch 74, CIFAR-10 Batch 1:  Cost:     1.3003 Valid Accuracy: 0.533
# Epoch 75, CIFAR-10 Batch 1:  Cost:     1.3245 Valid Accuracy: 0.52
# Epoch 76, CIFAR-10 Batch 1:  Cost:     1.2840 Valid Accuracy: 0.545
# Epoch 77, CIFAR-10 Batch 1:  Cost:     1.3069 Valid Accuracy: 0.529
# Epoch 78, CIFAR-10 Batch 1:  Cost:     1.2708 Valid Accuracy: 0.549
# Epoch 79, CIFAR-10 Batch 1:  Cost:     1.2867 Valid Accuracy: 0.543
# Epoch 80, CIFAR-10 Batch 1:  Cost:     1.2571 Valid Accuracy: 0.555
# Epoch 81, CIFAR-10 Batch 1:  Cost:     1.2669 Valid Accuracy: 0.546
# Epoch 82, CIFAR-10 Batch 1:  Cost:     1.2496 Valid Accuracy: 0.559
# Epoch 83, CIFAR-10 Batch 1:  Cost:     1.2523 Valid Accuracy: 0.557
# Epoch 84, CIFAR-10 Batch 1:  Cost:     1.2499 Valid Accuracy: 0.554
# Epoch 85, CIFAR-10 Batch 1:  Cost:     1.2424 Valid Accuracy: 0.557
# Epoch 86, CIFAR-10 Batch 1:  Cost:     1.2472 Valid Accuracy: 0.563
# Epoch 87, CIFAR-10 Batch 1:  Cost:     1.2424 Valid Accuracy: 0.561
# Epoch 88, CIFAR-10 Batch 1:  Cost:     1.2298 Valid Accuracy: 0.565
# Epoch 89, CIFAR-10 Batch 1:  Cost:     1.2409 Valid Accuracy: 0.565
# Epoch 90, CIFAR-10 Batch 1:  Cost:     1.2334 Valid Accuracy: 0.565
# Epoch 91, CIFAR-10 Batch 1:  Cost:     1.1996 Valid Accuracy: 0.576
# Epoch 92, CIFAR-10 Batch 1:  Cost:     1.1915 Valid Accuracy: 0.579
# Epoch 93, CIFAR-10 Batch 1:  Cost:     1.2095 Valid Accuracy: 0.563
# Epoch 94, CIFAR-10 Batch 1:  Cost:     1.2271 Valid Accuracy: 0.565
# Epoch 95, CIFAR-10 Batch 1:  Cost:     1.1886 Valid Accuracy: 0.578
# Epoch 96, CIFAR-10 Batch 1:  Cost:     1.2182 Valid Accuracy: 0.565
# Epoch 97, CIFAR-10 Batch 1:  Cost:     1.2617 Valid Accuracy: 0.552
# Epoch 98, CIFAR-10 Batch 1:  Cost:     1.1597 Valid Accuracy: 0.589
# Epoch 99, CIFAR-10 Batch 1:  Cost:     1.2437 Valid Accuracy: 0.552
# Epoch 100, CIFAR-10 Batch 1:  Cost:     1.1783 Valid Accuracy: 0.577
# Epoch 101, CIFAR-10 Batch 1:  Cost:     1.2345 Valid Accuracy: 0.564
# Epoch 102, CIFAR-10 Batch 1:  Cost:     1.1448 Valid Accuracy: 0.597
# Epoch 103, CIFAR-10 Batch 1:  Cost:     1.1814 Valid Accuracy: 0.577
# Epoch 104, CIFAR-10 Batch 1:  Cost:     1.1587 Valid Accuracy: 0.588
# Epoch 105, CIFAR-10 Batch 1:  Cost:     1.1909 Valid Accuracy: 0.576
# Epoch 106, CIFAR-10 Batch 1:  Cost:     1.1927 Valid Accuracy: 0.569
# Epoch 107, CIFAR-10 Batch 1:  Cost:     1.1415 Valid Accuracy: 0.594
# Epoch 108, CIFAR-10 Batch 1:  Cost:     1.1931 Valid Accuracy: 0.582
# Epoch 109, CIFAR-10 Batch 1:  Cost:     1.2012 Valid Accuracy: 0.568
# Epoch 110, CIFAR-10 Batch 1:  Cost:     1.1800 Valid Accuracy: 0.578
# Epoch 111, CIFAR-10 Batch 1:  Cost:     1.1979 Valid Accuracy: 0.577
# Epoch 112, CIFAR-10 Batch 1:  Cost:     1.2104 Valid Accuracy: 0.548
# Epoch 113, CIFAR-10 Batch 1:  Cost:     1.1713 Valid Accuracy: 0.583
# Epoch 114, CIFAR-10 Batch 1:  Cost:     1.1863 Valid Accuracy: 0.578
# Epoch 115, CIFAR-10 Batch 1:  Cost:     1.1717 Valid Accuracy: 0.574
# Epoch 116, CIFAR-10 Batch 1:  Cost:     1.1325 Valid Accuracy: 0.59
# Epoch 117, CIFAR-10 Batch 1:  Cost:     1.1071 Valid Accuracy: 0.604
# Epoch 118, CIFAR-10 Batch 1:  Cost:     1.1461 Valid Accuracy: 0.588
# Epoch 119, CIFAR-10 Batch 1:  Cost:     1.0873 Valid Accuracy: 0.614
# Epoch 120, CIFAR-10 Batch 1:  Cost:     1.0881 Valid Accuracy: 0.612
# Epoch 121, CIFAR-10 Batch 1:  Cost:     1.1171 Valid Accuracy: 0.603
# Epoch 122, CIFAR-10 Batch 1:  Cost:     1.0943 Valid Accuracy: 0.612
# Epoch 123, CIFAR-10 Batch 1:  Cost:     1.0981 Valid Accuracy: 0.604
# Epoch 124, CIFAR-10 Batch 1:  Cost:     1.0420 Valid Accuracy: 0.634
# Epoch 125, CIFAR-10 Batch 1:  Cost:     1.0853 Valid Accuracy: 0.612
# Epoch 126, CIFAR-10 Batch 1:  Cost:     1.0891 Valid Accuracy: 0.614
# Epoch 127, CIFAR-10 Batch 1:  Cost:     1.0987 Valid Accuracy: 0.612
# Epoch 128, CIFAR-10 Batch 1:  Cost:     1.0793 Valid Accuracy: 0.621
# Epoch 129, CIFAR-10 Batch 1:  Cost:     1.0269 Valid Accuracy: 0.638
# Epoch 130, CIFAR-10 Batch 1:  Cost:     1.0895 Valid Accuracy: 0.61
# Epoch 131, CIFAR-10 Batch 1:  Cost:     1.0936 Valid Accuracy: 0.612
# Epoch 132, CIFAR-10 Batch 1:  Cost:     1.0818 Valid Accuracy: 0.611
# Epoch 133, CIFAR-10 Batch 1:  Cost:     1.0401 Valid Accuracy: 0.632
# Epoch 134, CIFAR-10 Batch 1:  Cost:     1.0594 Valid Accuracy: 0.628
# Epoch 135, CIFAR-10 Batch 1:  Cost:     1.0699 Valid Accuracy: 0.62
# Epoch 136, CIFAR-10 Batch 1:  Cost:     1.0098 Valid Accuracy: 0.644
# Epoch 137, CIFAR-10 Batch 1:  Cost:     1.0575 Valid Accuracy: 0.622
# Epoch 138, CIFAR-10 Batch 1:  Cost:     0.9999 Valid Accuracy: 0.65
# Epoch 139, CIFAR-10 Batch 1:  Cost:     1.0294 Valid Accuracy: 0.633
# Epoch 140, CIFAR-10 Batch 1:  Cost:     0.9994 Valid Accuracy: 0.649
# Epoch 141, CIFAR-10 Batch 1:  Cost:     1.0108 Valid Accuracy: 0.64
# Epoch 142, CIFAR-10 Batch 1:  Cost:     0.9895 Valid Accuracy: 0.655
# Epoch 143, CIFAR-10 Batch 1:  Cost:     0.9923 Valid Accuracy: 0.65
# Epoch 144, CIFAR-10 Batch 1:  Cost:     0.9712 Valid Accuracy: 0.658
# Epoch 145, CIFAR-10 Batch 1:  Cost:     0.9785 Valid Accuracy: 0.658
# Epoch 146, CIFAR-10 Batch 1:  Cost:     0.9601 Valid Accuracy: 0.667
# Epoch 147, CIFAR-10 Batch 1:  Cost:     0.9608 Valid Accuracy: 0.665
# Epoch 148, CIFAR-10 Batch 1:  Cost:     0.9682 Valid Accuracy: 0.66
# Epoch 149, CIFAR-10 Batch 1:  Cost:     0.9983 Valid Accuracy: 0.648
# Epoch 150, CIFAR-10 Batch 1:  Cost:     0.9935 Valid Accuracy: 0.651
# Epoch 151, CIFAR-10 Batch 1:  Cost:     0.9554 Valid Accuracy: 0.661
# Epoch 152, CIFAR-10 Batch 1:  Cost:     0.9566 Valid Accuracy: 0.655
# Epoch 153, CIFAR-10 Batch 1:  Cost:     0.9370 Valid Accuracy: 0.671
# Epoch 154, CIFAR-10 Batch 1:  Cost:     0.9823 Valid Accuracy: 0.659
# Epoch 155, CIFAR-10 Batch 1:  Cost:     1.0252 Valid Accuracy: 0.634
# Epoch 156, CIFAR-10 Batch 1:  Cost:     1.0283 Valid Accuracy: 0.632
# Epoch 157, CIFAR-10 Batch 1:  Cost:     0.9915 Valid Accuracy: 0.641
# Epoch 158, CIFAR-10 Batch 1:  Cost:     0.9675 Valid Accuracy: 0.66
# Epoch 159, CIFAR-10 Batch 1:  Cost:     1.0274 Valid Accuracy: 0.626
# Epoch 160, CIFAR-10 Batch 1:  Cost:     1.0579 Valid Accuracy: 0.618
# Epoch 161, CIFAR-10 Batch 1:  Cost:     1.0135 Valid Accuracy: 0.632
# Epoch 162, CIFAR-10 Batch 1:  Cost:     1.0619 Valid Accuracy: 0.603
# Epoch 163, CIFAR-10 Batch 1:  Cost:     1.1580 Valid Accuracy: 0.587
# Epoch 164, CIFAR-10 Batch 1:  Cost:     1.0153 Valid Accuracy: 0.645
# Epoch 165, CIFAR-10 Batch 1:  Cost:     1.0585 Valid Accuracy: 0.626
# Epoch 166, CIFAR-10 Batch 1:  Cost:     0.9781 Valid Accuracy: 0.644
# Epoch 167, CIFAR-10 Batch 1:  Cost:     1.0530 Valid Accuracy: 0.624
# Epoch 168, CIFAR-10 Batch 1:  Cost:     1.0960 Valid Accuracy: 0.584
# Epoch 169, CIFAR-10 Batch 1:  Cost:     0.9718 Valid Accuracy: 0.659
# Epoch 170, CIFAR-10 Batch 1:  Cost:     0.9698 Valid Accuracy: 0.657
# Epoch 171, CIFAR-10 Batch 1:  Cost:     0.9950 Valid Accuracy: 0.648
# Epoch 172, CIFAR-10 Batch 1:  Cost:     0.9274 Valid Accuracy: 0.677
# Epoch 173, CIFAR-10 Batch 1:  Cost:     0.9294 Valid Accuracy: 0.672
# Epoch 174, CIFAR-10 Batch 1:  Cost:     0.9667 Valid Accuracy: 0.652
# Epoch 175, CIFAR-10 Batch 1:  Cost:     0.8909 Valid Accuracy: 0.685
# Epoch 176, CIFAR-10 Batch 1:  Cost:     0.9335 Valid Accuracy: 0.674
# Epoch 177, CIFAR-10 Batch 1:  Cost:     0.9360 Valid Accuracy: 0.671
# Epoch 178, CIFAR-10 Batch 1:  Cost:     0.8987 Valid Accuracy: 0.685
# Epoch 179, CIFAR-10 Batch 1:  Cost:     0.8925 Valid Accuracy: 0.69
# Epoch 180, CIFAR-10 Batch 1:  Cost:     0.8968 Valid Accuracy: 0.684
# Epoch 181, CIFAR-10 Batch 1:  Cost:     0.8960 Valid Accuracy: 0.682
# Epoch 182, CIFAR-10 Batch 1:  Cost:     0.8458 Valid Accuracy: 0.71
# Epoch 183, CIFAR-10 Batch 1:  Cost:     0.8735 Valid Accuracy: 0.695
# Epoch 184, CIFAR-10 Batch 1:  Cost:     0.8511 Valid Accuracy: 0.704
# Epoch 185, CIFAR-10 Batch 1:  Cost:     0.8461 Valid Accuracy: 0.704
# Epoch 186, CIFAR-10 Batch 1:  Cost:     0.8408 Valid Accuracy: 0.713
# Epoch 187, CIFAR-10 Batch 1:  Cost:     0.8513 Valid Accuracy: 0.703
# Epoch 188, CIFAR-10 Batch 1:  Cost:     0.8513 Valid Accuracy: 0.703
# Epoch 189, CIFAR-10 Batch 1:  Cost:     0.8278 Valid Accuracy: 0.707
# Epoch 190, CIFAR-10 Batch 1:  Cost:     0.8332 Valid Accuracy: 0.711
# Epoch 191, CIFAR-10 Batch 1:  Cost:     0.8563 Valid Accuracy: 0.696
# Epoch 192, CIFAR-10 Batch 1:  Cost:     0.8253 Valid Accuracy: 0.716
# Epoch 193, CIFAR-10 Batch 1:  Cost:     0.8286 Valid Accuracy: 0.703
# Epoch 194, CIFAR-10 Batch 1:  Cost:     0.7978 Valid Accuracy: 0.725
# Epoch 195, CIFAR-10 Batch 1:  Cost:     0.7965 Valid Accuracy: 0.721
# Epoch 196, CIFAR-10 Batch 1:  Cost:     0.7909 Valid Accuracy: 0.725
# Epoch 197, CIFAR-10 Batch 1:  Cost:     0.7774 Valid Accuracy: 0.733
# Epoch 198, CIFAR-10 Batch 1:  Cost:     0.7793 Valid Accuracy: 0.73
# Epoch 199, CIFAR-10 Batch 1:  Cost:     0.7685 Valid Accuracy: 0.742
# Epoch 200, CIFAR-10 Batch 1:  Cost:     0.7738 Valid Accuracy: 0.729
# Epoch 201, CIFAR-10 Batch 1:  Cost:     0.7780 Valid Accuracy: 0.734
# Epoch 202, CIFAR-10 Batch 1:  Cost:     0.7656 Valid Accuracy: 0.737
# Epoch 203, CIFAR-10 Batch 1:  Cost:     0.7743 Valid Accuracy: 0.73
# Epoch 204, CIFAR-10 Batch 1:  Cost:     0.7788 Valid Accuracy: 0.726
# Epoch 205, CIFAR-10 Batch 1:  Cost:     0.7870 Valid Accuracy: 0.725
# Epoch 206, CIFAR-10 Batch 1:  Cost:     0.7772 Valid Accuracy: 0.724
# Epoch 207, CIFAR-10 Batch 1:  Cost:     0.7362 Valid Accuracy: 0.745
# Epoch 208, CIFAR-10 Batch 1:  Cost:     0.7210 Valid Accuracy: 0.754
# Epoch 209, CIFAR-10 Batch 1:  Cost:     0.7564 Valid Accuracy: 0.732
# Epoch 210, CIFAR-10 Batch 1:  Cost:     0.7558 Valid Accuracy: 0.737
# Epoch 211, CIFAR-10 Batch 1:  Cost:     0.7484 Valid Accuracy: 0.739
# Epoch 212, CIFAR-10 Batch 1:  Cost:     0.7118 Valid Accuracy: 0.756
# Epoch 213, CIFAR-10 Batch 1:  Cost:     0.7363 Valid Accuracy: 0.742
# Epoch 214, CIFAR-10 Batch 1:  Cost:     0.8137 Valid Accuracy: 0.704
# Epoch 215, CIFAR-10 Batch 1:  Cost:     0.8492 Valid Accuracy: 0.694
# Epoch 216, CIFAR-10 Batch 1:  Cost:     0.9502 Valid Accuracy: 0.663
# Epoch 217, CIFAR-10 Batch 1:  Cost:     0.9076 Valid Accuracy: 0.675
# Epoch 218, CIFAR-10 Batch 1:  Cost:     0.8464 Valid Accuracy: 0.683
# Epoch 219, CIFAR-10 Batch 1:  Cost:     1.3149 Valid Accuracy: 0.541
# Epoch 220, CIFAR-10 Batch 1:  Cost:     1.2374 Valid Accuracy: 0.634
# Epoch 221, CIFAR-10 Batch 1:  Cost:     1.6896 Valid Accuracy: 0.539
# Epoch 222, CIFAR-10 Batch 1:  Cost:     1.4928 Valid Accuracy: 0.565
# Epoch 223, CIFAR-10 Batch 1:  Cost:     1.3794 Valid Accuracy: 0.56
# Epoch 224, CIFAR-10 Batch 1:  Cost:     1.0717 Valid Accuracy: 0.613
# Epoch 225, CIFAR-10 Batch 1:  Cost:     1.4305 Valid Accuracy: 0.515
# Epoch 226, CIFAR-10 Batch 1:  Cost:     1.0805 Valid Accuracy: 0.605
# Epoch 227, CIFAR-10 Batch 1:  Cost:     1.0979 Valid Accuracy: 0.582
# Epoch 228, CIFAR-10 Batch 1:  Cost:     1.0280 Valid Accuracy: 0.619
# Epoch 229, CIFAR-10 Batch 1:  Cost:     1.0300 Valid Accuracy: 0.618
# Epoch 230, CIFAR-10 Batch 1:  Cost:     1.0704 Valid Accuracy: 0.602
# Epoch 231, CIFAR-10 Batch 1:  Cost:     1.0616 Valid Accuracy: 0.608
# Epoch 232, CIFAR-10 Batch 1:  Cost:     0.9308 Valid Accuracy: 0.662
# Epoch 233, CIFAR-10 Batch 1:  Cost:     0.9550 Valid Accuracy: 0.648
# Epoch 234, CIFAR-10 Batch 1:  Cost:     1.0178 Valid Accuracy: 0.618
# Epoch 235, CIFAR-10 Batch 1:  Cost:     0.9350 Valid Accuracy: 0.669
# Epoch 236, CIFAR-10 Batch 1:  Cost:     0.9078 Valid Accuracy: 0.678
# Epoch 237, CIFAR-10 Batch 1:  Cost:     0.8719 Valid Accuracy: 0.686
# Epoch 238, CIFAR-10 Batch 1:  Cost:     0.9126 Valid Accuracy: 0.663
# Epoch 239, CIFAR-10 Batch 1:  Cost:     0.9180 Valid Accuracy: 0.657
# Epoch 240, CIFAR-10 Batch 1:  Cost:     0.8391 Valid Accuracy: 0.702
# Epoch 241, CIFAR-10 Batch 1:  Cost:     0.8418 Valid Accuracy: 0.702
# Epoch 242, CIFAR-10 Batch 1:  Cost:     0.8058 Valid Accuracy: 0.718
# Epoch 243, CIFAR-10 Batch 1:  Cost:     0.8435 Valid Accuracy: 0.697
# Epoch 244, CIFAR-10 Batch 1:  Cost:     0.8099 Valid Accuracy: 0.717
# Epoch 245, CIFAR-10 Batch 1:  Cost:     0.8009 Valid Accuracy: 0.716
# Epoch 246, CIFAR-10 Batch 1:  Cost:     0.7609 Valid Accuracy: 0.736
# Epoch 247, CIFAR-10 Batch 1:  Cost:     0.7790 Valid Accuracy: 0.73
# Epoch 248, CIFAR-10 Batch 1:  Cost:     0.7595 Valid Accuracy: 0.731
# Epoch 249, CIFAR-10 Batch 1:  Cost:     0.7576 Valid Accuracy: 0.734
# Epoch 250, CIFAR-10 Batch 1:  Cost:     0.7379 Valid Accuracy: 0.743

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost:     3.1098 Valid Accuracy: 0.111
# Epoch  1, CIFAR-10 Batch 2:  Cost:     2.3245 Valid Accuracy: 0.136
# Epoch  1, CIFAR-10 Batch 3:  Cost:     2.2537 Valid Accuracy: 0.157
# Epoch  1, CIFAR-10 Batch 4:  Cost:     2.2375 Valid Accuracy: 0.148
# Epoch  1, CIFAR-10 Batch 5:  Cost:     2.1773 Valid Accuracy: 0.204
# Epoch  2, CIFAR-10 Batch 1:  Cost:     2.1534 Valid Accuracy: 0.194
# Epoch  2, CIFAR-10 Batch 2:  Cost:     2.1590 Valid Accuracy: 0.191
# Epoch  2, CIFAR-10 Batch 3:  Cost:     2.1161 Valid Accuracy: 0.237
# Epoch  2, CIFAR-10 Batch 4:  Cost:     2.0939 Valid Accuracy: 0.226
# Epoch  2, CIFAR-10 Batch 5:  Cost:     2.0692 Valid Accuracy: 0.265
# Epoch  3, CIFAR-10 Batch 1:  Cost:     2.0417 Valid Accuracy: 0.268
# Epoch  3, CIFAR-10 Batch 2:  Cost:     2.0540 Valid Accuracy: 0.257
# Epoch  3, CIFAR-10 Batch 3:  Cost:     1.9963 Valid Accuracy: 0.288
# Epoch  3, CIFAR-10 Batch 4:  Cost:     1.9965 Valid Accuracy: 0.29
# Epoch  3, CIFAR-10 Batch 5:  Cost:     1.9726 Valid Accuracy: 0.291
# Epoch  4, CIFAR-10 Batch 1:  Cost:     1.9445 Valid Accuracy: 0.298
# Epoch  4, CIFAR-10 Batch 2:  Cost:     1.9392 Valid Accuracy: 0.31
# Epoch  4, CIFAR-10 Batch 3:  Cost:     1.8984 Valid Accuracy: 0.331
# Epoch  4, CIFAR-10 Batch 4:  Cost:     1.8955 Valid Accuracy: 0.326
# Epoch  4, CIFAR-10 Batch 5:  Cost:     1.8767 Valid Accuracy: 0.331
# Epoch  5, CIFAR-10 Batch 1:  Cost:     1.8395 Valid Accuracy: 0.346
# Epoch  5, CIFAR-10 Batch 2:  Cost:     1.8472 Valid Accuracy: 0.346
# Epoch  5, CIFAR-10 Batch 3:  Cost:     1.7985 Valid Accuracy: 0.374
# Epoch  5, CIFAR-10 Batch 4:  Cost:     1.8053 Valid Accuracy: 0.357
# Epoch  5, CIFAR-10 Batch 5:  Cost:     1.7813 Valid Accuracy: 0.359
# Epoch  6, CIFAR-10 Batch 1:  Cost:     1.7419 Valid Accuracy: 0.372
# Epoch  6, CIFAR-10 Batch 2:  Cost:     1.7505 Valid Accuracy: 0.373
# Epoch  6, CIFAR-10 Batch 3:  Cost:     1.7237 Valid Accuracy: 0.391
# Epoch  6, CIFAR-10 Batch 4:  Cost:     1.7709 Valid Accuracy: 0.362
# Epoch  6, CIFAR-10 Batch 5:  Cost:     1.7218 Valid Accuracy: 0.38
# Epoch  7, CIFAR-10 Batch 1:  Cost:     1.6835 Valid Accuracy: 0.404
# Epoch  7, CIFAR-10 Batch 2:  Cost:     1.7108 Valid Accuracy: 0.383
# Epoch  7, CIFAR-10 Batch 3:  Cost:     1.6598 Valid Accuracy: 0.403
# Epoch  7, CIFAR-10 Batch 4:  Cost:     1.6782 Valid Accuracy: 0.411
# Epoch  7, CIFAR-10 Batch 5:  Cost:     1.6631 Valid Accuracy: 0.406
# Epoch  8, CIFAR-10 Batch 1:  Cost:     1.6267 Valid Accuracy: 0.423
# Epoch  8, CIFAR-10 Batch 2:  Cost:     1.6595 Valid Accuracy: 0.405
# Epoch  8, CIFAR-10 Batch 3:  Cost:     1.6129 Valid Accuracy: 0.426
# Epoch  8, CIFAR-10 Batch 4:  Cost:     1.6517 Valid Accuracy: 0.413
# Epoch  8, CIFAR-10 Batch 5:  Cost:     1.6277 Valid Accuracy: 0.416
# Epoch  9, CIFAR-10 Batch 1:  Cost:     1.6279 Valid Accuracy: 0.417
# Epoch  9, CIFAR-10 Batch 2:  Cost:     1.6946 Valid Accuracy: 0.398
# Epoch  9, CIFAR-10 Batch 3:  Cost:     1.5929 Valid Accuracy: 0.422
# Epoch  9, CIFAR-10 Batch 4:  Cost:     1.6296 Valid Accuracy: 0.426
# Epoch  9, CIFAR-10 Batch 5:  Cost:     1.6705 Valid Accuracy: 0.399
# Epoch 10, CIFAR-10 Batch 1:  Cost:     1.5595 Valid Accuracy: 0.443
# Epoch 10, CIFAR-10 Batch 2:  Cost:     1.6387 Valid Accuracy: 0.423
# Epoch 10, CIFAR-10 Batch 3:  Cost:     1.5586 Valid Accuracy: 0.436
# Epoch 10, CIFAR-10 Batch 4:  Cost:     1.5926 Valid Accuracy: 0.424
# Epoch 10, CIFAR-10 Batch 5:  Cost:     1.5710 Valid Accuracy: 0.434
# Epoch 11, CIFAR-10 Batch 1:  Cost:     1.5506 Valid Accuracy: 0.446
# Epoch 11, CIFAR-10 Batch 2:  Cost:     1.5522 Valid Accuracy: 0.449
# Epoch 11, CIFAR-10 Batch 3:  Cost:     1.5451 Valid Accuracy: 0.431
# Epoch 11, CIFAR-10 Batch 4:  Cost:     1.5453 Valid Accuracy: 0.447
# Epoch 11, CIFAR-10 Batch 5:  Cost:     1.5468 Valid Accuracy: 0.457
# Epoch 12, CIFAR-10 Batch 1:  Cost:     1.5030 Valid Accuracy: 0.464
# Epoch 12, CIFAR-10 Batch 2:  Cost:     1.5275 Valid Accuracy: 0.457
# Epoch 12, CIFAR-10 Batch 3:  Cost:     1.4850 Valid Accuracy: 0.464
# Epoch 12, CIFAR-10 Batch 4:  Cost:     1.5160 Valid Accuracy: 0.461
# Epoch 12, CIFAR-10 Batch 5:  Cost:     1.4920 Valid Accuracy: 0.471
# Epoch 13, CIFAR-10 Batch 1:  Cost:     1.4918 Valid Accuracy: 0.469
# Epoch 13, CIFAR-10 Batch 2:  Cost:     1.5521 Valid Accuracy: 0.441
# Epoch 13, CIFAR-10 Batch 3:  Cost:     1.6104 Valid Accuracy: 0.431
# Epoch 13, CIFAR-10 Batch 4:  Cost:     1.6038 Valid Accuracy: 0.443
# Epoch 13, CIFAR-10 Batch 5:  Cost:     1.4932 Valid Accuracy: 0.466
# Epoch 14, CIFAR-10 Batch 1:  Cost:     1.5829 Valid Accuracy: 0.448
# Epoch 14, CIFAR-10 Batch 2:  Cost:     1.5002 Valid Accuracy: 0.469
# Epoch 14, CIFAR-10 Batch 3:  Cost:     1.5178 Valid Accuracy: 0.453
# Epoch 14, CIFAR-10 Batch 4:  Cost:     1.4893 Valid Accuracy: 0.467
# Epoch 14, CIFAR-10 Batch 5:  Cost:     1.5075 Valid Accuracy: 0.471
# Epoch 15, CIFAR-10 Batch 1:  Cost:     1.4496 Valid Accuracy: 0.493
# Epoch 15, CIFAR-10 Batch 2:  Cost:     1.4922 Valid Accuracy: 0.472
# Epoch 15, CIFAR-10 Batch 3:  Cost:     1.4386 Valid Accuracy: 0.481
# Epoch 15, CIFAR-10 Batch 4:  Cost:     1.4690 Valid Accuracy: 0.482
# Epoch 15, CIFAR-10 Batch 5:  Cost:     1.4493 Valid Accuracy: 0.488
# Epoch 16, CIFAR-10 Batch 1:  Cost:     1.4253 Valid Accuracy: 0.497
# Epoch 16, CIFAR-10 Batch 2:  Cost:     1.4525 Valid Accuracy: 0.493
# Epoch 16, CIFAR-10 Batch 3:  Cost:     1.4079 Valid Accuracy: 0.497
# Epoch 16, CIFAR-10 Batch 4:  Cost:     1.4428 Valid Accuracy: 0.489
# Epoch 16, CIFAR-10 Batch 5:  Cost:     1.4220 Valid Accuracy: 0.496
# Epoch 17, CIFAR-10 Batch 1:  Cost:     1.3955 Valid Accuracy: 0.512
# Epoch 17, CIFAR-10 Batch 2:  Cost:     1.4255 Valid Accuracy: 0.496
# Epoch 17, CIFAR-10 Batch 3:  Cost:     1.4035 Valid Accuracy: 0.498
# Epoch 17, CIFAR-10 Batch 4:  Cost:     1.4137 Valid Accuracy: 0.499
# Epoch 17, CIFAR-10 Batch 5:  Cost:     1.3953 Valid Accuracy: 0.505
# Epoch 18, CIFAR-10 Batch 1:  Cost:     1.3817 Valid Accuracy: 0.514
# Epoch 18, CIFAR-10 Batch 2:  Cost:     1.4023 Valid Accuracy: 0.499
# Epoch 18, CIFAR-10 Batch 3:  Cost:     1.4169 Valid Accuracy: 0.498
# Epoch 18, CIFAR-10 Batch 4:  Cost:     1.5294 Valid Accuracy: 0.44
# Epoch 18, CIFAR-10 Batch 5:  Cost:     1.5970 Valid Accuracy: 0.431
# Epoch 19, CIFAR-10 Batch 1:  Cost:     1.4856 Valid Accuracy: 0.469
# Epoch 19, CIFAR-10 Batch 2:  Cost:     1.6257 Valid Accuracy: 0.403
# Epoch 19, CIFAR-10 Batch 3:  Cost:     1.4020 Valid Accuracy: 0.498
# Epoch 19, CIFAR-10 Batch 4:  Cost:     1.5389 Valid Accuracy: 0.461
# Epoch 19, CIFAR-10 Batch 5:  Cost:     1.4280 Valid Accuracy: 0.484
# Epoch 20, CIFAR-10 Batch 1:  Cost:     1.3954 Valid Accuracy: 0.509
# Epoch 20, CIFAR-10 Batch 2:  Cost:     1.5065 Valid Accuracy: 0.436
# Epoch 20, CIFAR-10 Batch 3:  Cost:     1.3986 Valid Accuracy: 0.492
# Epoch 20, CIFAR-10 Batch 4:  Cost:     1.4164 Valid Accuracy: 0.499
# Epoch 20, CIFAR-10 Batch 5:  Cost:     1.4348 Valid Accuracy: 0.491
# Epoch 21, CIFAR-10 Batch 1:  Cost:     1.4116 Valid Accuracy: 0.488
# Epoch 21, CIFAR-10 Batch 2:  Cost:     1.4302 Valid Accuracy: 0.485
# Epoch 21, CIFAR-10 Batch 3:  Cost:     1.3786 Valid Accuracy: 0.5
# Epoch 21, CIFAR-10 Batch 4:  Cost:     1.4085 Valid Accuracy: 0.497
# Epoch 21, CIFAR-10 Batch 5:  Cost:     1.4056 Valid Accuracy: 0.5
# Epoch 22, CIFAR-10 Batch 1:  Cost:     1.3775 Valid Accuracy: 0.513
# Epoch 22, CIFAR-10 Batch 2:  Cost:     1.3860 Valid Accuracy: 0.505
# Epoch 22, CIFAR-10 Batch 3:  Cost:     1.3616 Valid Accuracy: 0.508
# Epoch 22, CIFAR-10 Batch 4:  Cost:     1.4025 Valid Accuracy: 0.495
# Epoch 22, CIFAR-10 Batch 5:  Cost:     1.3619 Valid Accuracy: 0.522
# Epoch 23, CIFAR-10 Batch 1:  Cost:     1.3494 Valid Accuracy: 0.523
# Epoch 23, CIFAR-10 Batch 2:  Cost:     1.3656 Valid Accuracy: 0.506
# Epoch 23, CIFAR-10 Batch 3:  Cost:     1.3455 Valid Accuracy: 0.511
# Epoch 23, CIFAR-10 Batch 4:  Cost:     1.3577 Valid Accuracy: 0.515
# Epoch 23, CIFAR-10 Batch 5:  Cost:     1.3351 Valid Accuracy: 0.529
# Epoch 24, CIFAR-10 Batch 1:  Cost:     1.3273 Valid Accuracy: 0.533
# Epoch 24, CIFAR-10 Batch 2:  Cost:     1.3429 Valid Accuracy: 0.519
# Epoch 24, CIFAR-10 Batch 3:  Cost:     1.3122 Valid Accuracy: 0.528
# Epoch 24, CIFAR-10 Batch 4:  Cost:     1.3322 Valid Accuracy: 0.526
# Epoch 24, CIFAR-10 Batch 5:  Cost:     1.3251 Valid Accuracy: 0.533
# Epoch 25, CIFAR-10 Batch 1:  Cost:     1.3117 Valid Accuracy: 0.538
# Epoch 25, CIFAR-10 Batch 2:  Cost:     1.3422 Valid Accuracy: 0.525
# Epoch 25, CIFAR-10 Batch 3:  Cost:     1.3187 Valid Accuracy: 0.525
# Epoch 25, CIFAR-10 Batch 4:  Cost:     1.3370 Valid Accuracy: 0.529
# Epoch 25, CIFAR-10 Batch 5:  Cost:     1.3336 Valid Accuracy: 0.527
# Epoch 26, CIFAR-10 Batch 1:  Cost:     1.3487 Valid Accuracy: 0.529
# Epoch 26, CIFAR-10 Batch 2:  Cost:     1.3493 Valid Accuracy: 0.518
# Epoch 26, CIFAR-10 Batch 3:  Cost:     1.3007 Valid Accuracy: 0.533
# Epoch 26, CIFAR-10 Batch 4:  Cost:     1.3024 Valid Accuracy: 0.541
# Epoch 26, CIFAR-10 Batch 5:  Cost:     1.3263 Valid Accuracy: 0.528
# Epoch 27, CIFAR-10 Batch 1:  Cost:     1.3040 Valid Accuracy: 0.541
# Epoch 27, CIFAR-10 Batch 2:  Cost:     1.3164 Valid Accuracy: 0.536
# Epoch 27, CIFAR-10 Batch 3:  Cost:     1.3067 Valid Accuracy: 0.533
# Epoch 27, CIFAR-10 Batch 4:  Cost:     1.3301 Valid Accuracy: 0.532
# Epoch 27, CIFAR-10 Batch 5:  Cost:     1.2891 Valid Accuracy: 0.547
# Epoch 28, CIFAR-10 Batch 1:  Cost:     1.2927 Valid Accuracy: 0.534
# Epoch 28, CIFAR-10 Batch 2:  Cost:     1.3383 Valid Accuracy: 0.525
# Epoch 28, CIFAR-10 Batch 3:  Cost:     1.3049 Valid Accuracy: 0.53
# Epoch 28, CIFAR-10 Batch 4:  Cost:     1.3140 Valid Accuracy: 0.537
# Epoch 28, CIFAR-10 Batch 5:  Cost:     1.2914 Valid Accuracy: 0.546
# Epoch 29, CIFAR-10 Batch 1:  Cost:     1.3047 Valid Accuracy: 0.541
# Epoch 29, CIFAR-10 Batch 2:  Cost:     1.3248 Valid Accuracy: 0.529
# Epoch 29, CIFAR-10 Batch 3:  Cost:     1.2625 Valid Accuracy: 0.552
# Epoch 29, CIFAR-10 Batch 4:  Cost:     1.3005 Valid Accuracy: 0.537
# Epoch 29, CIFAR-10 Batch 5:  Cost:     1.2881 Valid Accuracy: 0.548
# Epoch 30, CIFAR-10 Batch 1:  Cost:     1.2598 Valid Accuracy: 0.552
# Epoch 30, CIFAR-10 Batch 2:  Cost:     1.2803 Valid Accuracy: 0.547
# Epoch 30, CIFAR-10 Batch 3:  Cost:     1.2705 Valid Accuracy: 0.547
# Epoch 30, CIFAR-10 Batch 4:  Cost:     1.2726 Valid Accuracy: 0.553
# Epoch 30, CIFAR-10 Batch 5:  Cost:     1.2652 Valid Accuracy: 0.556
# Epoch 31, CIFAR-10 Batch 1:  Cost:     1.2552 Valid Accuracy: 0.559
# Epoch 31, CIFAR-10 Batch 2:  Cost:     1.2587 Valid Accuracy: 0.554
# Epoch 31, CIFAR-10 Batch 3:  Cost:     1.2403 Valid Accuracy: 0.56
# Epoch 31, CIFAR-10 Batch 4:  Cost:     1.2485 Valid Accuracy: 0.559
# Epoch 31, CIFAR-10 Batch 5:  Cost:     1.2429 Valid Accuracy: 0.565
# Epoch 32, CIFAR-10 Batch 1:  Cost:     1.2270 Valid Accuracy: 0.564
# Epoch 32, CIFAR-10 Batch 2:  Cost:     1.1859 Valid Accuracy: 0.578
# Epoch 48, CIFAR-10 Batch 4:  Cost:     1.1908 Valid Accuracy: 0.578
# Epoch 48, CIFAR-10 Batch 5:  Cost:     1.1708 Valid Accuracy: 0.579
# Epoch 49, CIFAR-10 Batch 1:  Cost:     1.1746 Valid Accuracy: 0.582
# Epoch 49, CIFAR-10 Batch 2:  Cost:     1.2092 Valid Accuracy: 0.575
# Epoch 49, CIFAR-10 Batch 3:  Cost:     1.1276 Valid Accuracy: 0.601
# Epoch 49, CIFAR-10 Batch 4:  Cost:     1.1546 Valid Accuracy: 0.588
# Epoch 49, CIFAR-10 Batch 5:  Cost:     1.1709 Valid Accuracy: 0.59
# Epoch 50, CIFAR-10 Batch 1:  Cost:     1.1267 Valid Accuracy: 0.606
# Epoch 50, CIFAR-10 Batch 2:  Cost:     1.1682 Valid Accuracy: 0.58
# Epoch 50, CIFAR-10 Batch 3:  Cost:     1.1364 Valid Accuracy: 0.597
# Epoch 50, CIFAR-10 Batch 4:  Cost:     1.1405 Valid Accuracy: 0.596
# Epoch 50, CIFAR-10 Batch 5:  Cost:     1.1566 Valid Accuracy: 0.587
# Epoch 51, CIFAR-10 Batch 1:  Cost:     1.1086 Valid Accuracy: 0.611
# Epoch 51, CIFAR-10 Batch 2:  Cost:     1.1568 Valid Accuracy: 0.591
# Epoch 51, CIFAR-10 Batch 3:  Cost:     1.0965 Valid Accuracy: 0.613
# Epoch 51, CIFAR-10 Batch 4:  Cost:     1.1440 Valid Accuracy: 0.598
# Epoch 51, CIFAR-10 Batch 5:  Cost:     1.1179 Valid Accuracy: 0.605
# Epoch 52, CIFAR-10 Batch 1:  Cost:     1.1176 Valid Accuracy: 0.607
# Epoch 52, CIFAR-10 Batch 2:  Cost:     1.1361 Valid Accuracy: 0.598
# Epoch 52, CIFAR-10 Batch 3:  Cost:     1.1144 Valid Accuracy: 0.605
# Epoch 52, CIFAR-10 Batch 4:  Cost:     1.1163 Valid Accuracy: 0.609
# Epoch 52, CIFAR-10 Batch 5:  Cost:     1.1134 Valid Accuracy: 0.609
# Epoch 53, CIFAR-10 Batch 1:  Cost:     1.0826 Valid Accuracy: 0.617
# Epoch 53, CIFAR-10 Batch 2:  Cost:     1.1270 Valid Accuracy: 0.604
# Epoch 53, CIFAR-10 Batch 3:  Cost:     1.0900 Valid Accuracy: 0.612
# Epoch 53, CIFAR-10 Batch 4:  Cost:     1.1022 Valid Accuracy: 0.613
# Epoch 53, CIFAR-10 Batch 5:  Cost:     1.1074 Valid Accuracy: 0.611
# Epoch 54, CIFAR-10 Batch 1:  Cost:     1.0891 Valid Accuracy: 0.617
# Epoch 54, CIFAR-10 Batch 2:  Cost:     1.1058 Valid Accuracy: 0.609
# Epoch 54, CIFAR-10 Batch 3:  Cost:     1.0730 Valid Accuracy: 0.616
# Epoch 54, CIFAR-10 Batch 4:  Cost:     1.0966 Valid Accuracy: 0.613
# Epoch 54, CIFAR-10 Batch 5:  Cost:     1.0908 Valid Accuracy: 0.615
# Epoch 55, CIFAR-10 Batch 1:  Cost:     1.0830 Valid Accuracy: 0.617
# Epoch 55, CIFAR-10 Batch 2:  Cost:     1.1203 Valid Accuracy: 0.6
# Epoch 55, CIFAR-10 Batch 3:  Cost:     1.1229 Valid Accuracy: 0.599
# Epoch 55, CIFAR-10 Batch 4:  Cost:     1.1832 Valid Accuracy: 0.583
# Epoch 55, CIFAR-10 Batch 5:  Cost:     1.2172 Valid Accuracy: 0.57
# Epoch 56, CIFAR-10 Batch 1:  Cost:     1.1411 Valid Accuracy: 0.594
# Epoch 56, CIFAR-10 Batch 2:  Cost:     1.1134 Valid Accuracy: 0.605
# Epoch 56, CIFAR-10 Batch 3:  Cost:     1.1504 Valid Accuracy: 0.583
# Epoch 56, CIFAR-10 Batch 4:  Cost:     1.1461 Valid Accuracy: 0.595
# Epoch 56, CIFAR-10 Batch 5:  Cost:     1.1374 Valid Accuracy: 0.601
# Epoch 57, CIFAR-10 Batch 1:  Cost:     1.1202 Valid Accuracy: 0.604
# Epoch 57, CIFAR-10 Batch 2:  Cost:     1.1544 Valid Accuracy: 0.595
# Epoch 57, CIFAR-10 Batch 3:  Cost:     1.0781 Valid Accuracy: 0.621
# Epoch 57, CIFAR-10 Batch 4:  Cost:     1.1357 Valid Accuracy: 0.594
# Epoch 57, CIFAR-10 Batch 5:  Cost:     1.0980 Valid Accuracy: 0.617
# Epoch 58, CIFAR-10 Batch 1:  Cost:     1.1446 Valid Accuracy: 0.599
# Epoch 58, CIFAR-10 Batch 2:  Cost:     1.1803 Valid Accuracy: 0.591
# Epoch 58, CIFAR-10 Batch 3:  Cost:     1.1282 Valid Accuracy: 0.596
# Epoch 58, CIFAR-10 Batch 4:  Cost:     1.1230 Valid Accuracy: 0.604
# Epoch 58, CIFAR-10 Batch 5:  Cost:     1.1359 Valid Accuracy: 0.606
# Epoch 59, CIFAR-10 Batch 1:  Cost:     1.1510 Valid Accuracy: 0.591
# Epoch 59, CIFAR-10 Batch 2:  Cost:     1.1066 Valid Accuracy: 0.609
# Epoch 59, CIFAR-10 Batch 3:  Cost:     1.1308 Valid Accuracy: 0.598
# Epoch 59, CIFAR-10 Batch 4:  Cost:     1.1261 Valid Accuracy: 0.6
# Epoch 59, CIFAR-10 Batch 5:  Cost:     1.0915 Valid Accuracy: 0.621
# Epoch 60, CIFAR-10 Batch 1:  Cost:     1.1212 Valid Accuracy: 0.608
# Epoch 60, CIFAR-10 Batch 2:  Cost:     1.1286 Valid Accuracy: 0.599
# Epoch 60, CIFAR-10 Batch 3:  Cost:     1.0832 Valid Accuracy: 0.615
# Epoch 60, CIFAR-10 Batch 4:  Cost:     1.0925 Valid Accuracy: 0.613
# Epoch 60, CIFAR-10 Batch 5:  Cost:     1.0919 Valid Accuracy: 0.617
# Epoch 61, CIFAR-10 Batch 1:  Cost:     1.0928 Valid Accuracy: 0.615
# Epoch 61, CIFAR-10 Batch 2:  Cost:     1.0876 Valid Accuracy: 0.618
# Epoch 61, CIFAR-10 Batch 3:  Cost:     1.0615 Valid Accuracy: 0.626
# Epoch 61, CIFAR-10 Batch 4:  Cost:     1.0836 Valid Accuracy: 0.619
# Epoch 61, CIFAR-10 Batch 5:  Cost:     1.0570 Valid Accuracy: 0.632
# Epoch 62, CIFAR-10 Batch 1:  Cost:     1.0643 Valid Accuracy: 0.625
# Epoch 62, CIFAR-10 Batch 2:  Cost:     1.0742 Valid Accuracy: 0.619
# Epoch 62, CIFAR-10 Batch 3:  Cost:     1.0574 Valid Accuracy: 0.625
# Epoch 62, CIFAR-10 Batch 4:  Cost:     1.0650 Valid Accuracy: 0.624
# Epoch 62, CIFAR-10 Batch 5:  Cost:     1.0634 Valid Accuracy: 0.624
# Epoch 63, CIFAR-10 Batch 1:  Cost:     1.0449 Valid Accuracy: 0.635
# Epoch 63, CIFAR-10 Batch 2:  Cost:     1.0684 Valid Accuracy: 0.62
# Epoch 63, CIFAR-10 Batch 3:  Cost:     1.0402 Valid Accuracy: 0.631
# Epoch 63, CIFAR-10 Batch 4:  Cost:     1.0671 Valid Accuracy: 0.624
# Epoch 63, CIFAR-10 Batch 5:  Cost:     1.0609 Valid Accuracy: 0.627
# Epoch 64, CIFAR-10 Batch 1:  Cost:     1.0455 Valid Accuracy: 0.638
# Epoch 64, CIFAR-10 Batch 2:  Cost:     1.0576 Valid Accuracy: 0.623
# Epoch 64, CIFAR-10 Batch 3:  Cost:     1.0350 Valid Accuracy: 0.633
# Epoch 64, CIFAR-10 Batch 4:  Cost:     1.0784 Valid Accuracy: 0.616
# Epoch 64, CIFAR-10 Batch 5:  Cost:     1.0707 Valid Accuracy: 0.621
# Epoch 65, CIFAR-10 Batch 1:  Cost:     1.0262 Valid Accuracy: 0.64
# Epoch 65, CIFAR-10 Batch 2:  Cost:     1.0611 Valid Accuracy: 0.625
# Epoch 65, CIFAR-10 Batch 3:  Cost:     1.0585 Valid Accuracy: 0.624
# Epoch 65, CIFAR-10 Batch 4:  Cost:     1.0496 Valid Accuracy: 0.63
# Epoch 65, CIFAR-10 Batch 5:  Cost:     1.0444 Valid Accuracy: 0.632
# Epoch 66, CIFAR-10 Batch 1:  Cost:     1.0382 Valid Accuracy: 0.633
# Epoch 66, CIFAR-10 Batch 2:  Cost:     1.0559 Valid Accuracy: 0.623
# Epoch 66, CIFAR-10 Batch 3:  Cost:     1.0361 Valid Accuracy: 0.625
# Epoch 66, CIFAR-10 Batch 4:  Cost:     1.0418 Valid Accuracy: 0.632
# Epoch 66, CIFAR-10 Batch 5:  Cost:     1.0358 Valid Accuracy: 0.639
# Epoch 67, CIFAR-10 Batch 1:  Cost:     1.0345 Valid Accuracy: 0.636
# Epoch 67, CIFAR-10 Batch 2:  Cost:     1.0532 Valid Accuracy: 0.626
# Epoch 67, CIFAR-10 Batch 3:  Cost:     1.0440 Valid Accuracy: 0.627
# Epoch 67, CIFAR-10 Batch 4:  Cost:     1.0476 Valid Accuracy: 0.629
# Epoch 67, CIFAR-10 Batch 5:  Cost:     1.0275 Valid Accuracy: 0.635
# Epoch 68, CIFAR-10 Batch 1:  Cost:     1.0291 Valid Accuracy: 0.635
# Epoch 68, CIFAR-10 Batch 2:  Cost:     1.0430 Valid Accuracy: 0.63
# Epoch 68, CIFAR-10 Batch 3:  Cost:     1.0183 Valid Accuracy: 0.637
# Epoch 68, CIFAR-10 Batch 4:  Cost:     1.0446 Valid Accuracy: 0.631
# Epoch 68, CIFAR-10 Batch 5:  Cost:     1.0323 Valid Accuracy: 0.636
# Epoch 69, CIFAR-10 Batch 1:  Cost:     1.0157 Valid Accuracy: 0.643
# Epoch 69, CIFAR-10 Batch 2:  Cost:     1.0325 Valid Accuracy: 0.637
# Epoch 69, CIFAR-10 Batch 3:  Cost:     1.0000 Valid Accuracy: 0.649
# Epoch 69, CIFAR-10 Batch 4:  Cost:     1.0231 Valid Accuracy: 0.636
# Epoch 69, CIFAR-10 Batch 5:  Cost:     1.0169 Valid Accuracy: 0.644
# Epoch 70, CIFAR-10 Batch 1:  Cost:     1.0078 Valid Accuracy: 0.645
# Epoch 70, CIFAR-10 Batch 2:  Cost:     1.0375 Valid Accuracy: 0.629
# Epoch 70, CIFAR-10 Batch 3:  Cost:     1.0121 Valid Accuracy: 0.644
# Epoch 70, CIFAR-10 Batch 4:  Cost:     1.0435 Valid Accuracy: 0.629
# Epoch 70, CIFAR-10 Batch 5:  Cost:     1.0713 Valid Accuracy: 0.619
# Epoch 71, CIFAR-10 Batch 1:  Cost:     1.0375 Valid Accuracy: 0.631
# Epoch 71, CIFAR-10 Batch 2:  Cost:     1.0487 Valid Accuracy: 0.631
# Epoch 71, CIFAR-10 Batch 3:  Cost:     1.0319 Valid Accuracy: 0.64
# Epoch 71, CIFAR-10 Batch 4:  Cost:     1.0358 Valid Accuracy: 0.638
# Epoch 71, CIFAR-10 Batch 5:  Cost:     1.0256 Valid Accuracy: 0.642
# Epoch 72, CIFAR-10 Batch 1:  Cost:     1.0154 Valid Accuracy: 0.641
# Epoch 72, CIFAR-10 Batch 2:  Cost:     1.0531 Valid Accuracy: 0.629
# Epoch 72, CIFAR-10 Batch 3:  Cost:     1.0783 Valid Accuracy: 0.622
# Epoch 72, CIFAR-10 Batch 4:  Cost:     1.0672 Valid Accuracy: 0.625
# Epoch 72, CIFAR-10 Batch 5:  Cost:     1.0746 Valid Accuracy: 0.618
# Epoch 73, CIFAR-10 Batch 1:  Cost:     1.1174 Valid Accuracy: 0.605
# Epoch 73, CIFAR-10 Batch 2:  Cost:     1.0453 Valid Accuracy: 0.627
# Epoch 73, CIFAR-10 Batch 3:  Cost:     1.0773 Valid Accuracy: 0.617
# Epoch 73, CIFAR-10 Batch 4:  Cost:     1.0695 Valid Accuracy: 0.625
# Epoch 73, CIFAR-10 Batch 5:  Cost:     1.0677 Valid Accuracy: 0.625
# Epoch 74, CIFAR-10 Batch 1:  Cost:     1.0191 Valid Accuracy: 0.639
# Epoch 74, CIFAR-10 Batch 2:  Cost:     1.0632 Valid Accuracy: 0.618
# Epoch 74, CIFAR-10 Batch 3:  Cost:     1.0854 Valid Accuracy: 0.613
# Epoch 74, CIFAR-10 Batch 4:  Cost:     1.0430 Valid Accuracy: 0.633
# Epoch 74, CIFAR-10 Batch 5:  Cost:     1.0563 Valid Accuracy: 0.62
# Epoch 75, CIFAR-10 Batch 1:  Cost:     1.0813 Valid Accuracy: 0.618
# Epoch 75, CIFAR-10 Batch 2:  Cost:     1.1065 Valid Accuracy: 0.604
# Epoch 75, CIFAR-10 Batch 3:  Cost:     1.0472 Valid Accuracy: 0.626
# Epoch 75, CIFAR-10 Batch 4:  Cost:     1.1141 Valid Accuracy: 0.6
# Epoch 75, CIFAR-10 Batch 5:  Cost:     1.1056 Valid Accuracy: 0.604
# Epoch 76, CIFAR-10 Batch 1:  Cost:     1.1064 Valid Accuracy: 0.602
# Epoch 76, CIFAR-10 Batch 2:  Cost:     1.1213 Valid Accuracy: 0.597
# Epoch 76, CIFAR-10 Batch 3:  Cost:     1.1131 Valid Accuracy: 0.601
# Epoch 76, CIFAR-10 Batch 4:  Cost:     1.1771 Valid Accuracy: 0.584
# Epoch 76, CIFAR-10 Batch 5:  Cost:     1.1360 Valid Accuracy: 0.593
# Epoch 77, CIFAR-10 Batch 1:  Cost:     1.0856 Valid Accuracy: 0.615
# Epoch 77, CIFAR-10 Batch 2:  Cost:     1.1387 Valid Accuracy: 0.597
# Epoch 77, CIFAR-10 Batch 3:  Cost:     1.1050 Valid Accuracy: 0.607
# Epoch 77, CIFAR-10 Batch 4:  Cost:     1.0592 Valid Accuracy: 0.618
# Epoch 77, CIFAR-10 Batch 5:  Cost:     1.0860 Valid Accuracy: 0.606
# Epoch 78, CIFAR-10 Batch 1:  Cost:     1.0496 Valid Accuracy: 0.626
# Epoch 78, CIFAR-10 Batch 2:  Cost:     1.0519 Valid Accuracy: 0.626
# Epoch 78, CIFAR-10 Batch 3:  Cost:     1.0453 Valid Accuracy: 0.626
# Epoch 78, CIFAR-10 Batch 4:  Cost:     1.0491 Valid Accuracy: 0.626
# Epoch 78, CIFAR-10 Batch 5:  Cost:     1.0376 Valid Accuracy: 0.63
# Epoch 79, CIFAR-10 Batch 1:  Cost:     1.0271 Valid Accuracy: 0.634
# Epoch 79, CIFAR-10 Batch 2:  Cost:     1.0423 Valid Accuracy: 0.627
# Epoch 79, CIFAR-10 Batch 3:  Cost:     1.0269 Valid Accuracy: 0.637
# Epoch 79, CIFAR-10 Batch 4:  Cost:     1.0211 Valid Accuracy: 0.638
# Epoch 79, CIFAR-10 Batch 5:  Cost:     1.0380 Valid Accuracy: 0.629
# Epoch 80, CIFAR-10 Batch 1:  Cost:     0.9999 Valid Accuracy: 0.651
# Epoch 80, CIFAR-10 Batch 2:  Cost:     1.0284 Valid Accuracy: 0.634
# Epoch 80, CIFAR-10 Batch 3:  Cost:     1.0029 Valid Accuracy: 0.64
# Epoch 80, CIFAR-10 Batch 4:  Cost:     0.9998 Valid Accuracy: 0.644
# Epoch 80, CIFAR-10 Batch 5:  Cost:     1.0091 Valid Accuracy: 0.64
# Epoch 81, CIFAR-10 Batch 1:  Cost:     0.9880 Valid Accuracy: 0.65
# Epoch 81, CIFAR-10 Batch 2:  Cost:     1.0175 Valid Accuracy: 0.639
# Epoch 81, CIFAR-10 Batch 3:  Cost:     0.9884 Valid Accuracy: 0.648
# Epoch 81, CIFAR-10 Batch 4:  Cost:     1.0010 Valid Accuracy: 0.643
# Epoch 81, CIFAR-10 Batch 5:  Cost:     1.0018 Valid Accuracy: 0.644
# Epoch 82, CIFAR-10 Batch 1:  Cost:     0.9722 Valid Accuracy: 0.659
# Epoch 82, CIFAR-10 Batch 2:  Cost:     1.0100 Valid Accuracy: 0.647
# Epoch 82, CIFAR-10 Batch 3:  Cost:     0.9799 Valid Accuracy: 0.653
# Epoch 82, CIFAR-10 Batch 4:  Cost:     0.9833 Valid Accuracy: 0.654
# Epoch 82, CIFAR-10 Batch 5:  Cost:     0.9835 Valid Accuracy: 0.656
# Epoch 83, CIFAR-10 Batch 1:  Cost:     0.9744 Valid Accuracy: 0.656
# Epoch 83, CIFAR-10 Batch 2:  Cost:     1.0033 Valid Accuracy: 0.647
# Epoch 83, CIFAR-10 Batch 3:  Cost:     0.9906 Valid Accuracy: 0.653
# Epoch 83, CIFAR-10 Batch 4:  Cost:     1.0524 Valid Accuracy: 0.636
# Epoch 83, CIFAR-10 Batch 5:  Cost:     1.0841 Valid Accuracy: 0.621
# Epoch 84, CIFAR-10 Batch 1:  Cost:     1.1341 Valid Accuracy: 0.611
# Epoch 84, CIFAR-10 Batch 2:  Cost:     1.0953 Valid Accuracy: 0.621
# Epoch 84, CIFAR-10 Batch 3:  Cost:     0.9900 Valid Accuracy: 0.646
# Epoch 84, CIFAR-10 Batch 4:  Cost:     1.0992 Valid Accuracy: 0.616
# Epoch 84, CIFAR-10 Batch 5:  Cost:     1.1123 Valid Accuracy: 0.616
# Epoch 85, CIFAR-10 Batch 1:  Cost:     1.0183 Valid Accuracy: 0.636
# Epoch 85, CIFAR-10 Batch 2:  Cost:     1.0965 Valid Accuracy: 0.609
# Epoch 85, CIFAR-10 Batch 3:  Cost:     1.0138 Valid Accuracy: 0.646
# Epoch 85, CIFAR-10 Batch 4:  Cost:     1.0934 Valid Accuracy: 0.609
# Epoch 85, CIFAR-10 Batch 5:  Cost:     1.0260 Valid Accuracy: 0.634
# Epoch 86, CIFAR-10 Batch 1:  Cost:     1.0526 Valid Accuracy: 0.63
# Epoch 86, CIFAR-10 Batch 2:  Cost:     1.0371 Valid Accuracy: 0.634
# Epoch 86, CIFAR-10 Batch 3:  Cost:     1.0284 Valid Accuracy: 0.637
# Epoch 86, CIFAR-10 Batch 4:  Cost:     0.9970 Valid Accuracy: 0.653
# Epoch 86, CIFAR-10 Batch 5:  Cost:     1.0237 Valid Accuracy: 0.643
# Epoch 87, CIFAR-10 Batch 1:  Cost:     0.9944 Valid Accuracy: 0.656
# Epoch 87, CIFAR-10 Batch 2:  Cost:     1.0133 Valid Accuracy: 0.642
# Epoch 87, CIFAR-10 Batch 3:  Cost:     0.9814 Valid Accuracy: 0.652
# Epoch 87, CIFAR-10 Batch 4:  Cost:     0.9982 Valid Accuracy: 0.652
# Epoch 87, CIFAR-10 Batch 5:  Cost:     0.9870 Valid Accuracy: 0.651
# Epoch 88, CIFAR-10 Batch 1:  Cost:     0.9702 Valid Accuracy: 0.661
# Epoch 88, CIFAR-10 Batch 2:  Cost:     0.9966 Valid Accuracy: 0.652
# Epoch 88, CIFAR-10 Batch 3:  Cost:     0.9567 Valid Accuracy: 0.664
# Epoch 88, CIFAR-10 Batch 4:  Cost:     0.9903 Valid Accuracy: 0.65
# Epoch 88, CIFAR-10 Batch 5:  Cost:     0.9856 Valid Accuracy: 0.652
# Epoch 89, CIFAR-10 Batch 1:  Cost:     0.9578 Valid Accuracy: 0.666
# Epoch 89, CIFAR-10 Batch 2:  Cost:     0.9887 Valid Accuracy: 0.65
# Epoch 89, CIFAR-10 Batch 3:  Cost:     0.9673 Valid Accuracy: 0.662
# Epoch 89, CIFAR-10 Batch 4:  Cost:     0.9754 Valid Accuracy: 0.656
# Epoch 89, CIFAR-10 Batch 5:  Cost:     0.9803 Valid Accuracy: 0.654
# Epoch 90, CIFAR-10 Batch 1:  Cost:     0.9577 Valid Accuracy: 0.662
# Epoch 90, CIFAR-10 Batch 2:  Cost:     0.9669 Valid Accuracy: 0.658
# Epoch 90, CIFAR-10 Batch 3:  Cost:     0.9607 Valid Accuracy: 0.662
# Epoch 90, CIFAR-10 Batch 4:  Cost:     0.9879 Valid Accuracy: 0.655
# Epoch 90, CIFAR-10 Batch 5:  Cost:     0.9751 Valid Accuracy: 0.657
# Epoch 91, CIFAR-10 Batch 1:  Cost:     0.9420 Valid Accuracy: 0.67
# Epoch 91, CIFAR-10 Batch 2:  Cost:     0.9809 Valid Accuracy: 0.651
# Epoch 91, CIFAR-10 Batch 3:  Cost:     0.9696 Valid Accuracy: 0.658
# Epoch 91, CIFAR-10 Batch 4:  Cost:     0.9799 Valid Accuracy: 0.651
# Epoch 91, CIFAR-10 Batch 5:  Cost:     0.9743 Valid Accuracy: 0.656
# Epoch 92, CIFAR-10 Batch 1:  Cost:     0.9765 Valid Accuracy: 0.655
# Epoch 92, CIFAR-10 Batch 2:  Cost:     0.9823 Valid Accuracy: 0.653
# Epoch 92, CIFAR-10 Batch 3:  Cost:     0.9857 Valid Accuracy: 0.655
# Epoch 92, CIFAR-10 Batch 4:  Cost:     0.9970 Valid Accuracy: 0.648
# Epoch 92, CIFAR-10 Batch 5:  Cost:     0.9552 Valid Accuracy: 0.658
# Epoch 93, CIFAR-10 Batch 1:  Cost:     0.9615 Valid Accuracy: 0.667
# Epoch 93, CIFAR-10 Batch 2:  Cost:     0.9780 Valid Accuracy: 0.655
# Epoch 93, CIFAR-10 Batch 3:  Cost:     0.9364 Valid Accuracy: 0.673
# Epoch 93, CIFAR-10 Batch 4:  Cost:     0.9576 Valid Accuracy: 0.669
# Epoch 93, CIFAR-10 Batch 5:  Cost:     0.9436 Valid Accuracy: 0.667
# Epoch 94, CIFAR-10 Batch 1:  Cost:     0.9545 Valid Accuracy: 0.664
# Epoch 94, CIFAR-10 Batch 2:  Cost:     0.9770 Valid Accuracy: 0.656
# Epoch 94, CIFAR-10 Batch 3:  Cost:     0.9568 Valid Accuracy: 0.662
# Epoch 94, CIFAR-10 Batch 4:  Cost:     0.9775 Valid Accuracy: 0.651
# Epoch 94, CIFAR-10 Batch 5:  Cost:     0.9639 Valid Accuracy: 0.659
# Epoch 95, CIFAR-10 Batch 1:  Cost:     0.9553 Valid Accuracy: 0.668
# Epoch 95, CIFAR-10 Batch 2:  Cost:     0.9571 Valid Accuracy: 0.664
# Epoch 95, CIFAR-10 Batch 3:  Cost:     0.9397 Valid Accuracy: 0.661
# Epoch 95, CIFAR-10 Batch 4:  Cost:     0.9570 Valid Accuracy: 0.663
# Epoch 95, CIFAR-10 Batch 5:  Cost:     0.9538 Valid Accuracy: 0.665
# Epoch 96, CIFAR-10 Batch 1:  Cost:     0.9363 Valid Accuracy: 0.671
# Epoch 96, CIFAR-10 Batch 2:  Cost:     0.9521 Valid Accuracy: 0.666
# Epoch 96, CIFAR-10 Batch 3:  Cost:     0.9324 Valid Accuracy: 0.673
# Epoch 96, CIFAR-10 Batch 4:  Cost:     0.9597 Valid Accuracy: 0.66
# Epoch 96, CIFAR-10 Batch 5:  Cost:     0.9874 Valid Accuracy: 0.648
# Epoch 97, CIFAR-10 Batch 1:  Cost:     0.9502 Valid Accuracy: 0.664
# Epoch 97, CIFAR-10 Batch 2:  Cost:     1.0139 Valid Accuracy: 0.644
# Epoch 97, CIFAR-10 Batch 3:  Cost:     0.9618 Valid Accuracy: 0.661
# Epoch 97, CIFAR-10 Batch 4:  Cost:     0.9465 Valid Accuracy: 0.665
# Epoch 97, CIFAR-10 Batch 5:  Cost:     1.0017 Valid Accuracy: 0.64
# Epoch 98, CIFAR-10 Batch 1:  Cost:     1.0274 Valid Accuracy: 0.633
# Epoch 98, CIFAR-10 Batch 2:  Cost:     1.0042 Valid Accuracy: 0.642
# Epoch 98, CIFAR-10 Batch 3:  Cost:     0.9538 Valid Accuracy: 0.655
# Epoch 98, CIFAR-10 Batch 4:  Cost:     1.0378 Valid Accuracy: 0.629
# Epoch 98, CIFAR-10 Batch 5:  Cost:     1.0490 Valid Accuracy: 0.627
# Epoch 99, CIFAR-10 Batch 1:  Cost:     1.0558 Valid Accuracy: 0.628
# Epoch 99, CIFAR-10 Batch 2:  Cost:     1.0820 Valid Accuracy: 0.615
# Epoch 99, CIFAR-10 Batch 3:  Cost:     0.9981 Valid Accuracy: 0.644
# Epoch 99, CIFAR-10 Batch 4:  Cost:     1.1938 Valid Accuracy: 0.583
# Epoch 99, CIFAR-10 Batch 5:  Cost:     1.0762 Valid Accuracy: 0.608
# Epoch 100, CIFAR-10 Batch 1:  Cost:     1.0402 Valid Accuracy: 0.63
# Epoch 100, CIFAR-10 Batch 2:  Cost:     1.0981 Valid Accuracy: 0.601
# Epoch 100, CIFAR-10 Batch 3:  Cost:     1.0346 Valid Accuracy: 0.623
# Epoch 100, CIFAR-10 Batch 4:  Cost:     1.0342 Valid Accuracy: 0.63
# Epoch 100, CIFAR-10 Batch 5:  Cost:     1.0355 Valid Accuracy: 0.635
# Epoch 101, CIFAR-10 Batch 1:  Cost:     1.0428 Valid Accuracy: 0.625
# Epoch 101, CIFAR-10 Batch 2:  Cost:     0.9900 Valid Accuracy: 0.648
# Epoch 101, CIFAR-10 Batch 3:  Cost:     1.0099 Valid Accuracy: 0.625
# Epoch 101, CIFAR-10 Batch 4:  Cost:     0.9913 Valid Accuracy: 0.645
# Epoch 101, CIFAR-10 Batch 5:  Cost:     1.0039 Valid Accuracy: 0.643
# Epoch 102, CIFAR-10 Batch 1:  Cost:     0.9662 Valid Accuracy: 0.658
# Epoch 102, CIFAR-10 Batch 2:  Cost:     0.9967 Valid Accuracy: 0.644
# Epoch 102, CIFAR-10 Batch 3:  Cost:     0.9779 Valid Accuracy: 0.654
# Epoch 102, CIFAR-10 Batch 4:  Cost:     0.9797 Valid Accuracy: 0.656
# Epoch 102, CIFAR-10 Batch 5:  Cost:     0.9723 Valid Accuracy: 0.661
# Epoch 103, CIFAR-10 Batch 1:  Cost:     0.9486 Valid Accuracy: 0.662
# Epoch 103, CIFAR-10 Batch 2:  Cost:     0.9811 Valid Accuracy: 0.653
# Epoch 103, CIFAR-10 Batch 3:  Cost:     0.9424 Valid Accuracy: 0.667
# Epoch 103, CIFAR-10 Batch 4:  Cost:     0.9736 Valid Accuracy: 0.654
# Epoch 103, CIFAR-10 Batch 5:  Cost:     0.9628 Valid Accuracy: 0.658
# Epoch 104, CIFAR-10 Batch 1:  Cost:     0.9477 Valid Accuracy: 0.666
# Epoch 104, CIFAR-10 Batch 2:  Cost:     0.9530 Valid Accuracy: 0.666
# Epoch 104, CIFAR-10 Batch 3:  Cost:     0.9404 Valid Accuracy: 0.671
# Epoch 104, CIFAR-10 Batch 4:  Cost:     1.0024 Valid Accuracy: 0.642
# Epoch 104, CIFAR-10 Batch 5:  Cost:     1.0248 Valid Accuracy: 0.64
# Epoch 105, CIFAR-10 Batch 1:  Cost:     0.9539 Valid Accuracy: 0.665
# Epoch 105, CIFAR-10 Batch 2:  Cost:     0.9977 Valid Accuracy: 0.646
# Epoch 105, CIFAR-10 Batch 3:  Cost:     1.0686 Valid Accuracy: 0.616
# Epoch 105, CIFAR-10 Batch 4:  Cost:     0.9680 Valid Accuracy: 0.652
# Epoch 105, CIFAR-10 Batch 5:  Cost:     1.1084 Valid Accuracy: 0.604
# Epoch 106, CIFAR-10 Batch 1:  Cost:     1.1155 Valid Accuracy: 0.62
# Epoch 106, CIFAR-10 Batch 2:  Cost:     1.1553 Valid Accuracy: 0.589
# Epoch 106, CIFAR-10 Batch 3:  Cost:     1.0042 Valid Accuracy: 0.646
# Epoch 106, CIFAR-10 Batch 4:  Cost:     1.0993 Valid Accuracy: 0.596
# Epoch 106, CIFAR-10 Batch 5:  Cost:     0.9868 Valid Accuracy: 0.653
# Epoch 107, CIFAR-10 Batch 1:  Cost:     1.0270 Valid Accuracy: 0.63
# Epoch 107, CIFAR-10 Batch 2:  Cost:     1.0224 Valid Accuracy: 0.631
# Epoch 107, CIFAR-10 Batch 3:  Cost:     0.9725 Valid Accuracy: 0.66
# Epoch 107, CIFAR-10 Batch 4:  Cost:     0.9875 Valid Accuracy: 0.648
# Epoch 107, CIFAR-10 Batch 5:  Cost:     1.0143 Valid Accuracy: 0.636
# Epoch 108, CIFAR-10 Batch 1:  Cost:     0.9561 Valid Accuracy: 0.666
# Epoch 108, CIFAR-10 Batch 2:  Cost:     0.9733 Valid Accuracy: 0.662
# Epoch 108, CIFAR-10 Batch 3:  Cost:     0.9790 Valid Accuracy: 0.655
# Epoch 108, CIFAR-10 Batch 4:  Cost:     0.9779 Valid Accuracy: 0.654
# Epoch 108, CIFAR-10 Batch 5:  Cost:     0.9675 Valid Accuracy: 0.661
# Epoch 109, CIFAR-10 Batch 1:  Cost:     0.9405 Valid Accuracy: 0.67
# Epoch 109, CIFAR-10 Batch 2:  Cost:     0.9943 Valid Accuracy: 0.648
# Epoch 109, CIFAR-10 Batch 3:  Cost:     0.9525 Valid Accuracy: 0.666
# Epoch 109, CIFAR-10 Batch 4:  Cost:     0.9484 Valid Accuracy: 0.666
# Epoch 109, CIFAR-10 Batch 5:  Cost:     0.9661 Valid Accuracy: 0.66
# Epoch 110, CIFAR-10 Batch 1:  Cost:     0.9578 Valid Accuracy: 0.662
# Epoch 110, CIFAR-10 Batch 2:  Cost:     0.9453 Valid Accuracy: 0.665
# Epoch 110, CIFAR-10 Batch 3:  Cost:     0.9293 Valid Accuracy: 0.669
# Epoch 110, CIFAR-10 Batch 4:  Cost:     0.9499 Valid Accuracy: 0.664
# Epoch 110, CIFAR-10 Batch 5:  Cost:     0.9332 Valid Accuracy: 0.672
# Epoch 111, CIFAR-10 Batch 1:  Cost:     0.9240 Valid Accuracy: 0.674
# Epoch 111, CIFAR-10 Batch 2:  Cost:     0.9432 Valid Accuracy: 0.669
# Epoch 111, CIFAR-10 Batch 3:  Cost:     0.9062 Valid Accuracy: 0.679
# Epoch 111, CIFAR-10 Batch 4:  Cost:     0.9399 Valid Accuracy: 0.67
# Epoch 111, CIFAR-10 Batch 5:  Cost:     0.9334 Valid Accuracy: 0.674
# Epoch 112, CIFAR-10 Batch 1:  Cost:     0.9110 Valid Accuracy: 0.684
# Epoch 112, CIFAR-10 Batch 2:  Cost:     0.9484 Valid Accuracy: 0.665
# Epoch 112, CIFAR-10 Batch 3:  Cost:     0.9120 Valid Accuracy: 0.68
# Epoch 112, CIFAR-10 Batch 4:  Cost:     0.9197 Valid Accuracy: 0.678
# Epoch 112, CIFAR-10 Batch 5:  Cost:     0.9336 Valid Accuracy: 0.673
# Epoch 113, CIFAR-10 Batch 1:  Cost:     0.9087 Valid Accuracy: 0.684
# Epoch 113, CIFAR-10 Batch 2:  Cost:     0.9179 Valid Accuracy: 0.679
# Epoch 113, CIFAR-10 Batch 3:  Cost:     0.9013 Valid Accuracy: 0.681
# Epoch 113, CIFAR-10 Batch 4:  Cost:     0.9164 Valid Accuracy: 0.681
# Epoch 113, CIFAR-10 Batch 5:  Cost:     0.9180 Valid Accuracy: 0.677
# Epoch 114, CIFAR-10 Batch 1:  Cost:     0.9006 Valid Accuracy: 0.686
# Epoch 114, CIFAR-10 Batch 2:  Cost:     0.9196 Valid Accuracy: 0.675
# Epoch 114, CIFAR-10 Batch 3:  Cost:     0.9024 Valid Accuracy: 0.678
# Epoch 114, CIFAR-10 Batch 4:  Cost:     0.9102 Valid Accuracy: 0.675
# Epoch 114, CIFAR-10 Batch 5:  Cost:     0.9078 Valid Accuracy: 0.682
# Epoch 115, CIFAR-10 Batch 1:  Cost:     0.9109 Valid Accuracy: 0.682
# Epoch 115, CIFAR-10 Batch 2:  Cost:     0.9090 Valid Accuracy: 0.681
# Epoch 115, CIFAR-10 Batch 3:  Cost:     0.8942 Valid Accuracy: 0.685
# Epoch 115, CIFAR-10 Batch 4:  Cost:     0.9155 Valid Accuracy: 0.683
# Epoch 115, CIFAR-10 Batch 5:  Cost:     0.9092 Valid Accuracy: 0.68
# Epoch 116, CIFAR-10 Batch 1:  Cost:     0.8974 Valid Accuracy: 0.684
# Epoch 116, CIFAR-10 Batch 2:  Cost:     0.9013 Valid Accuracy: 0.687
# Epoch 116, CIFAR-10 Batch 3:  Cost:     0.8882 Valid Accuracy: 0.685
# Epoch 116, CIFAR-10 Batch 4:  Cost:     0.9103 Valid Accuracy: 0.681
# Epoch 116, CIFAR-10 Batch 5:  Cost:     0.9042 Valid Accuracy: 0.682
# Epoch 117, CIFAR-10 Batch 1:  Cost:     0.8917 Valid Accuracy: 0.689
# Epoch 117, CIFAR-10 Batch 2:  Cost:     0.9309 Valid Accuracy: 0.669
# Epoch 117, CIFAR-10 Batch 3:  Cost:     0.9204 Valid Accuracy: 0.676
# Epoch 117, CIFAR-10 Batch 4:  Cost:     0.9542 Valid Accuracy: 0.661
# Epoch 117, CIFAR-10 Batch 5:  Cost:     0.9395 Valid Accuracy: 0.663
# Epoch 118, CIFAR-10 Batch 1:  Cost:     0.8941 Valid Accuracy: 0.687
# Epoch 118, CIFAR-10 Batch 2:  Cost:     0.9495 Valid Accuracy: 0.664
# Epoch 118, CIFAR-10 Batch 3:  Cost:     0.9133 Valid Accuracy: 0.678
# Epoch 118, CIFAR-10 Batch 4:  Cost:     0.9437 Valid Accuracy: 0.665
# Epoch 118, CIFAR-10 Batch 5:  Cost:     0.9427 Valid Accuracy: 0.665
# Epoch 119, CIFAR-10 Batch 1:  Cost:     0.9020 Valid Accuracy: 0.682
# Epoch 119, CIFAR-10 Batch 2:  Cost:     0.9313 Valid Accuracy: 0.67
# Epoch 119, CIFAR-10 Batch 3:  Cost:     0.9368 Valid Accuracy: 0.663
# Epoch 119, CIFAR-10 Batch 4:  Cost:     0.9220 Valid Accuracy: 0.676
# Epoch 119, CIFAR-10 Batch 5:  Cost:     0.9564 Valid Accuracy: 0.658
# Epoch 120, CIFAR-10 Batch 1:  Cost:     0.9684 Valid Accuracy: 0.652
# Epoch 120, CIFAR-10 Batch 2:  Cost:     1.0024 Valid Accuracy: 0.648
# Epoch 120, CIFAR-10 Batch 3:  Cost:     0.9335 Valid Accuracy: 0.672
# Epoch 120, CIFAR-10 Batch 4:  Cost:     0.9822 Valid Accuracy: 0.65
# Epoch 120, CIFAR-10 Batch 5:  Cost:     0.9505 Valid Accuracy: 0.662
# Epoch 121, CIFAR-10 Batch 1:  Cost:     1.1040 Valid Accuracy: 0.621
# Epoch 121, CIFAR-10 Batch 2:  Cost:     1.2442 Valid Accuracy: 0.591
# Epoch 121, CIFAR-10 Batch 3:  Cost:     1.1756 Valid Accuracy: 0.581
# Epoch 121, CIFAR-10 Batch 4:  Cost:     1.1087 Valid Accuracy: 0.602
# Epoch 121, CIFAR-10 Batch 5:  Cost:     1.2011 Valid Accuracy: 0.591
# Epoch 122, CIFAR-10 Batch 1:  Cost:     1.0065 Valid Accuracy: 0.64
# Epoch 122, CIFAR-10 Batch 2:  Cost:     1.0158 Valid Accuracy: 0.634
# Epoch 122, CIFAR-10 Batch 3:  Cost:     1.1121 Valid Accuracy: 0.596
# Epoch 122, CIFAR-10 Batch 4:  Cost:     1.0338 Valid Accuracy: 0.632
# Epoch 122, CIFAR-10 Batch 5:  Cost:     1.0135 Valid Accuracy: 0.643
# Epoch 123, CIFAR-10 Batch 1:  Cost:     1.0078 Valid Accuracy: 0.642
# Epoch 123, CIFAR-10 Batch 2:  Cost:     1.0385 Valid Accuracy: 0.631
# Epoch 123, CIFAR-10 Batch 3:  Cost:     0.9902 Valid Accuracy: 0.646
# Epoch 123, CIFAR-10 Batch 4:  Cost:     1.0035 Valid Accuracy: 0.643
# Epoch 123, CIFAR-10 Batch 5:  Cost:     0.9711 Valid Accuracy: 0.657
# Epoch 124, CIFAR-10 Batch 1:  Cost:     0.9629 Valid Accuracy: 0.663
# Epoch 124, CIFAR-10 Batch 2:  Cost:     0.9805 Valid Accuracy: 0.654
# Epoch 124, CIFAR-10 Batch 3:  Cost:     0.9589 Valid Accuracy: 0.659
# Epoch 124, CIFAR-10 Batch 4:  Cost:     0.9618 Valid Accuracy: 0.658
# Epoch 124, CIFAR-10 Batch 5:  Cost:     0.9571 Valid Accuracy: 0.663
# Epoch 125, CIFAR-10 Batch 1:  Cost:     0.9282 Valid Accuracy: 0.675
# Epoch 125, CIFAR-10 Batch 2:  Cost:     0.9645 Valid Accuracy: 0.659
# Epoch 125, CIFAR-10 Batch 3:  Cost:     0.9240 Valid Accuracy: 0.672
# Epoch 125, CIFAR-10 Batch 4:  Cost:     0.9452 Valid Accuracy: 0.665
# Epoch 125, CIFAR-10 Batch 5:  Cost:     0.9209 Valid Accuracy: 0.681
# Epoch 126, CIFAR-10 Batch 1:  Cost:     0.9197 Valid Accuracy: 0.68
# Epoch 126, CIFAR-10 Batch 2:  Cost:     0.9263 Valid Accuracy: 0.676
# Epoch 126, CIFAR-10 Batch 3:  Cost:     0.9055 Valid Accuracy: 0.682
# Epoch 126, CIFAR-10 Batch 4:  Cost:     0.9233 Valid Accuracy: 0.676
# Epoch 126, CIFAR-10 Batch 5:  Cost:     0.9106 Valid Accuracy: 0.68
# Epoch 127, CIFAR-10 Batch 1:  Cost:     0.8911 Valid Accuracy: 0.689
# Epoch 127, CIFAR-10 Batch 2:  Cost:     0.9202 Valid Accuracy: 0.677
# Epoch 127, CIFAR-10 Batch 3:  Cost:     0.8942 Valid Accuracy: 0.684
# Epoch 127, CIFAR-10 Batch 4:  Cost:     0.9144 Valid Accuracy: 0.678
# Epoch 127, CIFAR-10 Batch 5:  Cost:     0.9023 Valid Accuracy: 0.687
# Epoch 128, CIFAR-10 Batch 1:  Cost:     0.8863 Valid Accuracy: 0.689
# Epoch 128, CIFAR-10 Batch 2:  Cost:     0.9097 Valid Accuracy: 0.678
# Epoch 128, CIFAR-10 Batch 3:  Cost:     0.8939 Valid Accuracy: 0.685
# Epoch 128, CIFAR-10 Batch 4:  Cost:     0.9292 Valid Accuracy: 0.669
# Epoch 128, CIFAR-10 Batch 5:  Cost:     0.9066 Valid Accuracy: 0.684
# Epoch 129, CIFAR-10 Batch 1:  Cost:     0.8796 Valid Accuracy: 0.694
# Epoch 129, CIFAR-10 Batch 2:  Cost:     0.9182 Valid Accuracy: 0.676
# Epoch 129, CIFAR-10 Batch 3:  Cost:     0.9212 Valid Accuracy: 0.678
# Epoch 129, CIFAR-10 Batch 4:  Cost:     0.9216 Valid Accuracy: 0.67
# Epoch 129, CIFAR-10 Batch 5:  Cost:     0.8887 Valid Accuracy: 0.689
# Epoch 130, CIFAR-10 Batch 1:  Cost:     0.9091 Valid Accuracy: 0.682
# Epoch 130, CIFAR-10 Batch 2:  Cost:     0.9162 Valid Accuracy: 0.672
# Epoch 130, CIFAR-10 Batch 3:  Cost:     0.8820 Valid Accuracy: 0.692
# Epoch 130, CIFAR-10 Batch 4:  Cost:     0.9325 Valid Accuracy: 0.669
# Epoch 130, CIFAR-10 Batch 5:  Cost:     0.8937 Valid Accuracy: 0.685
# Epoch 131, CIFAR-10 Batch 1:  Cost:     0.8781 Valid Accuracy: 0.694
# Epoch 131, CIFAR-10 Batch 2:  Cost:     0.9104 Valid Accuracy: 0.679
# Epoch 131, CIFAR-10 Batch 3:  Cost:     0.8740 Valid Accuracy: 0.692
# Epoch 131, CIFAR-10 Batch 4:  Cost:     0.8887 Valid Accuracy: 0.688
# Epoch 131, CIFAR-10 Batch 5:  Cost:     0.8816 Valid Accuracy: 0.69
# Epoch 132, CIFAR-10 Batch 1:  Cost:     0.8802 Valid Accuracy: 0.695
# Epoch 132, CIFAR-10 Batch 2:  Cost:     0.8873 Valid Accuracy: 0.688
# Epoch 132, CIFAR-10 Batch 3:  Cost:     0.8643 Valid Accuracy: 0.702
# Epoch 132, CIFAR-10 Batch 4:  Cost:     0.8812 Valid Accuracy: 0.693
# Epoch 132, CIFAR-10 Batch 5:  Cost:     0.8799 Valid Accuracy: 0.689
# Epoch 133, CIFAR-10 Batch 1:  Cost:     0.8700 Valid Accuracy: 0.695
# Epoch 133, CIFAR-10 Batch 2:  Cost:     0.8831 Valid Accuracy: 0.691
# Epoch 133, CIFAR-10 Batch 3:  Cost:     0.8702 Valid Accuracy: 0.693
# Epoch 133, CIFAR-10 Batch 4:  Cost:     0.8898 Valid Accuracy: 0.687
# Epoch 133, CIFAR-10 Batch 5:  Cost:     0.8720 Valid Accuracy: 0.695
# Epoch 134, CIFAR-10 Batch 1:  Cost:     0.8675 Valid Accuracy: 0.694
# Epoch 134, CIFAR-10 Batch 2:  Cost:     0.8801 Valid Accuracy: 0.692
# Epoch 134, CIFAR-10 Batch 3:  Cost:     0.8592 Valid Accuracy: 0.7
# Epoch 134, CIFAR-10 Batch 4:  Cost:     0.8793 Valid Accuracy: 0.69
# Epoch 134, CIFAR-10 Batch 5:  Cost:     0.8714 Valid Accuracy: 0.698
# Epoch 135, CIFAR-10 Batch 1:  Cost:     0.8558 Valid Accuracy: 0.701
# Epoch 135, CIFAR-10 Batch 2:  Cost:     0.8660 Valid Accuracy: 0.697
# Epoch 135, CIFAR-10 Batch 3:  Cost:     0.8525 Valid Accuracy: 0.702
# Epoch 135, CIFAR-10 Batch 4:  Cost:     0.8652 Valid Accuracy: 0.693
# Epoch 135, CIFAR-10 Batch 5:  Cost:     0.8730 Valid Accuracy: 0.695
# Epoch 136, CIFAR-10 Batch 1:  Cost:     0.8785 Valid Accuracy: 0.697
# Epoch 136, CIFAR-10 Batch 2:  Cost:     0.8890 Valid Accuracy: 0.685
# Epoch 136, CIFAR-10 Batch 3:  Cost:     0.8650 Valid Accuracy: 0.697
# Epoch 136, CIFAR-10 Batch 4:  Cost:     0.9121 Valid Accuracy: 0.682
# Epoch 136, CIFAR-10 Batch 5:  Cost:     0.8969 Valid Accuracy: 0.687
# Epoch 137, CIFAR-10 Batch 1:  Cost:     0.8522 Valid Accuracy: 0.7
# Epoch 137, CIFAR-10 Batch 2:  Cost:     0.8694 Valid Accuracy: 0.693
# Epoch 137, CIFAR-10 Batch 3:  Cost:     0.8555 Valid Accuracy: 0.703
# Epoch 137, CIFAR-10 Batch 4:  Cost:     0.8831 Valid Accuracy: 0.686
# Epoch 137, CIFAR-10 Batch 5:  Cost:     0.8642 Valid Accuracy: 0.7
# Epoch 138, CIFAR-10 Batch 1:  Cost:     0.8481 Valid Accuracy: 0.702
# Epoch 138, CIFAR-10 Batch 2:  Cost:     0.8693 Valid Accuracy: 0.696
# Epoch 138, CIFAR-10 Batch 3:  Cost:     0.8786 Valid Accuracy: 0.696
# Epoch 138, CIFAR-10 Batch 4:  Cost:     0.8826 Valid Accuracy: 0.685
# Epoch 138, CIFAR-10 Batch 5:  Cost:     0.8738 Valid Accuracy: 0.697
# Epoch 139, CIFAR-10 Batch 1:  Cost:     0.8737 Valid Accuracy: 0.697
# Epoch 139, CIFAR-10 Batch 2:  Cost:     0.8890 Valid Accuracy: 0.686
# Epoch 139, CIFAR-10 Batch 3:  Cost:     0.8660 Valid Accuracy: 0.691
# Epoch 139, CIFAR-10 Batch 4:  Cost:     0.8873 Valid Accuracy: 0.691
# Epoch 139, CIFAR-10 Batch 5:  Cost:     0.9119 Valid Accuracy: 0.679
# Epoch 140, CIFAR-10 Batch 1:  Cost:     0.9085 Valid Accuracy: 0.684
# Epoch 140, CIFAR-10 Batch 2:  Cost:     0.9338 Valid Accuracy: 0.665
# Epoch 140, CIFAR-10 Batch 3:  Cost:     0.9061 Valid Accuracy: 0.676
# Epoch 140, CIFAR-10 Batch 4:  Cost:     0.8858 Valid Accuracy: 0.687
# Epoch 140, CIFAR-10 Batch 5:  Cost:     0.9310 Valid Accuracy: 0.672
# Epoch 141, CIFAR-10 Batch 1:  Cost:     0.8879 Valid Accuracy: 0.684
# Epoch 141, CIFAR-10 Batch 2:  Cost:     0.8916 Valid Accuracy: 0.681
# Epoch 141, CIFAR-10 Batch 3:  Cost:     0.8866 Valid Accuracy: 0.685
# Epoch 141, CIFAR-10 Batch 4:  Cost:     0.8701 Valid Accuracy: 0.694
# Epoch 141, CIFAR-10 Batch 5:  Cost:     0.8850 Valid Accuracy: 0.688
# Epoch 142, CIFAR-10 Batch 1:  Cost:     0.8438 Valid Accuracy: 0.706
# Epoch 142, CIFAR-10 Batch 2:  Cost:     0.8645 Valid Accuracy: 0.7
# Epoch 142, CIFAR-10 Batch 3:  Cost:     0.8651 Valid Accuracy: 0.693
# Epoch 142, CIFAR-10 Batch 4:  Cost:     0.8880 Valid Accuracy: 0.682
# Epoch 142, CIFAR-10 Batch 5:  Cost:     0.9014 Valid Accuracy: 0.676
# Epoch 143, CIFAR-10 Batch 1:  Cost:     0.8848 Valid Accuracy: 0.69
# Epoch 143, CIFAR-10 Batch 2:  Cost:     0.9800 Valid Accuracy: 0.648
# Epoch 143, CIFAR-10 Batch 3:  Cost:     1.0536 Valid Accuracy: 0.645
# Epoch 143, CIFAR-10 Batch 4:  Cost:     1.0354 Valid Accuracy: 0.641
# Epoch 143, CIFAR-10 Batch 5:  Cost:     1.2969 Valid Accuracy: 0.57
# Epoch 144, CIFAR-10 Batch 1:  Cost:     1.7514 Valid Accuracy: 0.539
# Epoch 144, CIFAR-10 Batch 2:  Cost:     1.6279 Valid Accuracy: 0.536
# Epoch 144, CIFAR-10 Batch 3:  Cost:     1.7425 Valid Accuracy: 0.452
# Epoch 144, CIFAR-10 Batch 4:  Cost:     1.7424 Valid Accuracy: 0.485
# Epoch 144, CIFAR-10 Batch 5:  Cost:     1.5649 Valid Accuracy: 0.564
# Epoch 145, CIFAR-10 Batch 1:  Cost:     1.6507 Valid Accuracy: 0.516
# Epoch 145, CIFAR-10 Batch 2:  Cost:     1.5974 Valid Accuracy: 0.493
# Epoch 145, CIFAR-10 Batch 3:  Cost:     1.2927 Valid Accuracy: 0.55
# Epoch 145, CIFAR-10 Batch 4:  Cost:     1.2938 Valid Accuracy: 0.548
# Epoch 145, CIFAR-10 Batch 5:  Cost:     1.2519 Valid Accuracy: 0.556
# Epoch 146, CIFAR-10 Batch 1:  Cost:     1.2883 Valid Accuracy: 0.52
# Epoch 146, CIFAR-10 Batch 2:  Cost:     1.2478 Valid Accuracy: 0.546
# Epoch 146, CIFAR-10 Batch 3:  Cost:     1.2061 Valid Accuracy: 0.547
# Epoch 146, CIFAR-10 Batch 4:  Cost:     1.2741 Valid Accuracy: 0.522
# Epoch 146, CIFAR-10 Batch 5:  Cost:     1.1809 Valid Accuracy: 0.58
# Epoch 147, CIFAR-10 Batch 1:  Cost:     1.1616 Valid Accuracy: 0.582
# Epoch 147, CIFAR-10 Batch 2:  Cost:     1.2110 Valid Accuracy: 0.55
# Epoch 147, CIFAR-10 Batch 3:  Cost:     1.1665 Valid Accuracy: 0.574
# Epoch 147, CIFAR-10 Batch 4:  Cost:     1.1493 Valid Accuracy: 0.587
# Epoch 147, CIFAR-10 Batch 5:  Cost:     1.1418 Valid Accuracy: 0.598
# Epoch 148, CIFAR-10 Batch 1:  Cost:     1.1193 Valid Accuracy: 0.599
# Epoch 148, CIFAR-10 Batch 2:  Cost:     1.1363 Valid Accuracy: 0.588
# Epoch 148, CIFAR-10 Batch 3:  Cost:     1.0824 Valid Accuracy: 0.616
# Epoch 148, CIFAR-10 Batch 4:  Cost:     1.0937 Valid Accuracy: 0.61
# Epoch 148, CIFAR-10 Batch 5:  Cost:     1.0984 Valid Accuracy: 0.613
# Epoch 149, CIFAR-10 Batch 1:  Cost:     1.0620 Valid Accuracy: 0.623
# Epoch 149, CIFAR-10 Batch 2:  Cost:     1.0760 Valid Accuracy: 0.62
# Epoch 149, CIFAR-10 Batch 3:  Cost:     1.0382 Valid Accuracy: 0.626
# Epoch 149, CIFAR-10 Batch 4:  Cost:     1.0555 Valid Accuracy: 0.619
# Epoch 149, CIFAR-10 Batch 5:  Cost:     1.0516 Valid Accuracy: 0.623
# Epoch 150, CIFAR-10 Batch 1:  Cost:     1.0170 Valid Accuracy: 0.638
# Epoch 150, CIFAR-10 Batch 2:  Cost:     1.0273 Valid Accuracy: 0.634
# Epoch 150, CIFAR-10 Batch 3:  Cost:     1.0032 Valid Accuracy: 0.639
# Epoch 150, CIFAR-10 Batch 4:  Cost:     1.0131 Valid Accuracy: 0.638
# Epoch 150, CIFAR-10 Batch 5:  Cost:     1.0101 Valid Accuracy: 0.645
# Epoch 151, CIFAR-10 Batch 1:  Cost:     0.9783 Valid Accuracy: 0.652
# Epoch 151, CIFAR-10 Batch 2:  Cost:     0.9994 Valid Accuracy: 0.648
# Epoch 151, CIFAR-10 Batch 3:  Cost:     0.9648 Valid Accuracy: 0.656
# Epoch 151, CIFAR-10 Batch 4:  Cost:     0.9780 Valid Accuracy: 0.65
# Epoch 151, CIFAR-10 Batch 5:  Cost:     0.9793 Valid Accuracy: 0.653
# Epoch 152, CIFAR-10 Batch 1:  Cost:     0.9528 Valid Accuracy: 0.662
# Epoch 152, CIFAR-10 Batch 2:  Cost:     0.9725 Valid Accuracy: 0.661
# Epoch 152, CIFAR-10 Batch 3:  Cost:     0.9349 Valid Accuracy: 0.664
# Epoch 152, CIFAR-10 Batch 4:  Cost:     0.9581 Valid Accuracy: 0.657
# Epoch 152, CIFAR-10 Batch 5:  Cost:     0.9553 Valid Accuracy: 0.663
# Epoch 153, CIFAR-10 Batch 1:  Cost:     0.9325 Valid Accuracy: 0.67
# Epoch 153, CIFAR-10 Batch 2:  Cost:     0.9450 Valid Accuracy: 0.67
# Epoch 153, CIFAR-10 Batch 3:  Cost:     0.9208 Valid Accuracy: 0.673
# Epoch 153, CIFAR-10 Batch 4:  Cost:     0.9330 Valid Accuracy: 0.672
# Epoch 153, CIFAR-10 Batch 5:  Cost:     0.9338 Valid Accuracy: 0.673
# Epoch 154, CIFAR-10 Batch 1:  Cost:     0.9129 Valid Accuracy: 0.68
# Epoch 154, CIFAR-10 Batch 2:  Cost:     0.9297 Valid Accuracy: 0.677
# Epoch 154, CIFAR-10 Batch 3:  Cost:     0.9010 Valid Accuracy: 0.676
# Epoch 154, CIFAR-10 Batch 4:  Cost:     0.9166 Valid Accuracy: 0.678
# Epoch 154, CIFAR-10 Batch 5:  Cost:     0.9184 Valid Accuracy: 0.679
# Epoch 155, CIFAR-10 Batch 1:  Cost:     0.9017 Valid Accuracy: 0.683
# Epoch 155, CIFAR-10 Batch 2:  Cost:     0.9185 Valid Accuracy: 0.681
# Epoch 155, CIFAR-10 Batch 3:  Cost:     0.8866 Valid Accuracy: 0.686
# Epoch 155, CIFAR-10 Batch 4:  Cost:     0.9038 Valid Accuracy: 0.681
# Epoch 155, CIFAR-10 Batch 5:  Cost:     0.9050 Valid Accuracy: 0.683
# Epoch 156, CIFAR-10 Batch 1:  Cost:     0.8965 Valid Accuracy: 0.683
# Epoch 156, CIFAR-10 Batch 2:  Cost:     0.9123 Valid Accuracy: 0.683
# Epoch 156, CIFAR-10 Batch 3:  Cost:     0.8804 Valid Accuracy: 0.688
# Epoch 156, CIFAR-10 Batch 4:  Cost:     0.8930 Valid Accuracy: 0.688
# Epoch 156, CIFAR-10 Batch 5:  Cost:     0.8963 Valid Accuracy: 0.686
# Epoch 157, CIFAR-10 Batch 1:  Cost:     0.8907 Valid Accuracy: 0.69
# Epoch 157, CIFAR-10 Batch 2:  Cost:     0.9014 Valid Accuracy: 0.687
# ...
# Epoch 204, CIFAR-10 Batch 5:  Cost:     0.8667 Valid Accuracy: 0.69
# Epoch 205, CIFAR-10 Batch 1:  Cost:     0.8585 Valid Accuracy: 0.696
# Epoch 205, CIFAR-10 Batch 2:  Cost:     0.9113 Valid Accuracy: 0.68
# Epoch 205, CIFAR-10 Batch 3:  Cost:     0.8424 Valid Accuracy: 0.7
# Epoch 205, CIFAR-10 Batch 4:  Cost:     0.8203 Valid Accuracy: 0.709
# Epoch 205, CIFAR-10 Batch 5:  Cost:     0.8933 Valid Accuracy: 0.693
# Epoch 206, CIFAR-10 Batch 1:  Cost:     0.8650 Valid Accuracy: 0.7
# Epoch 206, CIFAR-10 Batch 2:  Cost:     0.8781 Valid Accuracy: 0.68
# Epoch 206, CIFAR-10 Batch 3:  Cost:     0.8158 Valid Accuracy: 0.712
# Epoch 206, CIFAR-10 Batch 4:  Cost:     0.8643 Valid Accuracy: 0.687
# Epoch 206, CIFAR-10 Batch 5:  Cost:     0.8719 Valid Accuracy: 0.689
# Epoch 207, CIFAR-10 Batch 1:  Cost:     0.8236 Valid Accuracy: 0.708
# Epoch 207, CIFAR-10 Batch 2:  Cost:     0.8921 Valid Accuracy: 0.681
# Epoch 207, CIFAR-10 Batch 3:  Cost:     0.8132 Valid Accuracy: 0.713
# Epoch 207, CIFAR-10 Batch 4:  Cost:     0.8539 Valid Accuracy: 0.693
# Epoch 207, CIFAR-10 Batch 5:  Cost:     0.8476 Valid Accuracy: 0.697
# Epoch 208, CIFAR-10 Batch 1:  Cost:     0.8150 Valid Accuracy: 0.705
# Epoch 208, CIFAR-10 Batch 2:  Cost:     0.8244 Valid Accuracy: 0.702
# Epoch 208, CIFAR-10 Batch 3:  Cost:     0.8042 Valid Accuracy: 0.72
# Epoch 208, CIFAR-10 Batch 4:  Cost:     0.8165 Valid Accuracy: 0.713
# Epoch 208, CIFAR-10 Batch 5:  Cost:     0.8099 Valid Accuracy: 0.717
# Epoch 209, CIFAR-10 Batch 1:  Cost:     0.8057 Valid Accuracy: 0.715
# Epoch 209, CIFAR-10 Batch 2:  Cost:     0.7971 Valid Accuracy: 0.721
# Epoch 209, CIFAR-10 Batch 3:  Cost:     0.7886 Valid Accuracy: 0.727
# Epoch 209, CIFAR-10 Batch 4:  Cost:     0.7986 Valid Accuracy: 0.719
# Epoch 209, CIFAR-10 Batch 5:  Cost:     0.7975 Valid Accuracy: 0.723
# Epoch 210, CIFAR-10 Batch 1:  Cost:     0.7774 Valid Accuracy: 0.732
# Epoch 210, CIFAR-10 Batch 2:  Cost:     0.7921 Valid Accuracy: 0.725
# Epoch 210, CIFAR-10 Batch 3:  Cost:     0.7814 Valid Accuracy: 0.725
# Epoch 210, CIFAR-10 Batch 4:  Cost:     0.8034 Valid Accuracy: 0.71
# Epoch 210, CIFAR-10 Batch 5:  Cost:     0.7960 Valid Accuracy: 0.721
# Epoch 211, CIFAR-10 Batch 1:  Cost:     0.7845 Valid Accuracy: 0.725
# Epoch 211, CIFAR-10 Batch 2:  Cost:     0.7745 Valid Accuracy: 0.73
# Epoch 211, CIFAR-10 Batch 3:  Cost:     0.7705 Valid Accuracy: 0.727
# Epoch 211, CIFAR-10 Batch 4:  Cost:     0.8054 Valid Accuracy: 0.713
# Epoch 211, CIFAR-10 Batch 5:  Cost:     0.8331 Valid Accuracy: 0.71
# Epoch 212, CIFAR-10 Batch 1:  Cost:     0.7903 Valid Accuracy: 0.721
# Epoch 212, CIFAR-10 Batch 2:  Cost:     0.7671 Valid Accuracy: 0.729
# Epoch 212, CIFAR-10 Batch 3:  Cost:     0.8029 Valid Accuracy: 0.715
# Epoch 212, CIFAR-10 Batch 4:  Cost:     0.8476 Valid Accuracy: 0.698
# Epoch 212, CIFAR-10 Batch 5:  Cost:     0.8146 Valid Accuracy: 0.714
# Epoch 213, CIFAR-10 Batch 1:  Cost:     0.7793 Valid Accuracy: 0.726
# Epoch 213, CIFAR-10 Batch 2:  Cost:     0.8108 Valid Accuracy: 0.708
# Epoch 213, CIFAR-10 Batch 3:  Cost:     0.8228 Valid Accuracy: 0.706
# Epoch 213, CIFAR-10 Batch 4:  Cost:     0.7969 Valid Accuracy: 0.721
# Epoch 213, CIFAR-10 Batch 5:  Cost:     0.8165 Valid Accuracy: 0.709
# Epoch 214, CIFAR-10 Batch 1:  Cost:     0.7929 Valid Accuracy: 0.719
# Epoch 214, CIFAR-10 Batch 2:  Cost:     0.7817 Valid Accuracy: 0.726
# Epoch 214, CIFAR-10 Batch 3:  Cost:     0.8006 Valid Accuracy: 0.715
# Epoch 214, CIFAR-10 Batch 4:  Cost:     0.7998 Valid Accuracy: 0.721
# Epoch 214, CIFAR-10 Batch 5:  Cost:     0.7984 Valid Accuracy: 0.721
# Epoch 215, CIFAR-10 Batch 1:  Cost:     0.7874 Valid Accuracy: 0.727
# Epoch 215, CIFAR-10 Batch 2:  Cost:     0.8054 Valid Accuracy: 0.715
# Epoch 215, CIFAR-10 Batch 3:  Cost:     0.7858 Valid Accuracy: 0.728
# Epoch 215, CIFAR-10 Batch 4:  Cost:     0.7947 Valid Accuracy: 0.721
# Epoch 215, CIFAR-10 Batch 5:  Cost:     0.8198 Valid Accuracy: 0.712
# Epoch 216, CIFAR-10 Batch 1:  Cost:     0.8089 Valid Accuracy: 0.712
# Epoch 216, CIFAR-10 Batch 2:  Cost:     0.7899 Valid Accuracy: 0.717
# Epoch 216, CIFAR-10 Batch 3:  Cost:     0.8148 Valid Accuracy: 0.707
# Epoch 216, CIFAR-10 Batch 4:  Cost:     0.8171 Valid Accuracy: 0.708
# Epoch 216, CIFAR-10 Batch 5:  Cost:     0.7942 Valid Accuracy: 0.719
# Epoch 217, CIFAR-10 Batch 1:  Cost:     0.8250 Valid Accuracy: 0.711
# Epoch 217, CIFAR-10 Batch 2:  Cost:     0.7930 Valid Accuracy: 0.718
# Epoch 217, CIFAR-10 Batch 3:  Cost:     0.8110 Valid Accuracy: 0.712
# Epoch 217, CIFAR-10 Batch 4:  Cost:     0.8001 Valid Accuracy: 0.719
# Epoch 217, CIFAR-10 Batch 5:  Cost:     0.7787 Valid Accuracy: 0.727
# Epoch 218, CIFAR-10 Batch 1:  Cost:     0.8317 Valid Accuracy: 0.706
# Epoch 218, CIFAR-10 Batch 2:  Cost:     0.8853 Valid Accuracy: 0.687
# Epoch 218, CIFAR-10 Batch 3:  Cost:     0.8333 Valid Accuracy: 0.705
# Epoch 218, CIFAR-10 Batch 4:  Cost:     0.8438 Valid Accuracy: 0.705
# Epoch 218, CIFAR-10 Batch 5:  Cost:     0.8575 Valid Accuracy: 0.689
# Epoch 219, CIFAR-10 Batch 1:  Cost:     0.9154 Valid Accuracy: 0.681
# Epoch 219, CIFAR-10 Batch 2:  Cost:     0.8678 Valid Accuracy: 0.689
# Epoch 219, CIFAR-10 Batch 3:  Cost:     0.9025 Valid Accuracy: 0.678
# Epoch 219, CIFAR-10 Batch 4:  Cost:     0.8296 Valid Accuracy: 0.706
# Epoch 219, CIFAR-10 Batch 5:  Cost:     0.8851 Valid Accuracy: 0.684
# Epoch 220, CIFAR-10 Batch 1:  Cost:     0.9165 Valid Accuracy: 0.683
# Epoch 220, CIFAR-10 Batch 2:  Cost:     0.9005 Valid Accuracy: 0.678
# Epoch 220, CIFAR-10 Batch 3:  Cost:     0.8976 Valid Accuracy: 0.68
# Epoch 220, CIFAR-10 Batch 4:  Cost:     0.8519 Valid Accuracy: 0.702
# Epoch 220, CIFAR-10 Batch 5:  Cost:     0.8899 Valid Accuracy: 0.678
# Epoch 221, CIFAR-10 Batch 1:  Cost:     0.8463 Valid Accuracy: 0.696
# Epoch 221, CIFAR-10 Batch 2:  Cost:     0.9115 Valid Accuracy: 0.669
# Epoch 221, CIFAR-10 Batch 3:  Cost:     0.8664 Valid Accuracy: 0.68
# Epoch 221, CIFAR-10 Batch 4:  Cost:     0.8530 Valid Accuracy: 0.694
# Epoch 221, CIFAR-10 Batch 5:  Cost:     0.8949 Valid Accuracy: 0.679
# Epoch 222, CIFAR-10 Batch 1:  Cost:     0.8077 Valid Accuracy: 0.713
# Epoch 222, CIFAR-10 Batch 2:  Cost:     0.8648 Valid Accuracy: 0.691
# Epoch 222, CIFAR-10 Batch 3:  Cost:     0.8515 Valid Accuracy: 0.695
# Epoch 222, CIFAR-10 Batch 4:  Cost:     0.8198 Valid Accuracy: 0.707
# Epoch 222, CIFAR-10 Batch 5:  Cost:     0.8220 Valid Accuracy: 0.711
# Epoch 223, CIFAR-10 Batch 1:  Cost:     0.8196 Valid Accuracy: 0.715
# Epoch 223, CIFAR-10 Batch 2:  Cost:     0.8093 Valid Accuracy: 0.718
# Epoch 223, CIFAR-10 Batch 3:  Cost:     0.7854 Valid Accuracy: 0.723
# Epoch 223, CIFAR-10 Batch 4:  Cost:     0.8164 Valid Accuracy: 0.709
# Epoch 223, CIFAR-10 Batch 5:  Cost:     0.8115 Valid Accuracy: 0.712
# Epoch 224, CIFAR-10 Batch 1:  Cost:     0.7806 Valid Accuracy: 0.727
# Epoch 224, CIFAR-10 Batch 2:  Cost:     0.7905 Valid Accuracy: 0.719
# Epoch 224, CIFAR-10 Batch 3:  Cost:     0.7921 Valid Accuracy: 0.719
# Epoch 224, CIFAR-10 Batch 4:  Cost:     0.7829 Valid Accuracy: 0.726
# Epoch 224, CIFAR-10 Batch 5:  Cost:     0.7997 Valid Accuracy: 0.719
# Epoch 225, CIFAR-10 Batch 1:  Cost:     0.7643 Valid Accuracy: 0.736
# Epoch 225, CIFAR-10 Batch 2:  Cost:     0.7894 Valid Accuracy: 0.722
# Epoch 225, CIFAR-10 Batch 3:  Cost:     0.7604 Valid Accuracy: 0.734
# Epoch 225, CIFAR-10 Batch 4:  Cost:     0.7832 Valid Accuracy: 0.722
# Epoch 225, CIFAR-10 Batch 5:  Cost:     0.7696 Valid Accuracy: 0.732
# Epoch 226, CIFAR-10 Batch 1:  Cost:     0.7612 Valid Accuracy: 0.734
# Epoch 226, CIFAR-10 Batch 2:  Cost:     0.7761 Valid Accuracy: 0.729
# Epoch 226, CIFAR-10 Batch 3:  Cost:     0.7550 Valid Accuracy: 0.738
# Epoch 226, CIFAR-10 Batch 4:  Cost:     0.7871 Valid Accuracy: 0.724
# Epoch 226, CIFAR-10 Batch 5:  Cost:     0.7630 Valid Accuracy: 0.73
# Epoch 227, CIFAR-10 Batch 1:  Cost:     0.7579 Valid Accuracy: 0.737
# Epoch 227, CIFAR-10 Batch 2:  Cost:     0.7644 Valid Accuracy: 0.731
# Epoch 227, CIFAR-10 Batch 3:  Cost:     0.7578 Valid Accuracy: 0.737
# Epoch 227, CIFAR-10 Batch 4:  Cost:     0.7747 Valid Accuracy: 0.725
# Epoch 227, CIFAR-10 Batch 5:  Cost:     0.7567 Valid Accuracy: 0.734
# Epoch 228, CIFAR-10 Batch 1:  Cost:     0.7579 Valid Accuracy: 0.74
# Epoch 228, CIFAR-10 Batch 2:  Cost:     0.7666 Valid Accuracy: 0.73
# Epoch 228, CIFAR-10 Batch 3:  Cost:     0.7600 Valid Accuracy: 0.734
# Epoch 228, CIFAR-10 Batch 4:  Cost:     0.7661 Valid Accuracy: 0.729
# Epoch 228, CIFAR-10 Batch 5:  Cost:     0.7517 Valid Accuracy: 0.737
# Epoch 229, CIFAR-10 Batch 1:  Cost:     0.7560 Valid Accuracy: 0.738
# Epoch 229, CIFAR-10 Batch 2:  Cost:     0.7607 Valid Accuracy: 0.732
# Epoch 229, CIFAR-10 Batch 3:  Cost:     0.7464 Valid Accuracy: 0.738
# Epoch 229, CIFAR-10 Batch 4:  Cost:     0.7560 Valid Accuracy: 0.736
# Epoch 229, CIFAR-10 Batch 5:  Cost:     0.7553 Valid Accuracy: 0.737
# Epoch 230, CIFAR-10 Batch 1:  Cost:     0.7788 Valid Accuracy: 0.728
# Epoch 230, CIFAR-10 Batch 2:  Cost:     0.7611 Valid Accuracy: 0.731
# Epoch 230, CIFAR-10 Batch 3:  Cost:     0.7361 Valid Accuracy: 0.744
# Epoch 230, CIFAR-10 Batch 4:  Cost:     0.7578 Valid Accuracy: 0.736
# Epoch 230, CIFAR-10 Batch 5:  Cost:     0.7748 Valid Accuracy: 0.726
# Epoch 231, CIFAR-10 Batch 1:  Cost:     0.7586 Valid Accuracy: 0.739
# Epoch 231, CIFAR-10 Batch 2:  Cost:     0.7478 Valid Accuracy: 0.737
# Epoch 231, CIFAR-10 Batch 3:  Cost:     0.7580 Valid Accuracy: 0.73
# Epoch 231, CIFAR-10 Batch 4:  Cost:     0.7755 Valid Accuracy: 0.728
# Epoch 231, CIFAR-10 Batch 5:  Cost:     0.7616 Valid Accuracy: 0.735
# Epoch 232, CIFAR-10 Batch 1:  Cost:     0.7911 Valid Accuracy: 0.726
# Epoch 232, CIFAR-10 Batch 2:  Cost:     0.7818 Valid Accuracy: 0.724
# Epoch 232, CIFAR-10 Batch 3:  Cost:     0.7768 Valid Accuracy: 0.723
# Epoch 232, CIFAR-10 Batch 4:  Cost:     0.7880 Valid Accuracy: 0.719
# Epoch 232, CIFAR-10 Batch 5:  Cost:     0.7761 Valid Accuracy: 0.725
# Epoch 233, CIFAR-10 Batch 1:  Cost:     0.8067 Valid Accuracy: 0.716
# Epoch 233, CIFAR-10 Batch 2:  Cost:     0.7586 Valid Accuracy: 0.731
# Epoch 233, CIFAR-10 Batch 3:  Cost:     0.7863 Valid Accuracy: 0.727
# Epoch 233, CIFAR-10 Batch 4:  Cost:     0.8162 Valid Accuracy: 0.71
# Epoch 233, CIFAR-10 Batch 5:  Cost:     0.8123 Valid Accuracy: 0.713
# Epoch 234, CIFAR-10 Batch 1:  Cost:     0.9054 Valid Accuracy: 0.677
# Epoch 234, CIFAR-10 Batch 2:  Cost:     0.8099 Valid Accuracy: 0.71
# Epoch 234, CIFAR-10 Batch 3:  Cost:     0.9260 Valid Accuracy: 0.672
# Epoch 234, CIFAR-10 Batch 4:  Cost:     0.8611 Valid Accuracy: 0.693
# Epoch 234, CIFAR-10 Batch 5:  Cost:     0.9643 Valid Accuracy: 0.661
# Epoch 235, CIFAR-10 Batch 1:  Cost:     1.1083 Valid Accuracy: 0.634
# Epoch 235, CIFAR-10 Batch 2:  Cost:     0.9048 Valid Accuracy: 0.68
# Epoch 235, CIFAR-10 Batch 3:  Cost:     1.0268 Valid Accuracy: 0.631
# Epoch 235, CIFAR-10 Batch 4:  Cost:     1.0426 Valid Accuracy: 0.633
# Epoch 235, CIFAR-10 Batch 5:  Cost:     1.1435 Valid Accuracy: 0.624
# Epoch 236, CIFAR-10 Batch 1:  Cost:     1.0744 Valid Accuracy: 0.628
# Epoch 236, CIFAR-10 Batch 2:  Cost:     1.0339 Valid Accuracy: 0.623
# Epoch 236, CIFAR-10 Batch 3:  Cost:     0.8915 Valid Accuracy: 0.678
# Epoch 236, CIFAR-10 Batch 4:  Cost:     0.9809 Valid Accuracy: 0.644
# Epoch 236, CIFAR-10 Batch 5:  Cost:     0.9501 Valid Accuracy: 0.662
# Epoch 237, CIFAR-10 Batch 1:  Cost:     0.8154 Valid Accuracy: 0.713
# Epoch 237, CIFAR-10 Batch 2:  Cost:     0.9327 Valid Accuracy: 0.656
# Epoch 237, CIFAR-10 Batch 3:  Cost:     0.8809 Valid Accuracy: 0.682
# Epoch 237, CIFAR-10 Batch 4:  Cost:     0.8797 Valid Accuracy: 0.684
# Epoch 237, CIFAR-10 Batch 5:  Cost:     0.8413 Valid Accuracy: 0.711
# Epoch 238, CIFAR-10 Batch 1:  Cost:     0.8585 Valid Accuracy: 0.697
# Epoch 238, CIFAR-10 Batch 2:  Cost:     0.8610 Valid Accuracy: 0.689
# Epoch 238, CIFAR-10 Batch 3:  Cost:     0.8451 Valid Accuracy: 0.695
# Epoch 238, CIFAR-10 Batch 4:  Cost:     0.8332 Valid Accuracy: 0.708
# Epoch 238, CIFAR-10 Batch 5:  Cost:     0.8414 Valid Accuracy: 0.706
# Epoch 239, CIFAR-10 Batch 1:  Cost:     0.8116 Valid Accuracy: 0.717
# Epoch 239, CIFAR-10 Batch 2:  Cost:     0.8287 Valid Accuracy: 0.704
# Epoch 239, CIFAR-10 Batch 3:  Cost:     0.8087 Valid Accuracy: 0.716
# Epoch 239, CIFAR-10 Batch 4:  Cost:     0.8223 Valid Accuracy: 0.714
# Epoch 239, CIFAR-10 Batch 5:  Cost:     0.7997 Valid Accuracy: 0.721
# Epoch 240, CIFAR-10 Batch 1:  Cost:     0.8043 Valid Accuracy: 0.715
# Epoch 240, CIFAR-10 Batch 2:  Cost:     0.8003 Valid Accuracy: 0.721
# Epoch 240, CIFAR-10 Batch 3:  Cost:     0.7877 Valid Accuracy: 0.724
# Epoch 240, CIFAR-10 Batch 4:  Cost:     0.7901 Valid Accuracy: 0.722
# Epoch 240, CIFAR-10 Batch 5:  Cost:     0.7959 Valid Accuracy: 0.718
# Epoch 241, CIFAR-10 Batch 1:  Cost:     0.7796 Valid Accuracy: 0.729
# Epoch 241, CIFAR-10 Batch 2:  Cost:     0.7873 Valid Accuracy: 0.725
# Epoch 241, CIFAR-10 Batch 3:  Cost:     0.7674 Valid Accuracy: 0.727
# Epoch 241, CIFAR-10 Batch 4:  Cost:     0.7834 Valid Accuracy: 0.725
# Epoch 241, CIFAR-10 Batch 5:  Cost:     0.7712 Valid Accuracy: 0.729
# Epoch 242, CIFAR-10 Batch 1:  Cost:     0.7696 Valid Accuracy: 0.73
# Epoch 242, CIFAR-10 Batch 2:  Cost:     0.7706 Valid Accuracy: 0.73
# Epoch 242, CIFAR-10 Batch 3:  Cost:     0.7632 Valid Accuracy: 0.732
# Epoch 242, CIFAR-10 Batch 4:  Cost:     0.7644 Valid Accuracy: 0.732
# Epoch 242, CIFAR-10 Batch 5:  Cost:     0.7628 Valid Accuracy: 0.733
# Epoch 243, CIFAR-10 Batch 1:  Cost:     0.7583 Valid Accuracy: 0.734
# Epoch 243, CIFAR-10 Batch 2:  Cost:     0.7546 Valid Accuracy: 0.738
# Epoch 243, CIFAR-10 Batch 3:  Cost:     0.7455 Valid Accuracy: 0.737
# Epoch 243, CIFAR-10 Batch 4:  Cost:     0.7574 Valid Accuracy: 0.737
# Epoch 243, CIFAR-10 Batch 5:  Cost:     0.7533 Valid Accuracy: 0.735
# Epoch 244, CIFAR-10 Batch 1:  Cost:     0.7435 Valid Accuracy: 0.743
# Epoch 244, CIFAR-10 Batch 2:  Cost:     0.7443 Valid Accuracy: 0.738
# Epoch 244, CIFAR-10 Batch 3:  Cost:     0.7363 Valid Accuracy: 0.743
# Epoch 244, CIFAR-10 Batch 4:  Cost:     0.7486 Valid Accuracy: 0.738
# Epoch 244, CIFAR-10 Batch 5:  Cost:     0.7439 Valid Accuracy: 0.741
# Epoch 245, CIFAR-10 Batch 1:  Cost:     0.7394 Valid Accuracy: 0.745
# Epoch 245, CIFAR-10 Batch 2:  Cost:     0.7430 Valid Accuracy: 0.741
# Epoch 245, CIFAR-10 Batch 3:  Cost:     0.7324 Valid Accuracy: 0.745
# Epoch 245, CIFAR-10 Batch 4:  Cost:     0.7438 Valid Accuracy: 0.74
# Epoch 245, CIFAR-10 Batch 5:  Cost:     0.7386 Valid Accuracy: 0.741
# Epoch 246, CIFAR-10 Batch 1:  Cost:     0.7368 Valid Accuracy: 0.745
# Epoch 246, CIFAR-10 Batch 2:  Cost:     0.7407 Valid Accuracy: 0.74
# Epoch 246, CIFAR-10 Batch 3:  Cost:     0.7327 Valid Accuracy: 0.744
# Epoch 246, CIFAR-10 Batch 4:  Cost:     0.7370 Valid Accuracy: 0.743
# Epoch 246, CIFAR-10 Batch 5:  Cost:     0.7367 Valid Accuracy: 0.74
# Epoch 247, CIFAR-10 Batch 1:  Cost:     0.7358 Valid Accuracy: 0.747
# Epoch 247, CIFAR-10 Batch 2:  Cost:     0.7361 Valid Accuracy: 0.742
# Epoch 247, CIFAR-10 Batch 3:  Cost:     0.7246 Valid Accuracy: 0.745
# Epoch 247, CIFAR-10 Batch 4:  Cost:     0.7390 Valid Accuracy: 0.743
# Epoch 247, CIFAR-10 Batch 5:  Cost:     0.7361 Valid Accuracy: 0.742
# Epoch 248, CIFAR-10 Batch 1:  Cost:     0.7356 Valid Accuracy: 0.746
# Epoch 248, CIFAR-10 Batch 2:  Cost:     0.7356 Valid Accuracy: 0.742
# Epoch 248, CIFAR-10 Batch 3:  Cost:     0.7309 Valid Accuracy: 0.744
# Epoch 248, CIFAR-10 Batch 4:  Cost:     0.7335 Valid Accuracy: 0.746
# Epoch 248, CIFAR-10 Batch 5:  Cost:     0.7338 Valid Accuracy: 0.741
# Epoch 249, CIFAR-10 Batch 1:  Cost:     0.7281 Valid Accuracy: 0.749
# Epoch 249, CIFAR-10 Batch 2:  Cost:     0.7245 Valid Accuracy: 0.744
# Epoch 249, CIFAR-10 Batch 3:  Cost:     0.7311 Valid Accuracy: 0.745
# Epoch 249, CIFAR-10 Batch 4:  Cost:     0.7747 Valid Accuracy: 0.726
# Epoch 249, CIFAR-10 Batch 5:  Cost:     0.8048 Valid Accuracy: 0.718
# Epoch 250, CIFAR-10 Batch 1:  Cost:     0.8588 Valid Accuracy: 0.698
# Epoch 250, CIFAR-10 Batch 2:  Cost:     0.9236 Valid Accuracy: 0.67
# Epoch 250, CIFAR-10 Batch 3:  Cost:     0.8092 Valid Accuracy: 0.714
# Epoch 250, CIFAR-10 Batch 4:  Cost:     0.8348 Valid Accuracy: 0.699
# Epoch 250, CIFAR-10 Batch 5:  Cost:     0.9123 Valid Accuracy: 0.682

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5514998435974121

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
