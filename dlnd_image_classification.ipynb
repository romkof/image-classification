# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 1
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 1:
# Image - Min Value: 2 Max Value: 247
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    
    # TODO: Implement Function
    return np.array(
        list(map(lambda image : 
                list(map(lambda pixel : pixel/256 ,image)), x)))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    
    # TODO: Implement Function
    return np.eye(10)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, 32, 32, 3], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, 10], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    tensor_channels =(x_tensor.shape.dims[-1]).value
    batch_size = 1
    pooling_channels =1
    
    weight_shape=[]
    weight_shape.extend(conv_ksize)
    weight_shape.append(tensor_channels)
    weight_shape.append(conv_num_outputs)
    
    weight = tf.Variable(tf.truncated_normal(weight_shape, stddev=0.05))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_stride = [batch_size]
    conv_stride.extend(conv_strides)
    conv_stride.append(pooling_channels)
    
    conv_layer = tf.nn.conv2d(x_tensor, weight, strides=conv_stride, padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    
    
    max_pool_stride = [batch_size]
    max_pool_stride.extend(pool_strides)
    max_pool_stride.append(pooling_channels)
    
    pool_ksize_list = [batch_size]
    pool_ksize_list.extend(pool_ksize)
    pool_ksize_list.append(pooling_channels)
    
    
    conv_layer = tf.nn.max_pool(
        conv_layer,
        ksize=pool_ksize_list,
        strides= max_pool_stride,
        padding='SAME')
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    
    layer_shape = x_tensor.get_shape()
    num_features = layer_shape[1:4].num_elements()
    return tf.reshape(x_tensor, [-1, num_features])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_input = x_tensor.get_shape()[1].value
    weight = tf.Variable(tf.truncated_normal([num_input,num_outputs], stddev =0.05))
    bias = tf.Variable(tf.zeros(num_outputs))
    layer = tf.matmul(x_tensor, weight) + bias
    layer = tf.nn.relu(layer)
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_input = x_tensor.get_shape()[1].value
    weight = tf.Variable(tf.truncated_normal([num_input,num_outputs], stddev =0.05))
    bias = tf.Variable(tf.zeros(num_outputs))
    layer = tf.matmul(x_tensor, weight) + bias   
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #
   
    conv_num_outputs_1 =  16
    conv_ksize_1 =       (2,2)
    conv_strides_1 =     (2,2)
    pool_ksize_1 =       (2,2)
    pool_strides_1 =     (2,2)
    
    conv_num_outputs_2 =  256
    conv_ksize_2 =       (2,2)  
    conv_strides_2 =     (2,2)
    pool_ksize_2 =       (2,2)
    pool_strides_2 =     (2,2)
    
    conv_num_outputs_3 =  64
    conv_ksize_3 =       (2,2)  
    conv_strides_3 =     (2,2)
    pool_ksize_3 =       (2,2)
    pool_strides_3 =     (2,2)
    
    
    fully_conn_layer_1_num_outputs = 2048
    fully_conn_layer_2_num_outputs = 2048
    fully_conn_layer_3_num_outputs = 512
    
    
    output_layer_num_outputs = 10
    
    conv_layer_1 = conv2d_maxpool(x, conv_num_outputs_1, conv_ksize_1, conv_strides_1, pool_ksize_1, pool_strides_1)
    conv_layer_2 = conv2d_maxpool(conv_layer_1, conv_num_outputs_2, conv_ksize_2, conv_strides_2, pool_ksize_2, pool_strides_2)
    
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   
    flatten_layer = flatten(conv_layer_2)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #
    
    fully_conn_layer_1 = fully_conn(flatten_layer, fully_conn_layer_1_num_outputs)
    fully_conn_layer_2 = fully_conn(fully_conn_layer_1, fully_conn_layer_2_num_outputs)
    fully_conn_layer_3 = fully_conn(fully_conn_layer_2, fully_conn_layer_3_num_outputs)
    
    fully_conn_layer_2_drop = tf.nn.dropout(fully_conn_layer_3, keep_prob)    
        
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   
    output_layer = output(fully_conn_layer_2_drop, output_layer_num_outputs)
    
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    feed_dict_train = {    x: feature_batch,
                           y: label_batch,
                           keep_prob: keep_probability
                      }
    session.run(optimizer, feed_dict=feed_dict_train)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# # Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    cost_feed_dict = {x: feature_batch,
                           y: label_batch,
                           keep_prob: 1.0}
    accuracy_feed_dict = {x: valid_features,
                           y: valid_labels,
                           keep_prob: 1.0}     
    current_cost = sess.run(cost, feed_dict=cost_feed_dict)
    valid_accuracy = sess.run(accuracy,feed_dict=accuracy_feed_dict)
    
    print('Cost: {:10.4f} Valid Accuracy: {:<5.3}'.format(current_cost,   valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 12288
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost:     2.2957 Valid Accuracy: 0.121
# Epoch  2, CIFAR-10 Batch 1:  Cost:     2.2852 Valid Accuracy: 0.207
# Epoch  3, CIFAR-10 Batch 1:  Cost:     2.2701 Valid Accuracy: 0.152
# Epoch  4, CIFAR-10 Batch 1:  Cost:     2.2490 Valid Accuracy: 0.159
# Epoch  5, CIFAR-10 Batch 1:  Cost:     2.2347 Valid Accuracy: 0.147
# Epoch  6, CIFAR-10 Batch 1:  Cost:     2.2386 Valid Accuracy: 0.136
# Epoch  7, CIFAR-10 Batch 1:  Cost:     2.1790 Valid Accuracy: 0.24
# Epoch  8, CIFAR-10 Batch 1:  Cost:     2.1835 Valid Accuracy: 0.2
# Epoch  9, CIFAR-10 Batch 1:  Cost:     2.1352 Valid Accuracy: 0.268
# Epoch 10, CIFAR-10 Batch 1:  Cost:     2.1033 Valid Accuracy: 0.271
# Epoch 11, CIFAR-10 Batch 1:  Cost:     2.0836 Valid Accuracy: 0.251
# Epoch 12, CIFAR-10 Batch 1:  Cost:     2.0460 Valid Accuracy: 0.27
# Epoch 13, CIFAR-10 Batch 1:  Cost:     1.9941 Valid Accuracy: 0.295
# Epoch 14, CIFAR-10 Batch 1:  Cost:     2.0051 Valid Accuracy: 0.259
# Epoch 15, CIFAR-10 Batch 1:  Cost:     1.9895 Valid Accuracy: 0.265
# Epoch 16, CIFAR-10 Batch 1:  Cost:     1.9417 Valid Accuracy: 0.296
# Epoch 17, CIFAR-10 Batch 1:  Cost:     1.9291 Valid Accuracy: 0.285
# Epoch 18, CIFAR-10 Batch 1:  Cost:     1.9216 Valid Accuracy: 0.278
# Epoch 19, CIFAR-10 Batch 1:  Cost:     1.8745 Valid Accuracy: 0.32
# Epoch 20, CIFAR-10 Batch 1:  Cost:     1.8879 Valid Accuracy: 0.305
# Epoch 21, CIFAR-10 Batch 1:  Cost:     1.8617 Valid Accuracy: 0.314
# Epoch 22, CIFAR-10 Batch 1:  Cost:     1.8657 Valid Accuracy: 0.312
# Epoch 23, CIFAR-10 Batch 1:  Cost:     1.8220 Valid Accuracy: 0.337
# Epoch 24, CIFAR-10 Batch 1:  Cost:     1.8321 Valid Accuracy: 0.34
# Epoch 25, CIFAR-10 Batch 1:  Cost:     1.8072 Valid Accuracy: 0.348
# Epoch 26, CIFAR-10 Batch 1:  Cost:     1.7960 Valid Accuracy: 0.335
# Epoch 27, CIFAR-10 Batch 1:  Cost:     1.7833 Valid Accuracy: 0.338
# Epoch 28, CIFAR-10 Batch 1:  Cost:     1.7655 Valid Accuracy: 0.35
# Epoch 29, CIFAR-10 Batch 1:  Cost:     1.7599 Valid Accuracy: 0.348
# Epoch 30, CIFAR-10 Batch 1:  Cost:     1.7343 Valid Accuracy: 0.356
# Epoch 31, CIFAR-10 Batch 1:  Cost:     1.7347 Valid Accuracy: 0.344
# Epoch 32, CIFAR-10 Batch 1:  Cost:     1.7252 Valid Accuracy: 0.37
# Epoch 33, CIFAR-10 Batch 1:  Cost:     1.7594 Valid Accuracy: 0.337
# Epoch 34, CIFAR-10 Batch 1:  Cost:     1.7587 Valid Accuracy: 0.366
# Epoch 35, CIFAR-10 Batch 1:  Cost:     1.7037 Valid Accuracy: 0.353
# Epoch 36, CIFAR-10 Batch 1:  Cost:     1.7000 Valid Accuracy: 0.361
# Epoch 37, CIFAR-10 Batch 1:  Cost:     1.7129 Valid Accuracy: 0.37
# Epoch 38, CIFAR-10 Batch 1:  Cost:     1.6661 Valid Accuracy: 0.383
# Epoch 39, CIFAR-10 Batch 1:  Cost:     1.6921 Valid Accuracy: 0.354
# Epoch 40, CIFAR-10 Batch 1:  Cost:     1.6575 Valid Accuracy: 0.375
# Epoch 41, CIFAR-10 Batch 1:  Cost:     1.6672 Valid Accuracy: 0.382
# Epoch 42, CIFAR-10 Batch 1:  Cost:     1.6485 Valid Accuracy: 0.384
# Epoch 43, CIFAR-10 Batch 1:  Cost:     1.6363 Valid Accuracy: 0.387
# Epoch 44, CIFAR-10 Batch 1:  Cost:     1.6401 Valid Accuracy: 0.383
# Epoch 45, CIFAR-10 Batch 1:  Cost:     1.6180 Valid Accuracy: 0.392
# Epoch 46, CIFAR-10 Batch 1:  Cost:     1.6213 Valid Accuracy: 0.394
# Epoch 47, CIFAR-10 Batch 1:  Cost:     1.5952 Valid Accuracy: 0.398
# Epoch 48, CIFAR-10 Batch 1:  Cost:     1.6010 Valid Accuracy: 0.398
# Epoch 49, CIFAR-10 Batch 1:  Cost:     1.5861 Valid Accuracy: 0.399
# Epoch 50, CIFAR-10 Batch 1:  Cost:     1.5786 Valid Accuracy: 0.403
# Epoch 51, CIFAR-10 Batch 1:  Cost:     1.5728 Valid Accuracy: 0.411
# Epoch 52, CIFAR-10 Batch 1:  Cost:     1.5689 Valid Accuracy: 0.401
# Epoch 53, CIFAR-10 Batch 1:  Cost:     1.5527 Valid Accuracy: 0.411
# Epoch 54, CIFAR-10 Batch 1:  Cost:     1.5545 Valid Accuracy: 0.413
# Epoch 55, CIFAR-10 Batch 1:  Cost:     1.5447 Valid Accuracy: 0.418
# Epoch 56, CIFAR-10 Batch 1:  Cost:     1.5610 Valid Accuracy: 0.41
# Epoch 57, CIFAR-10 Batch 1:  Cost:     1.6601 Valid Accuracy: 0.373
# Epoch 58, CIFAR-10 Batch 1:  Cost:     1.7129 Valid Accuracy: 0.381
# Epoch 59, CIFAR-10 Batch 1:  Cost:     1.5902 Valid Accuracy: 0.391
# Epoch 60, CIFAR-10 Batch 1:  Cost:     1.6144 Valid Accuracy: 0.39
# Epoch 61, CIFAR-10 Batch 1:  Cost:     1.5989 Valid Accuracy: 0.405
# Epoch 62, CIFAR-10 Batch 1:  Cost:     1.5848 Valid Accuracy: 0.405
# Epoch 63, CIFAR-10 Batch 1:  Cost:     1.5643 Valid Accuracy: 0.399
# Epoch 64, CIFAR-10 Batch 1:  Cost:     1.5877 Valid Accuracy: 0.393
# Epoch 65, CIFAR-10 Batch 1:  Cost:     1.5403 Valid Accuracy: 0.419
# Epoch 66, CIFAR-10 Batch 1:  Cost:     1.5545 Valid Accuracy: 0.411
# Epoch 67, CIFAR-10 Batch 1:  Cost:     1.5320 Valid Accuracy: 0.41
# Epoch 68, CIFAR-10 Batch 1:  Cost:     1.5277 Valid Accuracy: 0.416
# Epoch 69, CIFAR-10 Batch 1:  Cost:     1.5045 Valid Accuracy: 0.42
# Epoch 70, CIFAR-10 Batch 1:  Cost:     1.5135 Valid Accuracy: 0.419
# Epoch 71, CIFAR-10 Batch 1:  Cost:     1.4824 Valid Accuracy: 0.425
# Epoch 72, CIFAR-10 Batch 1:  Cost:     1.4888 Valid Accuracy: 0.425
# Epoch 73, CIFAR-10 Batch 1:  Cost:     1.4737 Valid Accuracy: 0.435
# Epoch 74, CIFAR-10 Batch 1:  Cost:     1.4655 Valid Accuracy: 0.441
# Epoch 75, CIFAR-10 Batch 1:  Cost:     1.4590 Valid Accuracy: 0.429
# Epoch 76, CIFAR-10 Batch 1:  Cost:     1.4509 Valid Accuracy: 0.439
# Epoch 77, CIFAR-10 Batch 1:  Cost:     1.4410 Valid Accuracy: 0.442
# Epoch 78, CIFAR-10 Batch 1:  Cost:     1.4378 Valid Accuracy: 0.439
# Epoch 79, CIFAR-10 Batch 1:  Cost:     1.4250 Valid Accuracy: 0.445
# Epoch 80, CIFAR-10 Batch 1:  Cost:     1.4205 Valid Accuracy: 0.441
# Epoch 81, CIFAR-10 Batch 1:  Cost:     1.4129 Valid Accuracy: 0.447
# Epoch 82, CIFAR-10 Batch 1:  Cost:     1.4102 Valid Accuracy: 0.443
# Epoch 83, CIFAR-10 Batch 1:  Cost:     1.3932 Valid Accuracy: 0.454
# Epoch 84, CIFAR-10 Batch 1:  Cost:     1.3992 Valid Accuracy: 0.446
# Epoch 85, CIFAR-10 Batch 1:  Cost:     1.4039 Valid Accuracy: 0.446
# Epoch 86, CIFAR-10 Batch 1:  Cost:     1.4180 Valid Accuracy: 0.445
# Epoch 87, CIFAR-10 Batch 1:  Cost:     1.4667 Valid Accuracy: 0.43
# Epoch 88, CIFAR-10 Batch 1:  Cost:     1.4968 Valid Accuracy: 0.422
# Epoch 89, CIFAR-10 Batch 1:  Cost:     1.4002 Valid Accuracy: 0.436
# Epoch 90, CIFAR-10 Batch 1:  Cost:     1.4603 Valid Accuracy: 0.425
# Epoch 91, CIFAR-10 Batch 1:  Cost:     1.4236 Valid Accuracy: 0.437
# Epoch 92, CIFAR-10 Batch 1:  Cost:     1.4274 Valid Accuracy: 0.442
# Epoch 93, CIFAR-10 Batch 1:  Cost:     1.3709 Valid Accuracy: 0.459
# Epoch 94, CIFAR-10 Batch 1:  Cost:     1.4243 Valid Accuracy: 0.434
# Epoch 95, CIFAR-10 Batch 1:  Cost:     1.3640 Valid Accuracy: 0.46
# Epoch 96, CIFAR-10 Batch 1:  Cost:     1.3880 Valid Accuracy: 0.455
# Epoch 97, CIFAR-10 Batch 1:  Cost:     1.3649 Valid Accuracy: 0.449
# Epoch 98, CIFAR-10 Batch 1:  Cost:     1.3605 Valid Accuracy: 0.451
# Epoch 99, CIFAR-10 Batch 1:  Cost:     1.3430 Valid Accuracy: 0.458
# Epoch 100, CIFAR-10 Batch 1:  Cost:     1.3399 Valid Accuracy: 0.454
# Epoch 101, CIFAR-10 Batch 1:  Cost:     1.3401 Valid Accuracy: 0.466
# Epoch 102, CIFAR-10 Batch 1:  Cost:     1.3197 Valid Accuracy: 0.466
# Epoch 103, CIFAR-10 Batch 1:  Cost:     1.3114 Valid Accuracy: 0.459
# Epoch 104, CIFAR-10 Batch 1:  Cost:     1.3297 Valid Accuracy: 0.463
# Epoch 105, CIFAR-10 Batch 1:  Cost:     1.3903 Valid Accuracy: 0.439
# Epoch 106, CIFAR-10 Batch 1:  Cost:     1.3655 Valid Accuracy: 0.456
# Epoch 107, CIFAR-10 Batch 1:  Cost:     1.3094 Valid Accuracy: 0.471
# Epoch 108, CIFAR-10 Batch 1:  Cost:     1.4297 Valid Accuracy: 0.412
# Epoch 109, CIFAR-10 Batch 1:  Cost:     1.3734 Valid Accuracy: 0.454
# Epoch 110, CIFAR-10 Batch 1:  Cost:     1.3867 Valid Accuracy: 0.449
# Epoch 111, CIFAR-10 Batch 1:  Cost:     1.3175 Valid Accuracy: 0.467
# Epoch 112, CIFAR-10 Batch 1:  Cost:     1.3287 Valid Accuracy: 0.458
# Epoch 113, CIFAR-10 Batch 1:  Cost:     1.3239 Valid Accuracy: 0.459
# Epoch 114, CIFAR-10 Batch 1:  Cost:     1.3134 Valid Accuracy: 0.457
# Epoch 115, CIFAR-10 Batch 1:  Cost:     1.3035 Valid Accuracy: 0.471
# Epoch 116, CIFAR-10 Batch 1:  Cost:     1.2983 Valid Accuracy: 0.466
# Epoch 117, CIFAR-10 Batch 1:  Cost:     1.2817 Valid Accuracy: 0.461
# Epoch 118, CIFAR-10 Batch 1:  Cost:     1.2821 Valid Accuracy: 0.48
# Epoch 119, CIFAR-10 Batch 1:  Cost:     1.2552 Valid Accuracy: 0.477
# Epoch 120, CIFAR-10 Batch 1:  Cost:     1.2611 Valid Accuracy: 0.465
# Epoch 121, CIFAR-10 Batch 1:  Cost:     1.2429 Valid Accuracy: 0.469
# Epoch 122, CIFAR-10 Batch 1:  Cost:     1.2384 Valid Accuracy: 0.482
# Epoch 123, CIFAR-10 Batch 1:  Cost:     1.2248 Valid Accuracy: 0.486
# Epoch 124, CIFAR-10 Batch 1:  Cost:     1.2277 Valid Accuracy: 0.478
# Epoch 125, CIFAR-10 Batch 1:  Cost:     1.2269 Valid Accuracy: 0.477
# Epoch 126, CIFAR-10 Batch 1:  Cost:     1.2250 Valid Accuracy: 0.482
# Epoch 127, CIFAR-10 Batch 1:  Cost:     1.1931 Valid Accuracy: 0.491
# Epoch 128, CIFAR-10 Batch 1:  Cost:     1.2133 Valid Accuracy: 0.485
# Epoch 129, CIFAR-10 Batch 1:  Cost:     1.1799 Valid Accuracy: 0.494
# Epoch 130, CIFAR-10 Batch 1:  Cost:     1.1919 Valid Accuracy: 0.487
# Epoch 131, CIFAR-10 Batch 1:  Cost:     1.1877 Valid Accuracy: 0.487
# Epoch 132, CIFAR-10 Batch 1:  Cost:     1.1793 Valid Accuracy: 0.488
# Epoch 133, CIFAR-10 Batch 1:  Cost:     1.1810 Valid Accuracy: 0.495
# Epoch 134, CIFAR-10 Batch 1:  Cost:     1.1860 Valid Accuracy: 0.48
# Epoch 135, CIFAR-10 Batch 1:  Cost:     1.1933 Valid Accuracy: 0.489
# Epoch 136, CIFAR-10 Batch 1:  Cost:     1.2063 Valid Accuracy: 0.49
# Epoch 137, CIFAR-10 Batch 1:  Cost:     1.1816 Valid Accuracy: 0.493
# Epoch 138, CIFAR-10 Batch 1:  Cost:     1.1463 Valid Accuracy: 0.497
# Epoch 139, CIFAR-10 Batch 1:  Cost:     1.1459 Valid Accuracy: 0.502
# Epoch 140, CIFAR-10 Batch 1:  Cost:     1.1457 Valid Accuracy: 0.494
# Epoch 141, CIFAR-10 Batch 1:  Cost:     1.1365 Valid Accuracy: 0.496
# Epoch 142, CIFAR-10 Batch 1:  Cost:     1.1556 Valid Accuracy: 0.495
# Epoch 143, CIFAR-10 Batch 1:  Cost:     1.1523 Valid Accuracy: 0.482
# Epoch 144, CIFAR-10 Batch 1:  Cost:     1.1151 Valid Accuracy: 0.504
# Epoch 145, CIFAR-10 Batch 1:  Cost:     1.1169 Valid Accuracy: 0.502
# Epoch 146, CIFAR-10 Batch 1:  Cost:     1.1577 Valid Accuracy: 0.472
# Epoch 147, CIFAR-10 Batch 1:  Cost:     1.1424 Valid Accuracy: 0.493
# Epoch 148, CIFAR-10 Batch 1:  Cost:     1.1092 Valid Accuracy: 0.508
# Epoch 149, CIFAR-10 Batch 1:  Cost:     1.1503 Valid Accuracy: 0.477
# Epoch 150, CIFAR-10 Batch 1:  Cost:     1.0967 Valid Accuracy: 0.507
# Epoch 151, CIFAR-10 Batch 1:  Cost:     1.0956 Valid Accuracy: 0.501
# Epoch 152, CIFAR-10 Batch 1:  Cost:     1.0961 Valid Accuracy: 0.495
# Epoch 153, CIFAR-10 Batch 1:  Cost:     1.0793 Valid Accuracy: 0.508
# Epoch 154, CIFAR-10 Batch 1:  Cost:     1.0929 Valid Accuracy: 0.499
# Epoch 155, CIFAR-10 Batch 1:  Cost:     1.1156 Valid Accuracy: 0.494
# Epoch 156, CIFAR-10 Batch 1:  Cost:     1.1439 Valid Accuracy: 0.477
# Epoch 157, CIFAR-10 Batch 1:  Cost:     1.2291 Valid Accuracy: 0.479
# Epoch 158, CIFAR-10 Batch 1:  Cost:     1.0960 Valid Accuracy: 0.492
# Epoch 159, CIFAR-10 Batch 1:  Cost:     1.1470 Valid Accuracy: 0.462
# Epoch 160, CIFAR-10 Batch 1:  Cost:     1.1572 Valid Accuracy: 0.487
# Epoch 161, CIFAR-10 Batch 1:  Cost:     1.1260 Valid Accuracy: 0.492
# Epoch 162, CIFAR-10 Batch 1:  Cost:     1.1012 Valid Accuracy: 0.496
# Epoch 163, CIFAR-10 Batch 1:  Cost:     1.1279 Valid Accuracy: 0.473
# Epoch 164, CIFAR-10 Batch 1:  Cost:     1.0943 Valid Accuracy: 0.5
# Epoch 165, CIFAR-10 Batch 1:  Cost:     1.0705 Valid Accuracy: 0.502
# Epoch 166, CIFAR-10 Batch 1:  Cost:     1.0765 Valid Accuracy: 0.5
# Epoch 167, CIFAR-10 Batch 1:  Cost:     1.0448 Valid Accuracy: 0.513
# Epoch 168, CIFAR-10 Batch 1:  Cost:     1.0663 Valid Accuracy: 0.494
# Epoch 169, CIFAR-10 Batch 1:  Cost:     1.0478 Valid Accuracy: 0.501
# Epoch 170, CIFAR-10 Batch 1:  Cost:     1.0333 Valid Accuracy: 0.502
# Epoch 171, CIFAR-10 Batch 1:  Cost:     1.0389 Valid Accuracy: 0.508
# Epoch 172, CIFAR-10 Batch 1:  Cost:     1.0181 Valid Accuracy: 0.499
# Epoch 173, CIFAR-10 Batch 1:  Cost:     1.0215 Valid Accuracy: 0.508
# Epoch 174, CIFAR-10 Batch 1:  Cost:     1.0457 Valid Accuracy: 0.505
# Epoch 175, CIFAR-10 Batch 1:  Cost:     1.0788 Valid Accuracy: 0.497
# Epoch 176, CIFAR-10 Batch 1:  Cost:     1.1735 Valid Accuracy: 0.465
# Epoch 177, CIFAR-10 Batch 1:  Cost:     1.1221 Valid Accuracy: 0.498
# Epoch 178, CIFAR-10 Batch 1:  Cost:     0.9863 Valid Accuracy: 0.515
# Epoch 179, CIFAR-10 Batch 1:  Cost:     1.0470 Valid Accuracy: 0.505
# Epoch 180, CIFAR-10 Batch 1:  Cost:     1.0358 Valid Accuracy: 0.5
# Epoch 181, CIFAR-10 Batch 1:  Cost:     0.9916 Valid Accuracy: 0.511
# Epoch 182, CIFAR-10 Batch 1:  Cost:     1.0245 Valid Accuracy: 0.5
# Epoch 183, CIFAR-10 Batch 1:  Cost:     0.9653 Valid Accuracy: 0.51
# Epoch 184, CIFAR-10 Batch 1:  Cost:     0.9971 Valid Accuracy: 0.512
# Epoch 185, CIFAR-10 Batch 1:  Cost:     0.9752 Valid Accuracy: 0.524
# Epoch 186, CIFAR-10 Batch 1:  Cost:     0.9578 Valid Accuracy: 0.509
# Epoch 187, CIFAR-10 Batch 1:  Cost:     0.9665 Valid Accuracy: 0.521
# Epoch 188, CIFAR-10 Batch 1:  Cost:     0.9341 Valid Accuracy: 0.526
# Epoch 189, CIFAR-10 Batch 1:  Cost:     0.9589 Valid Accuracy: 0.512
# Epoch 190, CIFAR-10 Batch 1:  Cost:     0.9182 Valid Accuracy: 0.523
# Epoch 191, CIFAR-10 Batch 1:  Cost:     0.9313 Valid Accuracy: 0.523
# Epoch 192, CIFAR-10 Batch 1:  Cost:     0.9238 Valid Accuracy: 0.515
# Epoch 193, CIFAR-10 Batch 1:  Cost:     0.9039 Valid Accuracy: 0.527
# Epoch 194, CIFAR-10 Batch 1:  Cost:     0.9026 Valid Accuracy: 0.526
# Epoch 195, CIFAR-10 Batch 1:  Cost:     0.9007 Valid Accuracy: 0.515
# Epoch 196, CIFAR-10 Batch 1:  Cost:     0.8903 Valid Accuracy: 0.522
# Epoch 197, CIFAR-10 Batch 1:  Cost:     0.8765 Valid Accuracy: 0.528
# Epoch 198, CIFAR-10 Batch 1:  Cost:     0.8891 Valid Accuracy: 0.522
# Epoch 199, CIFAR-10 Batch 1:  Cost:     0.8756 Valid Accuracy: 0.525
# Epoch 200, CIFAR-10 Batch 1:  Cost:     0.8971 Valid Accuracy: 0.52

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost:     2.2906 Valid Accuracy: 0.142
# Epoch  1, CIFAR-10 Batch 2:  Cost:     2.2802 Valid Accuracy: 0.181
# Epoch  1, CIFAR-10 Batch 3:  Cost:     2.2599 Valid Accuracy: 0.158
# Epoch  1, CIFAR-10 Batch 4:  Cost:     2.2328 Valid Accuracy: 0.24
# Epoch  1, CIFAR-10 Batch 5:  Cost:     2.1913 Valid Accuracy: 0.265
# Epoch  2, CIFAR-10 Batch 1:  Cost:     2.1349 Valid Accuracy: 0.257
# Epoch  2, CIFAR-10 Batch 2:  Cost:     2.1690 Valid Accuracy: 0.206
# Epoch  2, CIFAR-10 Batch 3:  Cost:     2.2307 Valid Accuracy: 0.153
# Epoch  2, CIFAR-10 Batch 4:  Cost:     2.0608 Valid Accuracy: 0.292
# Epoch  2, CIFAR-10 Batch 5:  Cost:     2.1632 Valid Accuracy: 0.214
# Epoch  3, CIFAR-10 Batch 1:  Cost:     2.0688 Valid Accuracy: 0.264
# Epoch  3, CIFAR-10 Batch 2:  Cost:     2.0591 Valid Accuracy: 0.263
# Epoch  3, CIFAR-10 Batch 3:  Cost:     2.0725 Valid Accuracy: 0.238
# Epoch  3, CIFAR-10 Batch 4:  Cost:     2.0140 Valid Accuracy: 0.288
# Epoch  3, CIFAR-10 Batch 5:  Cost:     2.0111 Valid Accuracy: 0.272
# Epoch  4, CIFAR-10 Batch 1:  Cost:     1.9914 Valid Accuracy: 0.266
# Epoch  4, CIFAR-10 Batch 2:  Cost:     1.9565 Valid Accuracy: 0.293
# Epoch  4, CIFAR-10 Batch 3:  Cost:     1.9385 Valid Accuracy: 0.27
# Epoch  4, CIFAR-10 Batch 4:  Cost:     1.9375 Valid Accuracy: 0.281
# Epoch  4, CIFAR-10 Batch 5:  Cost:     1.9014 Valid Accuracy: 0.311
# Epoch  5, CIFAR-10 Batch 1:  Cost:     1.8922 Valid Accuracy: 0.307
# Epoch  5, CIFAR-10 Batch 2:  Cost:     1.8794 Valid Accuracy: 0.327
# Epoch  5, CIFAR-10 Batch 3:  Cost:     1.8576 Valid Accuracy: 0.315
# Epoch  5, CIFAR-10 Batch 4:  Cost:     1.8855 Valid Accuracy: 0.298
# Epoch  5, CIFAR-10 Batch 5:  Cost:     1.8668 Valid Accuracy: 0.323
# Epoch  6, CIFAR-10 Batch 1:  Cost:     1.8369 Valid Accuracy: 0.321
# Epoch  6, CIFAR-10 Batch 2:  Cost:     1.8345 Valid Accuracy: 0.332
# Epoch  6, CIFAR-10 Batch 3:  Cost:     1.8305 Valid Accuracy: 0.326
# Epoch  6, CIFAR-10 Batch 4:  Cost:     1.8389 Valid Accuracy: 0.32
# Epoch  6, CIFAR-10 Batch 5:  Cost:     1.8151 Valid Accuracy: 0.339
# Epoch  7, CIFAR-10 Batch 1:  Cost:     1.8025 Valid Accuracy: 0.34
# Epoch  7, CIFAR-10 Batch 2:  Cost:     1.8015 Valid Accuracy: 0.35
# Epoch  7, CIFAR-10 Batch 3:  Cost:     1.7747 Valid Accuracy: 0.347
# Epoch  7, CIFAR-10 Batch 4:  Cost:     1.7915 Valid Accuracy: 0.349
# Epoch  7, CIFAR-10 Batch 5:  Cost:     1.7689 Valid Accuracy: 0.36
# Epoch  8, CIFAR-10 Batch 1:  Cost:     1.7447 Valid Accuracy: 0.353
# Epoch  8, CIFAR-10 Batch 2:  Cost:     1.7604 Valid Accuracy: 0.357
# Epoch  8, CIFAR-10 Batch 3:  Cost:     1.7312 Valid Accuracy: 0.355
# Epoch  8, CIFAR-10 Batch 4:  Cost:     1.7410 Valid Accuracy: 0.367
# Epoch  8, CIFAR-10 Batch 5:  Cost:     1.7365 Valid Accuracy: 0.362
# Epoch  9, CIFAR-10 Batch 1:  Cost:     1.7078 Valid Accuracy: 0.365
# Epoch  9, CIFAR-10 Batch 2:  Cost:     1.7779 Valid Accuracy: 0.364
# Epoch  9, CIFAR-10 Batch 3:  Cost:     1.7385 Valid Accuracy: 0.354
# Epoch  9, CIFAR-10 Batch 4:  Cost:     1.7125 Valid Accuracy: 0.383
# Epoch  9, CIFAR-10 Batch 5:  Cost:     1.7385 Valid Accuracy: 0.377
# Epoch 10, CIFAR-10 Batch 1:  Cost:     1.6994 Valid Accuracy: 0.365
# Epoch 10, CIFAR-10 Batch 2:  Cost:     1.6982 Valid Accuracy: 0.382
# Epoch 10, CIFAR-10 Batch 3:  Cost:     1.7051 Valid Accuracy: 0.381
# Epoch 10, CIFAR-10 Batch 4:  Cost:     1.6935 Valid Accuracy: 0.39
# Epoch 10, CIFAR-10 Batch 5:  Cost:     1.7068 Valid Accuracy: 0.379
# Epoch 11, CIFAR-10 Batch 1:  Cost:     1.6620 Valid Accuracy: 0.391
# Epoch 11, CIFAR-10 Batch 2:  Cost:     1.6825 Valid Accuracy: 0.391
# Epoch 11, CIFAR-10 Batch 3:  Cost:     1.6605 Valid Accuracy: 0.395
# Epoch 11, CIFAR-10 Batch 4:  Cost:     1.6677 Valid Accuracy: 0.401
# Epoch 11, CIFAR-10 Batch 5:  Cost:     1.6606 Valid Accuracy: 0.403
# Epoch 12, CIFAR-10 Batch 1:  Cost:     1.6290 Valid Accuracy: 0.395
# Epoch 12, CIFAR-10 Batch 2:  Cost:     1.6455 Valid Accuracy: 0.4
# Epoch 12, CIFAR-10 Batch 3:  Cost:     1.6071 Valid Accuracy: 0.406
# Epoch 12, CIFAR-10 Batch 4:  Cost:     1.6492 Valid Accuracy: 0.404
# Epoch 12, CIFAR-10 Batch 5:  Cost:     1.6309 Valid Accuracy: 0.406
# Epoch 13, CIFAR-10 Batch 1:  Cost:     1.5951 Valid Accuracy: 0.408
# Epoch 13, CIFAR-10 Batch 2:  Cost:     1.6079 Valid Accuracy: 0.418
# Epoch 13, CIFAR-10 Batch 3:  Cost:     1.5795 Valid Accuracy: 0.419
# Epoch 13, CIFAR-10 Batch 4:  Cost:     1.6156 Valid Accuracy: 0.414
# Epoch 13, CIFAR-10 Batch 5:  Cost:     1.6497 Valid Accuracy: 0.406
# Epoch 14, CIFAR-10 Batch 1:  Cost:     1.6579 Valid Accuracy: 0.383
# Epoch 14, CIFAR-10 Batch 2:  Cost:     1.6620 Valid Accuracy: 0.407
# Epoch 14, CIFAR-10 Batch 3:  Cost:     1.5595 Valid Accuracy: 0.419
# Epoch 14, CIFAR-10 Batch 4:  Cost:     1.6462 Valid Accuracy: 0.405
# Epoch 14, CIFAR-10 Batch 5:  Cost:     1.6081 Valid Accuracy: 0.421
# Epoch 15, CIFAR-10 Batch 1:  Cost:     1.5665 Valid Accuracy: 0.424
# Epoch 15, CIFAR-10 Batch 2:  Cost:     1.5996 Valid Accuracy: 0.417
# Epoch 15, CIFAR-10 Batch 3:  Cost:     1.5655 Valid Accuracy: 0.427
# Epoch 15, CIFAR-10 Batch 4:  Cost:     1.5806 Valid Accuracy: 0.428
# Epoch 15, CIFAR-10 Batch 5:  Cost:     1.6081 Valid Accuracy: 0.412
# Epoch 16, CIFAR-10 Batch 1:  Cost:     1.5666 Valid Accuracy: 0.418
# Epoch 16, CIFAR-10 Batch 2:  Cost:     1.5762 Valid Accuracy: 0.43
# Epoch 16, CIFAR-10 Batch 3:  Cost:     1.5418 Valid Accuracy: 0.426
# Epoch 16, CIFAR-10 Batch 4:  Cost:     1.5644 Valid Accuracy: 0.42
# Epoch 16, CIFAR-10 Batch 5:  Cost:     1.5472 Valid Accuracy: 0.437
# Epoch 17, CIFAR-10 Batch 1:  Cost:     1.5244 Valid Accuracy: 0.438
# Epoch 17, CIFAR-10 Batch 2:  Cost:     1.5360 Valid Accuracy: 0.438
# Epoch 17, CIFAR-10 Batch 3:  Cost:     1.5056 Valid Accuracy: 0.435
# Epoch 17, CIFAR-10 Batch 4:  Cost:     1.5278 Valid Accuracy: 0.439
# Epoch 17, CIFAR-10 Batch 5:  Cost:     1.5306 Valid Accuracy: 0.438
# Epoch 18, CIFAR-10 Batch 1:  Cost:     1.4825 Valid Accuracy: 0.451
# Epoch 18, CIFAR-10 Batch 2:  Cost:     1.5065 Valid Accuracy: 0.447
# Epoch 18, CIFAR-10 Batch 3:  Cost:     1.4654 Valid Accuracy: 0.453
# Epoch 18, CIFAR-10 Batch 4:  Cost:     1.5048 Valid Accuracy: 0.45
# Epoch 18, CIFAR-10 Batch 5:  Cost:     1.5222 Valid Accuracy: 0.443
# Epoch 19, CIFAR-10 Batch 1:  Cost:     1.5650 Valid Accuracy: 0.419
# Epoch 19, CIFAR-10 Batch 2:  Cost:     1.7106 Valid Accuracy: 0.406
# Epoch 19, CIFAR-10 Batch 3:  Cost:     1.6006 Valid Accuracy: 0.416
# Epoch 19, CIFAR-10 Batch 4:  Cost:     1.5343 Valid Accuracy: 0.428
# Epoch 19, CIFAR-10 Batch 5:  Cost:     1.6078 Valid Accuracy: 0.431
# Epoch 20, CIFAR-10 Batch 1:  Cost:     1.4680 Valid Accuracy: 0.449
# Epoch 20, CIFAR-10 Batch 2:  Cost:     1.5755 Valid Accuracy: 0.431
# Epoch 20, CIFAR-10 Batch 3:  Cost:     1.4790 Valid Accuracy: 0.459
# Epoch 20, CIFAR-10 Batch 4:  Cost:     1.5393 Valid Accuracy: 0.44
# Epoch 20, CIFAR-10 Batch 5:  Cost:     1.5207 Valid Accuracy: 0.448
# Epoch 21, CIFAR-10 Batch 1:  Cost:     1.4779 Valid Accuracy: 0.45
# Epoch 21, CIFAR-10 Batch 2:  Cost:     1.5092 Valid Accuracy: 0.452
# Epoch 21, CIFAR-10 Batch 3:  Cost:     1.4694 Valid Accuracy: 0.45
# Epoch 21, CIFAR-10 Batch 4:  Cost:     1.4926 Valid Accuracy: 0.452
# Epoch 21, CIFAR-10 Batch 5:  Cost:     1.4969 Valid Accuracy: 0.448
# Epoch 22, CIFAR-10 Batch 1:  Cost:     1.4373 Valid Accuracy: 0.464
# Epoch 22, CIFAR-10 Batch 2:  Cost:     1.4764 Valid Accuracy: 0.462
# Epoch 22, CIFAR-10 Batch 3:  Cost:     1.4318 Valid Accuracy: 0.465
# Epoch 22, CIFAR-10 Batch 4:  Cost:     1.4681 Valid Accuracy: 0.452
# Epoch 22, CIFAR-10 Batch 5:  Cost:     1.4443 Valid Accuracy: 0.472
# Epoch 23, CIFAR-10 Batch 1:  Cost:     1.4281 Valid Accuracy: 0.469
# Epoch 23, CIFAR-10 Batch 2:  Cost:     1.4404 Valid Accuracy: 0.47
# Epoch 23, CIFAR-10 Batch 3:  Cost:     1.4086 Valid Accuracy: 0.472
# Epoch 23, CIFAR-10 Batch 4:  Cost:     1.4211 Valid Accuracy: 0.477
# Epoch 23, CIFAR-10 Batch 5:  Cost:     1.4328 Valid Accuracy: 0.47
# Epoch 24, CIFAR-10 Batch 1:  Cost:     1.4005 Valid Accuracy: 0.483
# Epoch 24, CIFAR-10 Batch 2:  Cost:     1.4189 Valid Accuracy: 0.474
# Epoch 24, CIFAR-10 Batch 3:  Cost:     1.3740 Valid Accuracy: 0.485
# Epoch 24, CIFAR-10 Batch 4:  Cost:     1.4035 Valid Accuracy: 0.488
# Epoch 24, CIFAR-10 Batch 5:  Cost:     1.4109 Valid Accuracy: 0.474
# Epoch 25, CIFAR-10 Batch 1:  Cost:     1.3864 Valid Accuracy: 0.479
# Epoch 25, CIFAR-10 Batch 2:  Cost:     1.4028 Valid Accuracy: 0.481
# Epoch 25, CIFAR-10 Batch 3:  Cost:     1.3681 Valid Accuracy: 0.485
# Epoch 25, CIFAR-10 Batch 4:  Cost:     1.3947 Valid Accuracy: 0.489
# Epoch 25, CIFAR-10 Batch 5:  Cost:     1.4336 Valid Accuracy: 0.471
# Epoch 26, CIFAR-10 Batch 1:  Cost:     1.3801 Valid Accuracy: 0.484
# Epoch 26, CIFAR-10 Batch 2:  Cost:     1.3959 Valid Accuracy: 0.484
# Epoch 26, CIFAR-10 Batch 3:  Cost:     1.4221 Valid Accuracy: 0.456
# Epoch 26, CIFAR-10 Batch 4:  Cost:     1.3792 Valid Accuracy: 0.484
# Epoch 26, CIFAR-10 Batch 5:  Cost:     1.4606 Valid Accuracy: 0.467
# Epoch 27, CIFAR-10 Batch 1:  Cost:     1.4438 Valid Accuracy: 0.455
# Epoch 27, CIFAR-10 Batch 2:  Cost:     1.4998 Valid Accuracy: 0.44
# Epoch 27, CIFAR-10 Batch 3:  Cost:     1.3837 Valid Accuracy: 0.488
# Epoch 27, CIFAR-10 Batch 4:  Cost:     1.4714 Valid Accuracy: 0.466
# Epoch 27, CIFAR-10 Batch 5:  Cost:     1.4159 Valid Accuracy: 0.479
# Epoch 28, CIFAR-10 Batch 1:  Cost:     1.4098 Valid Accuracy: 0.466
# Epoch 28, CIFAR-10 Batch 2:  Cost:     1.4384 Valid Accuracy: 0.459
# Epoch 28, CIFAR-10 Batch 3:  Cost:     1.3637 Valid Accuracy: 0.48
# Epoch 28, CIFAR-10 Batch 4:  Cost:     1.4206 Valid Accuracy: 0.477
# Epoch 28, CIFAR-10 Batch 5:  Cost:     1.4070 Valid Accuracy: 0.485
# Epoch 29, CIFAR-10 Batch 1:  Cost:     1.3634 Valid Accuracy: 0.483
# Epoch 29, CIFAR-10 Batch 2:  Cost:     1.3998 Valid Accuracy: 0.483
# Epoch 29, CIFAR-10 Batch 3:  Cost:     1.3543 Valid Accuracy: 0.483
# Epoch 29, CIFAR-10 Batch 4:  Cost:     1.3822 Valid Accuracy: 0.48
# Epoch 29, CIFAR-10 Batch 5:  Cost:     1.3874 Valid Accuracy: 0.488
# Epoch 30, CIFAR-10 Batch 1:  Cost:     1.3571 Valid Accuracy: 0.494
# Epoch 30, CIFAR-10 Batch 2:  Cost:     1.3977 Valid Accuracy: 0.485
# Epoch 30, CIFAR-10 Batch 3:  Cost:     1.3411 Valid Accuracy: 0.497
# Epoch 30, CIFAR-10 Batch 4:  Cost:     1.3651 Valid Accuracy: 0.485
# Epoch 30, CIFAR-10 Batch 5:  Cost:     1.3524 Valid Accuracy: 0.492
# Epoch 31, CIFAR-10 Batch 1:  Cost:     1.3402 Valid Accuracy: 0.506
# Epoch 31, CIFAR-10 Batch 2:  Cost:     1.3706 Valid Accuracy: 0.498
# Epoch 31, CIFAR-10 Batch 3:  Cost:     1.3004 Valid Accuracy: 0.51
# Epoch 31, CIFAR-10 Batch 4:  Cost:     1.3306 Valid Accuracy: 0.502
# Epoch 31, CIFAR-10 Batch 5:  Cost:     1.3473 Valid Accuracy: 0.495
# Epoch 32, CIFAR-10 Batch 1:  Cost:     1.3113 Valid Accuracy: 0.505
# Epoch 32, CIFAR-10 Batch 2:  Cost:     1.3339 Valid Accuracy: 0.509
# Epoch 32, CIFAR-10 Batch 3:  Cost:     1.2958 Valid Accuracy: 0.513
# Epoch 32, CIFAR-10 Batch 4:  Cost:     1.3262 Valid Accuracy: 0.506
# Epoch 32, CIFAR-10 Batch 5:  Cost:     1.3474 Valid Accuracy: 0.501
# Epoch 33, CIFAR-10 Batch 1:  Cost:     1.2952 Valid Accuracy: 0.501
# Epoch 33, CIFAR-10 Batch 2:  Cost:     1.3062 Valid Accuracy: 0.514
# Epoch 33, CIFAR-10 Batch 3:  Cost:     1.2947 Valid Accuracy: 0.516
# Epoch 33, CIFAR-10 Batch 4:  Cost:     1.3082 Valid Accuracy: 0.512
# Epoch 33, CIFAR-10 Batch 5:  Cost:     1.2908 Valid Accuracy: 0.52
# Epoch 34, CIFAR-10 Batch 1:  Cost:     1.2834 Valid Accuracy: 0.505
# Epoch 34, CIFAR-10 Batch 2:  Cost:     1.3000 Valid Accuracy: 0.52
# Epoch 34, CIFAR-10 Batch 3:  Cost:     1.2670 Valid Accuracy: 0.517
# Epoch 34, CIFAR-10 Batch 4:  Cost:     1.2905 Valid Accuracy: 0.519
# Epoch 34, CIFAR-10 Batch 5:  Cost:     1.2789 Valid Accuracy: 0.521
# Epoch 35, CIFAR-10 Batch 1:  Cost:     1.2600 Valid Accuracy: 0.513
# Epoch 35, CIFAR-10 Batch 2:  Cost:     1.2968 Valid Accuracy: 0.515
# Epoch 35, CIFAR-10 Batch 3:  Cost:     1.2650 Valid Accuracy: 0.512
# Epoch 35, CIFAR-10 Batch 4:  Cost:     1.2792 Valid Accuracy: 0.526
# Epoch 35, CIFAR-10 Batch 5:  Cost:     1.2675 Valid Accuracy: 0.523
# Epoch 36, CIFAR-10 Batch 1:  Cost:     1.2490 Valid Accuracy: 0.52
# Epoch 36, CIFAR-10 Batch 2:  Cost:     1.2844 Valid Accuracy: 0.524
# Epoch 36, CIFAR-10 Batch 3:  Cost:     1.2650 Valid Accuracy: 0.526
# Epoch 36, CIFAR-10 Batch 4:  Cost:     1.3130 Valid Accuracy: 0.511
# Epoch 36, CIFAR-10 Batch 5:  Cost:     1.3693 Valid Accuracy: 0.499
# Epoch 37, CIFAR-10 Batch 1:  Cost:     1.3584 Valid Accuracy: 0.482
# Epoch 37, CIFAR-10 Batch 2:  Cost:     1.2698 Valid Accuracy: 0.522
# Epoch 37, CIFAR-10 Batch 3:  Cost:     1.3192 Valid Accuracy: 0.503
# Epoch 37, CIFAR-10 Batch 4:  Cost:     1.3672 Valid Accuracy: 0.491
# Epoch 37, CIFAR-10 Batch 5:  Cost:     1.3040 Valid Accuracy: 0.512
# Epoch 38, CIFAR-10 Batch 1:  Cost:     1.3399 Valid Accuracy: 0.503
# Epoch 38, CIFAR-10 Batch 2:  Cost:     1.3254 Valid Accuracy: 0.502
# Epoch 38, CIFAR-10 Batch 3:  Cost:     1.2746 Valid Accuracy: 0.518
# Epoch 38, CIFAR-10 Batch 4:  Cost:     1.3473 Valid Accuracy: 0.496
# Epoch 38, CIFAR-10 Batch 5:  Cost:     1.2782 Valid Accuracy: 0.527
# Epoch 39, CIFAR-10 Batch 1:  Cost:     1.3108 Valid Accuracy: 0.495
# Epoch 39, CIFAR-10 Batch 2:  Cost:     1.2886 Valid Accuracy: 0.52
# Epoch 39, CIFAR-10 Batch 3:  Cost:     1.2524 Valid Accuracy: 0.521
# Epoch 39, CIFAR-10 Batch 4:  Cost:     1.2794 Valid Accuracy: 0.519
# Epoch 39, CIFAR-10 Batch 5:  Cost:     1.2514 Valid Accuracy: 0.522
# Epoch 40, CIFAR-10 Batch 1:  Cost:     1.2430 Valid Accuracy: 0.527
# Epoch 40, CIFAR-10 Batch 2:  Cost:     1.2547 Valid Accuracy: 0.534
# Epoch 40, CIFAR-10 Batch 3:  Cost:     1.2245 Valid Accuracy: 0.53
# Epoch 40, CIFAR-10 Batch 4:  Cost:     1.2434 Valid Accuracy: 0.533
# Epoch 40, CIFAR-10 Batch 5:  Cost:     1.2396 Valid Accuracy: 0.535
# Epoch 41, CIFAR-10 Batch 1:  Cost:     1.2275 Valid Accuracy: 0.523
# Epoch 41, CIFAR-10 Batch 2:  Cost:     1.2416 Valid Accuracy: 0.536
# Epoch 41, CIFAR-10 Batch 3:  Cost:     1.2029 Valid Accuracy: 0.539
# Epoch 41, CIFAR-10 Batch 4:  Cost:     1.2409 Valid Accuracy: 0.528
# Epoch 41, CIFAR-10 Batch 5:  Cost:     1.2416 Valid Accuracy: 0.537
# Epoch 42, CIFAR-10 Batch 1:  Cost:     1.2402 Valid Accuracy: 0.53
# Epoch 42, CIFAR-10 Batch 2:  Cost:     1.2311 Valid Accuracy: 0.541
# Epoch 42, CIFAR-10 Batch 3:  Cost:     1.1827 Valid Accuracy: 0.545
# Epoch 42, CIFAR-10 Batch 4:  Cost:     1.2414 Valid Accuracy: 0.531
# Epoch 42, CIFAR-10 Batch 5:  Cost:     1.2579 Valid Accuracy: 0.532
# Epoch 43, CIFAR-10 Batch 1:  Cost:     1.2099 Valid Accuracy: 0.532
# Epoch 43, CIFAR-10 Batch 2:  Cost:     1.2193 Valid Accuracy: 0.539
# Epoch 43, CIFAR-10 Batch 3:  Cost:     1.2380 Valid Accuracy: 0.531
# Epoch 43, CIFAR-10 Batch 4:  Cost:     1.2378 Valid Accuracy: 0.523
# Epoch 43, CIFAR-10 Batch 5:  Cost:     1.2151 Valid Accuracy: 0.543
# Epoch 44, CIFAR-10 Batch 1:  Cost:     1.2375 Valid Accuracy: 0.526
# Epoch 44, CIFAR-10 Batch 2:  Cost:     1.2115 Valid Accuracy: 0.539
# Epoch 44, CIFAR-10 Batch 3:  Cost:     1.2125 Valid Accuracy: 0.526
# Epoch 44, CIFAR-10 Batch 4:  Cost:     1.2091 Valid Accuracy: 0.546
# Epoch 44, CIFAR-10 Batch 5:  Cost:     1.2039 Valid Accuracy: 0.545
# Epoch 45, CIFAR-10 Batch 1:  Cost:     1.1912 Valid Accuracy: 0.542
# Epoch 45, CIFAR-10 Batch 2:  Cost:     1.1876 Valid Accuracy: 0.551
# Epoch 45, CIFAR-10 Batch 3:  Cost:     1.1809 Valid Accuracy: 0.548
# Epoch 45, CIFAR-10 Batch 4:  Cost:     1.1812 Valid Accuracy: 0.545
# Epoch 45, CIFAR-10 Batch 5:  Cost:     1.1865 Valid Accuracy: 0.548
# Epoch 46, CIFAR-10 Batch 1:  Cost:     1.1539 Valid Accuracy: 0.552
# Epoch 46, CIFAR-10 Batch 2:  Cost:     1.1799 Valid Accuracy: 0.554
# Epoch 46, CIFAR-10 Batch 3:  Cost:     1.1505 Valid Accuracy: 0.551
# Epoch 46, CIFAR-10 Batch 4:  Cost:     1.1708 Valid Accuracy: 0.553
# Epoch 46, CIFAR-10 Batch 5:  Cost:     1.1790 Valid Accuracy: 0.551
# Epoch 47, CIFAR-10 Batch 1:  Cost:     1.1451 Valid Accuracy: 0.552
# Epoch 47, CIFAR-10 Batch 2:  Cost:     1.1710 Valid Accuracy: 0.553
# Epoch 47, CIFAR-10 Batch 3:  Cost:     1.1427 Valid Accuracy: 0.556
# Epoch 47, CIFAR-10 Batch 4:  Cost:     1.1635 Valid Accuracy: 0.553
# Epoch 47, CIFAR-10 Batch 5:  Cost:     1.1928 Valid Accuracy: 0.549
# Epoch 48, CIFAR-10 Batch 1:  Cost:     1.1496 Valid Accuracy: 0.553
# Epoch 48, CIFAR-10 Batch 2:  Cost:     1.1638 Valid Accuracy: 0.553
# Epoch 48, CIFAR-10 Batch 3:  Cost:     1.1321 Valid Accuracy: 0.56
# Epoch 48, CIFAR-10 Batch 4:  Cost:     1.1581 Valid Accuracy: 0.553
# Epoch 48, CIFAR-10 Batch 5:  Cost:     1.1704 Valid Accuracy: 0.549
# Epoch 49, CIFAR-10 Batch 1:  Cost:     1.1344 Valid Accuracy: 0.558
# Epoch 49, CIFAR-10 Batch 2:  Cost:     1.1431 Valid Accuracy: 0.565
# Epoch 49, CIFAR-10 Batch 3:  Cost:     1.1200 Valid Accuracy: 0.559
# Epoch 49, CIFAR-10 Batch 4:  Cost:     1.1557 Valid Accuracy: 0.554
# Epoch 49, CIFAR-10 Batch 5:  Cost:     1.1490 Valid Accuracy: 0.558
# Epoch 50, CIFAR-10 Batch 1:  Cost:     1.1057 Valid Accuracy: 0.566
# Epoch 50, CIFAR-10 Batch 2:  Cost:     1.1477 Valid Accuracy: 0.554
# Epoch 50, CIFAR-10 Batch 3:  Cost:     1.1460 Valid Accuracy: 0.549
# Epoch 50, CIFAR-10 Batch 4:  Cost:     1.1277 Valid Accuracy: 0.564
# Epoch 50, CIFAR-10 Batch 5:  Cost:     1.1415 Valid Accuracy: 0.554
# Epoch 51, CIFAR-10 Batch 1:  Cost:     1.1694 Valid Accuracy: 0.546
# Epoch 51, CIFAR-10 Batch 2:  Cost:     1.1392 Valid Accuracy: 0.562
# Epoch 51, CIFAR-10 Batch 3:  Cost:     1.1740 Valid Accuracy: 0.53
# Epoch 51, CIFAR-10 Batch 4:  Cost:     1.1909 Valid Accuracy: 0.549
# Epoch 51, CIFAR-10 Batch 5:  Cost:     1.2355 Valid Accuracy: 0.53
# Epoch 52, CIFAR-10 Batch 1:  Cost:     1.1320 Valid Accuracy: 0.557
# Epoch 52, CIFAR-10 Batch 2:  Cost:     1.2393 Valid Accuracy: 0.53
# Epoch 52, CIFAR-10 Batch 3:  Cost:     1.1972 Valid Accuracy: 0.527
# Epoch 52, CIFAR-10 Batch 4:  Cost:     1.2816 Valid Accuracy: 0.515
# Epoch 52, CIFAR-10 Batch 5:  Cost:     1.1868 Valid Accuracy: 0.545
# Epoch 53, CIFAR-10 Batch 1:  Cost:     1.1664 Valid Accuracy: 0.541
# Epoch 53, CIFAR-10 Batch 2:  Cost:     1.1938 Valid Accuracy: 0.539
# Epoch 53, CIFAR-10 Batch 3:  Cost:     1.1467 Valid Accuracy: 0.546
# Epoch 53, CIFAR-10 Batch 4:  Cost:     1.1932 Valid Accuracy: 0.546
# Epoch 53, CIFAR-10 Batch 5:  Cost:     1.1614 Valid Accuracy: 0.558
# Epoch 54, CIFAR-10 Batch 1:  Cost:     1.1647 Valid Accuracy: 0.538
# Epoch 54, CIFAR-10 Batch 2:  Cost:     1.1580 Valid Accuracy: 0.556
# Epoch 54, CIFAR-10 Batch 3:  Cost:     1.1222 Valid Accuracy: 0.558
# Epoch 54, CIFAR-10 Batch 4:  Cost:     1.1671 Valid Accuracy: 0.547
# Epoch 54, CIFAR-10 Batch 5:  Cost:     1.1369 Valid Accuracy: 0.563
# Epoch 55, CIFAR-10 Batch 1:  Cost:     1.1207 Valid Accuracy: 0.557
# Epoch 55, CIFAR-10 Batch 2:  Cost:     1.1317 Valid Accuracy: 0.56
# Epoch 55, CIFAR-10 Batch 3:  Cost:     1.1029 Valid Accuracy: 0.567
# Epoch 55, CIFAR-10 Batch 4:  Cost:     1.1116 Valid Accuracy: 0.568
# Epoch 55, CIFAR-10 Batch 5:  Cost:     1.1163 Valid Accuracy: 0.565
# Epoch 56, CIFAR-10 Batch 1:  Cost:     1.0768 Valid Accuracy: 0.567
# Epoch 56, CIFAR-10 Batch 2:  Cost:     1.1007 Valid Accuracy: 0.568
# Epoch 56, CIFAR-10 Batch 3:  Cost:     1.0783 Valid Accuracy: 0.568
# Epoch 56, CIFAR-10 Batch 4:  Cost:     1.0899 Valid Accuracy: 0.577
# Epoch 56, CIFAR-10 Batch 5:  Cost:     1.0867 Valid Accuracy: 0.568
# Epoch 57, CIFAR-10 Batch 1:  Cost:     1.0639 Valid Accuracy: 0.574
# Epoch 57, CIFAR-10 Batch 2:  Cost:     1.0835 Valid Accuracy: 0.576
# Epoch 57, CIFAR-10 Batch 3:  Cost:     1.0516 Valid Accuracy: 0.578
# Epoch 57, CIFAR-10 Batch 4:  Cost:     1.0882 Valid Accuracy: 0.573
# Epoch 57, CIFAR-10 Batch 5:  Cost:     1.0720 Valid Accuracy: 0.578
# Epoch 58, CIFAR-10 Batch 1:  Cost:     1.0534 Valid Accuracy: 0.579
# Epoch 58, CIFAR-10 Batch 2:  Cost:     1.0721 Valid Accuracy: 0.576
# Epoch 58, CIFAR-10 Batch 3:  Cost:     1.0377 Valid Accuracy: 0.579
# Epoch 58, CIFAR-10 Batch 4:  Cost:     1.0750 Valid Accuracy: 0.573
# Epoch 58, CIFAR-10 Batch 5:  Cost:     1.0728 Valid Accuracy: 0.578
# Epoch 59, CIFAR-10 Batch 1:  Cost:     1.0813 Valid Accuracy: 0.563
# Epoch 59, CIFAR-10 Batch 2:  Cost:     1.1817 Valid Accuracy: 0.541
# Epoch 59, CIFAR-10 Batch 3:  Cost:     1.1836 Valid Accuracy: 0.541
# Epoch 59, CIFAR-10 Batch 4:  Cost:     1.1100 Valid Accuracy: 0.561
# Epoch 59, CIFAR-10 Batch 5:  Cost:     1.1667 Valid Accuracy: 0.538
# Epoch 60, CIFAR-10 Batch 1:  Cost:     1.2002 Valid Accuracy: 0.537
# Epoch 60, CIFAR-10 Batch 2:  Cost:     1.1891 Valid Accuracy: 0.541
# Epoch 60, CIFAR-10 Batch 3:  Cost:     1.0955 Valid Accuracy: 0.562
# Epoch 60, CIFAR-10 Batch 4:  Cost:     1.1387 Valid Accuracy: 0.558
# Epoch 60, CIFAR-10 Batch 5:  Cost:     1.0967 Valid Accuracy: 0.564
# Epoch 61, CIFAR-10 Batch 1:  Cost:     1.1406 Valid Accuracy: 0.549
# Epoch 61, CIFAR-10 Batch 2:  Cost:     1.0995 Valid Accuracy: 0.571
# Epoch 61, CIFAR-10 Batch 3:  Cost:     1.0871 Valid Accuracy: 0.564
# Epoch 61, CIFAR-10 Batch 4:  Cost:     1.1397 Valid Accuracy: 0.559
# Epoch 61, CIFAR-10 Batch 5:  Cost:     1.0838 Valid Accuracy: 0.574
# Epoch 62, CIFAR-10 Batch 1:  Cost:     1.0776 Valid Accuracy: 0.564
# Epoch 62, CIFAR-10 Batch 2:  Cost:     1.1045 Valid Accuracy: 0.564
# Epoch 62, CIFAR-10 Batch 3:  Cost:     1.0526 Valid Accuracy: 0.574
# Epoch 62, CIFAR-10 Batch 4:  Cost:     1.0877 Valid Accuracy: 0.574
# Epoch 62, CIFAR-10 Batch 5:  Cost:     1.0707 Valid Accuracy: 0.575
# Epoch 63, CIFAR-10 Batch 1:  Cost:     1.0342 Valid Accuracy: 0.581
# Epoch 63, CIFAR-10 Batch 2:  Cost:     1.0695 Valid Accuracy: 0.577
# Epoch 63, CIFAR-10 Batch 3:  Cost:     1.0259 Valid Accuracy: 0.58
# Epoch 63, CIFAR-10 Batch 4:  Cost:     1.0600 Valid Accuracy: 0.575
# Epoch 63, CIFAR-10 Batch 5:  Cost:     1.0543 Valid Accuracy: 0.577
# Epoch 64, CIFAR-10 Batch 1:  Cost:     1.0093 Valid Accuracy: 0.588
# Epoch 64, CIFAR-10 Batch 2:  Cost:     1.0469 Valid Accuracy: 0.582
# Epoch 64, CIFAR-10 Batch 3:  Cost:     1.0135 Valid Accuracy: 0.579
# Epoch 64, CIFAR-10 Batch 4:  Cost:     1.0457 Valid Accuracy: 0.578
# Epoch 64, CIFAR-10 Batch 5:  Cost:     1.0390 Valid Accuracy: 0.578
# Epoch 65, CIFAR-10 Batch 1:  Cost:     1.0113 Valid Accuracy: 0.586
# Epoch 65, CIFAR-10 Batch 2:  Cost:     1.0400 Valid Accuracy: 0.58
# Epoch 65, CIFAR-10 Batch 3:  Cost:     0.9950 Valid Accuracy: 0.587
# Epoch 65, CIFAR-10 Batch 4:  Cost:     1.0361 Valid Accuracy: 0.579
# Epoch 65, CIFAR-10 Batch 5:  Cost:     1.0296 Valid Accuracy: 0.582
# Epoch 66, CIFAR-10 Batch 1:  Cost:     1.0159 Valid Accuracy: 0.587
# Epoch 66, CIFAR-10 Batch 2:  Cost:     1.0502 Valid Accuracy: 0.573
# Epoch 66, CIFAR-10 Batch 3:  Cost:     1.0052 Valid Accuracy: 0.585
# Epoch 66, CIFAR-10 Batch 4:  Cost:     1.0425 Valid Accuracy: 0.574
# Epoch 66, CIFAR-10 Batch 5:  Cost:     1.0239 Valid Accuracy: 0.581
# Epoch 67, CIFAR-10 Batch 1:  Cost:     0.9949 Valid Accuracy: 0.588
# Epoch 67, CIFAR-10 Batch 2:  Cost:     1.0445 Valid Accuracy: 0.569
# Epoch 67, CIFAR-10 Batch 3:  Cost:     1.0237 Valid Accuracy: 0.577
# Epoch 67, CIFAR-10 Batch 4:  Cost:     1.0374 Valid Accuracy: 0.577
# Epoch 67, CIFAR-10 Batch 5:  Cost:     1.0529 Valid Accuracy: 0.56
# Epoch 68, CIFAR-10 Batch 1:  Cost:     1.0567 Valid Accuracy: 0.568
# Epoch 68, CIFAR-10 Batch 2:  Cost:     1.0087 Valid Accuracy: 0.592
# Epoch 68, CIFAR-10 Batch 3:  Cost:     1.0646 Valid Accuracy: 0.55
# Epoch 68, CIFAR-10 Batch 4:  Cost:     1.0693 Valid Accuracy: 0.575
# Epoch 68, CIFAR-10 Batch 5:  Cost:     1.0503 Valid Accuracy: 0.575
# Epoch 69, CIFAR-10 Batch 1:  Cost:     1.0474 Valid Accuracy: 0.564
# Epoch 69, CIFAR-10 Batch 2:  Cost:     1.0508 Valid Accuracy: 0.568
# Epoch 69, CIFAR-10 Batch 3:  Cost:     1.0494 Valid Accuracy: 0.572
# Epoch 69, CIFAR-10 Batch 4:  Cost:     1.0878 Valid Accuracy: 0.561
# Epoch 69, CIFAR-10 Batch 5:  Cost:     1.0036 Valid Accuracy: 0.581
# Epoch 70, CIFAR-10 Batch 1:  Cost:     1.0469 Valid Accuracy: 0.561
# Epoch 70, CIFAR-10 Batch 2:  Cost:     1.0298 Valid Accuracy: 0.585
# Epoch 70, CIFAR-10 Batch 3:  Cost:     1.0164 Valid Accuracy: 0.58
# Epoch 70, CIFAR-10 Batch 4:  Cost:     1.0165 Valid Accuracy: 0.588
# Epoch 70, CIFAR-10 Batch 5:  Cost:     1.0489 Valid Accuracy: 0.57
# Epoch 71, CIFAR-10 Batch 1:  Cost:     0.9879 Valid Accuracy: 0.588
# Epoch 71, CIFAR-10 Batch 2:  Cost:     1.0255 Valid Accuracy: 0.582
# Epoch 71, CIFAR-10 Batch 3:  Cost:     0.9775 Valid Accuracy: 0.587
# Epoch 71, CIFAR-10 Batch 4:  Cost:     0.9923 Valid Accuracy: 0.59
# Epoch 71, CIFAR-10 Batch 5:  Cost:     0.9809 Valid Accuracy: 0.588
# Epoch 72, CIFAR-10 Batch 1:  Cost:     0.9713 Valid Accuracy: 0.589
# Epoch 72, CIFAR-10 Batch 2:  Cost:     0.9758 Valid Accuracy: 0.596
# Epoch 72, CIFAR-10 Batch 3:  Cost:     0.9571 Valid Accuracy: 0.589
# Epoch 72, CIFAR-10 Batch 4:  Cost:     0.9779 Valid Accuracy: 0.592
# Epoch 72, CIFAR-10 Batch 5:  Cost:     0.9585 Valid Accuracy: 0.594
# Epoch 73, CIFAR-10 Batch 1:  Cost:     0.9630 Valid Accuracy: 0.593
# Epoch 73, CIFAR-10 Batch 2:  Cost:     0.9707 Valid Accuracy: 0.597
# Epoch 73, CIFAR-10 Batch 3:  Cost:     0.9378 Valid Accuracy: 0.595
# Epoch 73, CIFAR-10 Batch 4:  Cost:     0.9721 Valid Accuracy: 0.59
# Epoch 73, CIFAR-10 Batch 5:  Cost:     0.9642 Valid Accuracy: 0.591
# Epoch 74, CIFAR-10 Batch 1:  Cost:     0.9628 Valid Accuracy: 0.582
# Epoch 74, CIFAR-10 Batch 2:  Cost:     0.9815 Valid Accuracy: 0.582
# Epoch 74, CIFAR-10 Batch 3:  Cost:     0.9858 Valid Accuracy: 0.585
# Epoch 74, CIFAR-10 Batch 4:  Cost:     1.0484 Valid Accuracy: 0.57
# Epoch 74, CIFAR-10 Batch 5:  Cost:     1.0246 Valid Accuracy: 0.563
# Epoch 75, CIFAR-10 Batch 1:  Cost:     0.9763 Valid Accuracy: 0.586
# Epoch 75, CIFAR-10 Batch 2:  Cost:     1.0053 Valid Accuracy: 0.579
# Epoch 75, CIFAR-10 Batch 3:  Cost:     0.9776 Valid Accuracy: 0.581
# Epoch 75, CIFAR-10 Batch 4:  Cost:     0.9834 Valid Accuracy: 0.593
# Epoch 75, CIFAR-10 Batch 5:  Cost:     0.9813 Valid Accuracy: 0.585
# Epoch 76, CIFAR-10 Batch 1:  Cost:     0.9683 Valid Accuracy: 0.591
# Epoch 76, CIFAR-10 Batch 2:  Cost:     0.9938 Valid Accuracy: 0.586
# Epoch 76, CIFAR-10 Batch 3:  Cost:     0.9587 Valid Accuracy: 0.583
# Epoch 76, CIFAR-10 Batch 4:  Cost:     0.9799 Valid Accuracy: 0.584
# Epoch 76, CIFAR-10 Batch 5:  Cost:     0.9634 Valid Accuracy: 0.59
# Epoch 77, CIFAR-10 Batch 1:  Cost:     0.9334 Valid Accuracy: 0.595
# Epoch 77, CIFAR-10 Batch 2:  Cost:     0.9400 Valid Accuracy: 0.593
# Epoch 77, CIFAR-10 Batch 3:  Cost:     0.9286 Valid Accuracy: 0.593
# Epoch 77, CIFAR-10 Batch 4:  Cost:     0.9413 Valid Accuracy: 0.602
# Epoch 77, CIFAR-10 Batch 5:  Cost:     0.9351 Valid Accuracy: 0.593
# Epoch 78, CIFAR-10 Batch 1:  Cost:     0.9028 Valid Accuracy: 0.605
# Epoch 78, CIFAR-10 Batch 2:  Cost:     0.9275 Valid Accuracy: 0.599
# Epoch 78, CIFAR-10 Batch 3:  Cost:     0.8961 Valid Accuracy: 0.604
# Epoch 78, CIFAR-10 Batch 4:  Cost:     0.9341 Valid Accuracy: 0.595
# Epoch 78, CIFAR-10 Batch 5:  Cost:     0.9049 Valid Accuracy: 0.6
# Epoch 79, CIFAR-10 Batch 1:  Cost:     0.8954 Valid Accuracy: 0.599
# Epoch 79, CIFAR-10 Batch 2:  Cost:     0.9017 Valid Accuracy: 0.606
# Epoch 79, CIFAR-10 Batch 3:  Cost:     0.8879 Valid Accuracy: 0.603
# Epoch 79, CIFAR-10 Batch 4:  Cost:     0.9076 Valid Accuracy: 0.603
# Epoch 79, CIFAR-10 Batch 5:  Cost:     0.9009 Valid Accuracy: 0.601
# Epoch 80, CIFAR-10 Batch 1:  Cost:     0.8957 Valid Accuracy: 0.598
# Epoch 80, CIFAR-10 Batch 2:  Cost:     0.9217 Valid Accuracy: 0.597
# Epoch 80, CIFAR-10 Batch 3:  Cost:     0.8937 Valid Accuracy: 0.603
# Epoch 80, CIFAR-10 Batch 4:  Cost:     0.9319 Valid Accuracy: 0.59
# Epoch 80, CIFAR-10 Batch 5:  Cost:     0.9024 Valid Accuracy: 0.604
# Epoch 81, CIFAR-10 Batch 1:  Cost:     0.8715 Valid Accuracy: 0.604
# Epoch 81, CIFAR-10 Batch 2:  Cost:     0.9061 Valid Accuracy: 0.6
# Epoch 81, CIFAR-10 Batch 3:  Cost:     0.9253 Valid Accuracy: 0.587
# Epoch 81, CIFAR-10 Batch 4:  Cost:     1.0044 Valid Accuracy: 0.575
# Epoch 81, CIFAR-10 Batch 5:  Cost:     1.0649 Valid Accuracy: 0.552
# Epoch 82, CIFAR-10 Batch 1:  Cost:     1.2129 Valid Accuracy: 0.53
# Epoch 82, CIFAR-10 Batch 2:  Cost:     1.1409 Valid Accuracy: 0.544
# Epoch 82, CIFAR-10 Batch 3:  Cost:     1.1978 Valid Accuracy: 0.505
# Epoch 82, CIFAR-10 Batch 4:  Cost:     1.0522 Valid Accuracy: 0.568
# Epoch 82, CIFAR-10 Batch 5:  Cost:     1.1849 Valid Accuracy: 0.518
# Epoch 83, CIFAR-10 Batch 1:  Cost:     1.0053 Valid Accuracy: 0.581
# Epoch 83, CIFAR-10 Batch 2:  Cost:     1.0414 Valid Accuracy: 0.566
# Epoch 83, CIFAR-10 Batch 3:  Cost:     1.0414 Valid Accuracy: 0.562
# Epoch 83, CIFAR-10 Batch 4:  Cost:     1.0411 Valid Accuracy: 0.576
# Epoch 83, CIFAR-10 Batch 5:  Cost:     1.0462 Valid Accuracy: 0.568
# Epoch 84, CIFAR-10 Batch 1:  Cost:     1.0413 Valid Accuracy: 0.569
# Epoch 84, CIFAR-10 Batch 2:  Cost:     0.9832 Valid Accuracy: 0.6
# Epoch 84, CIFAR-10 Batch 3:  Cost:     0.9807 Valid Accuracy: 0.585
# Epoch 84, CIFAR-10 Batch 4:  Cost:     1.0137 Valid Accuracy: 0.574
# Epoch 84, CIFAR-10 Batch 5:  Cost:     0.9835 Valid Accuracy: 0.586
# Epoch 85, CIFAR-10 Batch 1:  Cost:     0.9291 Valid Accuracy: 0.593
# Epoch 85, CIFAR-10 Batch 2:  Cost:     0.9640 Valid Accuracy: 0.587
# Epoch 85, CIFAR-10 Batch 3:  Cost:     0.9266 Valid Accuracy: 0.597
# Epoch 85, CIFAR-10 Batch 4:  Cost:     0.9507 Valid Accuracy: 0.597
# Epoch 85, CIFAR-10 Batch 5:  Cost:     0.9428 Valid Accuracy: 0.594
# Epoch 86, CIFAR-10 Batch 1:  Cost:     0.8911 Valid Accuracy: 0.603
# Epoch 86, CIFAR-10 Batch 2:  Cost:     0.9104 Valid Accuracy: 0.601
# Epoch 86, CIFAR-10 Batch 3:  Cost:     0.9048 Valid Accuracy: 0.597
# Epoch 86, CIFAR-10 Batch 4:  Cost:     0.9174 Valid Accuracy: 0.602
# Epoch 86, CIFAR-10 Batch 5:  Cost:     0.9090 Valid Accuracy: 0.595
# Epoch 87, CIFAR-10 Batch 1:  Cost:     0.8749 Valid Accuracy: 0.6
# Epoch 87, CIFAR-10 Batch 2:  Cost:     0.8764 Valid Accuracy: 0.608
# Epoch 87, CIFAR-10 Batch 3:  Cost:     0.8764 Valid Accuracy: 0.603
# Epoch 87, CIFAR-10 Batch 4:  Cost:     0.9218 Valid Accuracy: 0.592
# Epoch 87, CIFAR-10 Batch 5:  Cost:     0.9055 Valid Accuracy: 0.596
# Epoch 88, CIFAR-10 Batch 1:  Cost:     0.8640 Valid Accuracy: 0.602
# Epoch 88, CIFAR-10 Batch 2:  Cost:     0.8625 Valid Accuracy: 0.605
# Epoch 88, CIFAR-10 Batch 3:  Cost:     0.8834 Valid Accuracy: 0.589
# Epoch 88, CIFAR-10 Batch 4:  Cost:     0.8966 Valid Accuracy: 0.606
# Epoch 88, CIFAR-10 Batch 5:  Cost:     0.8550 Valid Accuracy: 0.604
# Epoch 89, CIFAR-10 Batch 1:  Cost:     0.8436 Valid Accuracy: 0.612
# Epoch 89, CIFAR-10 Batch 2:  Cost:     0.8822 Valid Accuracy: 0.603
# Epoch 89, CIFAR-10 Batch 3:  Cost:     0.8663 Valid Accuracy: 0.598
# Epoch 89, CIFAR-10 Batch 4:  Cost:     0.8579 Valid Accuracy: 0.61
# Epoch 89, CIFAR-10 Batch 5:  Cost:     0.8679 Valid Accuracy: 0.607
# Epoch 90, CIFAR-10 Batch 1:  Cost:     0.8676 Valid Accuracy: 0.603
# Epoch 90, CIFAR-10 Batch 2:  Cost:     0.8403 Valid Accuracy: 0.621
# Epoch 90, CIFAR-10 Batch 3:  Cost:     0.8717 Valid Accuracy: 0.593
# Epoch 90, CIFAR-10 Batch 4:  Cost:     0.9135 Valid Accuracy: 0.592
# Epoch 90, CIFAR-10 Batch 5:  Cost:     0.8400 Valid Accuracy: 0.608
# Epoch 91, CIFAR-10 Batch 1:  Cost:     0.8949 Valid Accuracy: 0.589
# Epoch 91, CIFAR-10 Batch 2:  Cost:     0.9387 Valid Accuracy: 0.578
# Epoch 91, CIFAR-10 Batch 3:  Cost:     0.9178 Valid Accuracy: 0.581
# Epoch 91, CIFAR-10 Batch 4:  Cost:     0.9061 Valid Accuracy: 0.599
# Epoch 91, CIFAR-10 Batch 5:  Cost:     0.8762 Valid Accuracy: 0.596
# Epoch 92, CIFAR-10 Batch 1:  Cost:     0.9035 Valid Accuracy: 0.59
# Epoch 92, CIFAR-10 Batch 2:  Cost:     0.8707 Valid Accuracy: 0.602
# Epoch 92, CIFAR-10 Batch 3:  Cost:     0.8780 Valid Accuracy: 0.6
# Epoch 92, CIFAR-10 Batch 4:  Cost:     0.9057 Valid Accuracy: 0.588
# Epoch 92, CIFAR-10 Batch 5:  Cost:     0.9257 Valid Accuracy: 0.578
# Epoch 93, CIFAR-10 Batch 1:  Cost:     0.8254 Valid Accuracy: 0.61
# Epoch 93, CIFAR-10 Batch 2:  Cost:     0.9085 Valid Accuracy: 0.578
# Epoch 93, CIFAR-10 Batch 3:  Cost:     0.8567 Valid Accuracy: 0.604
# Epoch 93, CIFAR-10 Batch 4:  Cost:     0.8657 Valid Accuracy: 0.605
# Epoch 93, CIFAR-10 Batch 5:  Cost:     0.8675 Valid Accuracy: 0.598
# Epoch 94, CIFAR-10 Batch 1:  Cost:     0.8271 Valid Accuracy: 0.605
# Epoch 94, CIFAR-10 Batch 2:  Cost:     0.8566 Valid Accuracy: 0.605
# Epoch 94, CIFAR-10 Batch 3:  Cost:     0.8159 Valid Accuracy: 0.611
# Epoch 94, CIFAR-10 Batch 4:  Cost:     0.8520 Valid Accuracy: 0.607
# Epoch 94, CIFAR-10 Batch 5:  Cost:     0.8141 Valid Accuracy: 0.614
# Epoch 95, CIFAR-10 Batch 1:  Cost:     0.8103 Valid Accuracy: 0.609
# Epoch 95, CIFAR-10 Batch 2:  Cost:     0.8335 Valid Accuracy: 0.606
# Epoch 95, CIFAR-10 Batch 3:  Cost:     0.8091 Valid Accuracy: 0.612
# Epoch 95, CIFAR-10 Batch 4:  Cost:     0.8231 Valid Accuracy: 0.615
# Epoch 95, CIFAR-10 Batch 5:  Cost:     0.8288 Valid Accuracy: 0.598
# Epoch 96, CIFAR-10 Batch 1:  Cost:     0.7844 Valid Accuracy: 0.613
# Epoch 96, CIFAR-10 Batch 2:  Cost:     0.8077 Valid Accuracy: 0.612
# Epoch 96, CIFAR-10 Batch 3:  Cost:     0.7975 Valid Accuracy: 0.608
# Epoch 96, CIFAR-10 Batch 4:  Cost:     0.8448 Valid Accuracy: 0.6
# Epoch 96, CIFAR-10 Batch 5:  Cost:     0.8430 Valid Accuracy: 0.606
# Epoch 97, CIFAR-10 Batch 1:  Cost:     0.7888 Valid Accuracy: 0.604
# Epoch 97, CIFAR-10 Batch 2:  Cost:     0.8062 Valid Accuracy: 0.605
# Epoch 97, CIFAR-10 Batch 3:  Cost:     0.7927 Valid Accuracy: 0.613
# Epoch 97, CIFAR-10 Batch 4:  Cost:     0.8142 Valid Accuracy: 0.608
# Epoch 97, CIFAR-10 Batch 5:  Cost:     0.7898 Valid Accuracy: 0.609
# Epoch 98, CIFAR-10 Batch 1:  Cost:     0.7853 Valid Accuracy: 0.609
# Epoch 98, CIFAR-10 Batch 2:  Cost:     0.7723 Valid Accuracy: 0.614
# Epoch 98, CIFAR-10 Batch 3:  Cost:     0.7651 Valid Accuracy: 0.616
# Epoch 98, CIFAR-10 Batch 4:  Cost:     0.7909 Valid Accuracy: 0.61
# Epoch 98, CIFAR-10 Batch 5:  Cost:     0.7560 Valid Accuracy: 0.619
# Epoch 99, CIFAR-10 Batch 1:  Cost:     0.7665 Valid Accuracy: 0.611
# Epoch 99, CIFAR-10 Batch 2:  Cost:     0.7720 Valid Accuracy: 0.612
# Epoch 99, CIFAR-10 Batch 3:  Cost:     0.7484 Valid Accuracy: 0.623
# Epoch 99, CIFAR-10 Batch 4:  Cost:     0.7763 Valid Accuracy: 0.61
# Epoch 99, CIFAR-10 Batch 5:  Cost:     0.7592 Valid Accuracy: 0.619
# Epoch 100, CIFAR-10 Batch 1:  Cost:     0.7520 Valid Accuracy: 0.617
# Epoch 100, CIFAR-10 Batch 2:  Cost:     0.7838 Valid Accuracy: 0.606
# Epoch 100, CIFAR-10 Batch 3:  Cost:     0.7619 Valid Accuracy: 0.609
# Epoch 100, CIFAR-10 Batch 4:  Cost:     0.7888 Valid Accuracy: 0.607
# Epoch 100, CIFAR-10 Batch 5:  Cost:     0.7757 Valid Accuracy: 0.609
# Epoch 101, CIFAR-10 Batch 1:  Cost:     0.7535 Valid Accuracy: 0.618
# Epoch 101, CIFAR-10 Batch 2:  Cost:     0.7599 Valid Accuracy: 0.619
# Epoch 101, CIFAR-10 Batch 3:  Cost:     0.7785 Valid Accuracy: 0.593
# Epoch 101, CIFAR-10 Batch 4:  Cost:     0.8037 Valid Accuracy: 0.609
# Epoch 101, CIFAR-10 Batch 5:  Cost:     0.7757 Valid Accuracy: 0.598
# Epoch 102, CIFAR-10 Batch 1:  Cost:     0.8535 Valid Accuracy: 0.583
# Epoch 102, CIFAR-10 Batch 2:  Cost:     0.8526 Valid Accuracy: 0.594
# Epoch 102, CIFAR-10 Batch 3:  Cost:     0.7900 Valid Accuracy: 0.599
# Epoch 102, CIFAR-10 Batch 4:  Cost:     0.8097 Valid Accuracy: 0.596
# Epoch 102, CIFAR-10 Batch 5:  Cost:     0.8126 Valid Accuracy: 0.598
# Epoch 103, CIFAR-10 Batch 1:  Cost:     0.8197 Valid Accuracy: 0.592
# Epoch 103, CIFAR-10 Batch 2:  Cost:     0.8610 Valid Accuracy: 0.574
# Epoch 103, CIFAR-10 Batch 3:  Cost:     0.8972 Valid Accuracy: 0.569
# Epoch 103, CIFAR-10 Batch 4:  Cost:     0.8960 Valid Accuracy: 0.578
# Epoch 103, CIFAR-10 Batch 5:  Cost:     0.8295 Valid Accuracy: 0.596
# Epoch 104, CIFAR-10 Batch 1:  Cost:     0.8171 Valid Accuracy: 0.587
# Epoch 104, CIFAR-10 Batch 2:  Cost:     0.7837 Valid Accuracy: 0.612
# Epoch 104, CIFAR-10 Batch 3:  Cost:     0.8122 Valid Accuracy: 0.603
# Epoch 104, CIFAR-10 Batch 4:  Cost:     0.8195 Valid Accuracy: 0.587
# Epoch 104, CIFAR-10 Batch 5:  Cost:     0.8121 Valid Accuracy: 0.6
# Epoch 105, CIFAR-10 Batch 1:  Cost:     0.7473 Valid Accuracy: 0.611
# Epoch 105, CIFAR-10 Batch 2:  Cost:     0.8099 Valid Accuracy: 0.603
# Epoch 105, CIFAR-10 Batch 3:  Cost:     0.7282 Valid Accuracy: 0.622
# Epoch 105, CIFAR-10 Batch 4:  Cost:     0.7803 Valid Accuracy: 0.601
# Epoch 105, CIFAR-10 Batch 5:  Cost:     0.7437 Valid Accuracy: 0.61
# Epoch 106, CIFAR-10 Batch 1:  Cost:     0.7271 Valid Accuracy: 0.62
# Epoch 106, CIFAR-10 Batch 2:  Cost:     0.7339 Valid Accuracy: 0.619
# Epoch 106, CIFAR-10 Batch 3:  Cost:     0.7178 Valid Accuracy: 0.621
# Epoch 106, CIFAR-10 Batch 4:  Cost:     0.7554 Valid Accuracy: 0.614
# Epoch 106, CIFAR-10 Batch 5:  Cost:     0.7266 Valid Accuracy: 0.618
# Epoch 107, CIFAR-10 Batch 1:  Cost:     0.7418 Valid Accuracy: 0.605
# Epoch 107, CIFAR-10 Batch 2:  Cost:     0.7221 Valid Accuracy: 0.616
# Epoch 107, CIFAR-10 Batch 3:  Cost:     0.7222 Valid Accuracy: 0.606
# Epoch 107, CIFAR-10 Batch 4:  Cost:     0.7676 Valid Accuracy: 0.593
# Epoch 107, CIFAR-10 Batch 5:  Cost:     0.8074 Valid Accuracy: 0.598
# Epoch 108, CIFAR-10 Batch 1:  Cost:     0.7838 Valid Accuracy: 0.595
# Epoch 108, CIFAR-10 Batch 2:  Cost:     0.8057 Valid Accuracy: 0.579
# Epoch 108, CIFAR-10 Batch 3:  Cost:     0.8944 Valid Accuracy: 0.575
# Epoch 108, CIFAR-10 Batch 4:  Cost:     0.8667 Valid Accuracy: 0.585
# Epoch 108, CIFAR-10 Batch 5:  Cost:     0.9193 Valid Accuracy: 0.545
# Epoch 109, CIFAR-10 Batch 1:  Cost:     0.8503 Valid Accuracy: 0.578
# Epoch 109, CIFAR-10 Batch 2:  Cost:     0.8721 Valid Accuracy: 0.576
# Epoch 109, CIFAR-10 Batch 3:  Cost:     0.8335 Valid Accuracy: 0.584
# Epoch 109, CIFAR-10 Batch 4:  Cost:     0.8839 Valid Accuracy: 0.576
# Epoch 109, CIFAR-10 Batch 5:  Cost:     0.8794 Valid Accuracy: 0.571
# Epoch 110, CIFAR-10 Batch 1:  Cost:     0.8065 Valid Accuracy: 0.596
# Epoch 110, CIFAR-10 Batch 2:  Cost:     0.8362 Valid Accuracy: 0.591
# Epoch 110, CIFAR-10 Batch 3:  Cost:     0.7677 Valid Accuracy: 0.608
# Epoch 110, CIFAR-10 Batch 4:  Cost:     0.8407 Valid Accuracy: 0.594
# Epoch 110, CIFAR-10 Batch 5:  Cost:     0.7683 Valid Accuracy: 0.601
# Epoch 111, CIFAR-10 Batch 1:  Cost:     0.7635 Valid Accuracy: 0.605
# Epoch 111, CIFAR-10 Batch 2:  Cost:     0.7664 Valid Accuracy: 0.604
# Epoch 111, CIFAR-10 Batch 3:  Cost:     0.7523 Valid Accuracy: 0.604
# Epoch 111, CIFAR-10 Batch 4:  Cost:     0.7460 Valid Accuracy: 0.608
# Epoch 111, CIFAR-10 Batch 5:  Cost:     0.7318 Valid Accuracy: 0.618
# Epoch 112, CIFAR-10 Batch 1:  Cost:     0.7278 Valid Accuracy: 0.61
# Epoch 112, CIFAR-10 Batch 2:  Cost:     0.7162 Valid Accuracy: 0.615
# Epoch 112, CIFAR-10 Batch 3:  Cost:     0.7068 Valid Accuracy: 0.612
# Epoch 112, CIFAR-10 Batch 4:  Cost:     0.7104 Valid Accuracy: 0.612
# Epoch 112, CIFAR-10 Batch 5:  Cost:     0.7126 Valid Accuracy: 0.613
# Epoch 113, CIFAR-10 Batch 1:  Cost:     0.6693 Valid Accuracy: 0.625
# Epoch 113, CIFAR-10 Batch 2:  Cost:     0.6970 Valid Accuracy: 0.61
# Epoch 113, CIFAR-10 Batch 3:  Cost:     0.6611 Valid Accuracy: 0.621
# Epoch 113, CIFAR-10 Batch 4:  Cost:     0.6912 Valid Accuracy: 0.616
# Epoch 113, CIFAR-10 Batch 5:  Cost:     0.6610 Valid Accuracy: 0.613
# Epoch 114, CIFAR-10 Batch 1:  Cost:     0.6660 Valid Accuracy: 0.615
# Epoch 114, CIFAR-10 Batch 2:  Cost:     0.6572 Valid Accuracy: 0.62
# Epoch 114, CIFAR-10 Batch 3:  Cost:     0.6467 Valid Accuracy: 0.619
# Epoch 114, CIFAR-10 Batch 4:  Cost:     0.6670 Valid Accuracy: 0.616
# Epoch 114, CIFAR-10 Batch 5:  Cost:     0.6424 Valid Accuracy: 0.613
# Epoch 115, CIFAR-10 Batch 1:  Cost:     0.6379 Valid Accuracy: 0.623
# Epoch 115, CIFAR-10 Batch 2:  Cost:     0.6365 Valid Accuracy: 0.619
# Epoch 115, CIFAR-10 Batch 3:  Cost:     0.6250 Valid Accuracy: 0.621
# Epoch 115, CIFAR-10 Batch 4:  Cost:     0.6485 Valid Accuracy: 0.615
# Epoch 115, CIFAR-10 Batch 5:  Cost:     0.6179 Valid Accuracy: 0.624
# Epoch 116, CIFAR-10 Batch 1:  Cost:     0.6242 Valid Accuracy: 0.624
# Epoch 116, CIFAR-10 Batch 2:  Cost:     0.6211 Valid Accuracy: 0.622
# Epoch 116, CIFAR-10 Batch 3:  Cost:     0.6063 Valid Accuracy: 0.623
# Epoch 116, CIFAR-10 Batch 4:  Cost:     0.6249 Valid Accuracy: 0.619
# Epoch 116, CIFAR-10 Batch 5:  Cost:     0.6033 Valid Accuracy: 0.617
# Epoch 117, CIFAR-10 Batch 1:  Cost:     0.6120 Valid Accuracy: 0.613
# Epoch 117, CIFAR-10 Batch 2:  Cost:     0.6235 Valid Accuracy: 0.621
# Epoch 117, CIFAR-10 Batch 3:  Cost:     0.6896 Valid Accuracy: 0.589
# Epoch 117, CIFAR-10 Batch 4:  Cost:     0.8342 Valid Accuracy: 0.58
# Epoch 117, CIFAR-10 Batch 5:  Cost:     0.9839 Valid Accuracy: 0.527
# Epoch 118, CIFAR-10 Batch 1:  Cost:     1.2625 Valid Accuracy: 0.514
# Epoch 118, CIFAR-10 Batch 2:  Cost:     1.2451 Valid Accuracy: 0.495
# Epoch 118, CIFAR-10 Batch 3:  Cost:     1.1327 Valid Accuracy: 0.507
# Epoch 118, CIFAR-10 Batch 4:  Cost:     1.6133 Valid Accuracy: 0.457
# Epoch 118, CIFAR-10 Batch 5:  Cost:     1.1350 Valid Accuracy: 0.489
# Epoch 119, CIFAR-10 Batch 1:  Cost:     1.2438 Valid Accuracy: 0.472
# Epoch 119, CIFAR-10 Batch 2:  Cost:     1.1889 Valid Accuracy: 0.498
# Epoch 119, CIFAR-10 Batch 3:  Cost:     1.0738 Valid Accuracy: 0.521
# Epoch 119, CIFAR-10 Batch 4:  Cost:     1.1401 Valid Accuracy: 0.503
# Epoch 119, CIFAR-10 Batch 5:  Cost:     1.0891 Valid Accuracy: 0.506
# Epoch 120, CIFAR-10 Batch 1:  Cost:     0.9736 Valid Accuracy: 0.57
# Epoch 120, CIFAR-10 Batch 2:  Cost:     1.0423 Valid Accuracy: 0.563
# Epoch 120, CIFAR-10 Batch 3:  Cost:     1.0445 Valid Accuracy: 0.551
# Epoch 120, CIFAR-10 Batch 4:  Cost:     0.9955 Valid Accuracy: 0.571
# Epoch 120, CIFAR-10 Batch 5:  Cost:     0.9963 Valid Accuracy: 0.566
# Epoch 121, CIFAR-10 Batch 1:  Cost:     0.9612 Valid Accuracy: 0.562
# Epoch 121, CIFAR-10 Batch 2:  Cost:     0.9403 Valid Accuracy: 0.577
# Epoch 121, CIFAR-10 Batch 3:  Cost:     0.9166 Valid Accuracy: 0.584
# Epoch 121, CIFAR-10 Batch 4:  Cost:     0.9257 Valid Accuracy: 0.58
# Epoch 121, CIFAR-10 Batch 5:  Cost:     0.8831 Valid Accuracy: 0.587
# Epoch 122, CIFAR-10 Batch 1:  Cost:     0.8674 Valid Accuracy: 0.577
# Epoch 122, CIFAR-10 Batch 2:  Cost:     0.8771 Valid Accuracy: 0.578
# Epoch 122, CIFAR-10 Batch 3:  Cost:     0.8113 Valid Accuracy: 0.595
# Epoch 122, CIFAR-10 Batch 4:  Cost:     0.8525 Valid Accuracy: 0.588
# Epoch 122, CIFAR-10 Batch 5:  Cost:     0.8020 Valid Accuracy: 0.6
# Epoch 123, CIFAR-10 Batch 1:  Cost:     0.7910 Valid Accuracy: 0.595
# Epoch 123, CIFAR-10 Batch 2:  Cost:     0.7901 Valid Accuracy: 0.594
# Epoch 123, CIFAR-10 Batch 3:  Cost:     0.7608 Valid Accuracy: 0.602
# Epoch 123, CIFAR-10 Batch 4:  Cost:     0.7727 Valid Accuracy: 0.606
# Epoch 123, CIFAR-10 Batch 5:  Cost:     0.7369 Valid Accuracy: 0.611
# Epoch 124, CIFAR-10 Batch 1:  Cost:     0.7246 Valid Accuracy: 0.599
# Epoch 124, CIFAR-10 Batch 2:  Cost:     0.7136 Valid Accuracy: 0.611
# Epoch 124, CIFAR-10 Batch 3:  Cost:     0.7027 Valid Accuracy: 0.608
# Epoch 124, CIFAR-10 Batch 4:  Cost:     0.6991 Valid Accuracy: 0.613
# Epoch 124, CIFAR-10 Batch 5:  Cost:     0.6875 Valid Accuracy: 0.61
# Epoch 125, CIFAR-10 Batch 1:  Cost:     0.6597 Valid Accuracy: 0.607
# Epoch 125, CIFAR-10 Batch 2:  Cost:     0.6683 Valid Accuracy: 0.609
# Epoch 125, CIFAR-10 Batch 3:  Cost:     0.6503 Valid Accuracy: 0.61
# Epoch 125, CIFAR-10 Batch 4:  Cost:     0.6630 Valid Accuracy: 0.614
# Epoch 125, CIFAR-10 Batch 5:  Cost:     0.6418 Valid Accuracy: 0.609
# Epoch 126, CIFAR-10 Batch 1:  Cost:     0.6329 Valid Accuracy: 0.612
# Epoch 126, CIFAR-10 Batch 2:  Cost:     0.6286 Valid Accuracy: 0.618
# Epoch 126, CIFAR-10 Batch 3:  Cost:     0.6221 Valid Accuracy: 0.615
# Epoch 126, CIFAR-10 Batch 4:  Cost:     0.6279 Valid Accuracy: 0.614
# Epoch 126, CIFAR-10 Batch 5:  Cost:     0.6167 Valid Accuracy: 0.612
# Epoch 127, CIFAR-10 Batch 1:  Cost:     0.6083 Valid Accuracy: 0.613
# Epoch 127, CIFAR-10 Batch 2:  Cost:     0.6051 Valid Accuracy: 0.616
# Epoch 127, CIFAR-10 Batch 3:  Cost:     0.6032 Valid Accuracy: 0.614
# Epoch 127, CIFAR-10 Batch 4:  Cost:     0.6041 Valid Accuracy: 0.614
# Epoch 127, CIFAR-10 Batch 5:  Cost:     0.5943 Valid Accuracy: 0.61
# Epoch 128, CIFAR-10 Batch 1:  Cost:     0.5814 Valid Accuracy: 0.614
# Epoch 128, CIFAR-10 Batch 2:  Cost:     0.5866 Valid Accuracy: 0.618
# Epoch 128, CIFAR-10 Batch 3:  Cost:     0.5901 Valid Accuracy: 0.614
# Epoch 128, CIFAR-10 Batch 4:  Cost:     0.5990 Valid Accuracy: 0.617
# Epoch 128, CIFAR-10 Batch 5:  Cost:     0.5904 Valid Accuracy: 0.614
# Epoch 129, CIFAR-10 Batch 1:  Cost:     0.5692 Valid Accuracy: 0.619
# Epoch 129, CIFAR-10 Batch 2:  Cost:     0.5686 Valid Accuracy: 0.616
# Epoch 129, CIFAR-10 Batch 3:  Cost:     0.5574 Valid Accuracy: 0.62
# Epoch 129, CIFAR-10 Batch 4:  Cost:     0.5822 Valid Accuracy: 0.611
# Epoch 129, CIFAR-10 Batch 5:  Cost:     0.5641 Valid Accuracy: 0.617
# Epoch 130, CIFAR-10 Batch 1:  Cost:     0.5562 Valid Accuracy: 0.623
# Epoch 130, CIFAR-10 Batch 2:  Cost:     0.5458 Valid Accuracy: 0.62
# Epoch 130, CIFAR-10 Batch 3:  Cost:     0.5397 Valid Accuracy: 0.621
# Epoch 130, CIFAR-10 Batch 4:  Cost:     0.5540 Valid Accuracy: 0.616
# Epoch 130, CIFAR-10 Batch 5:  Cost:     0.5377 Valid Accuracy: 0.624
# Epoch 131, CIFAR-10 Batch 1:  Cost:     0.5261 Valid Accuracy: 0.619
# Epoch 131, CIFAR-10 Batch 2:  Cost:     0.5282 Valid Accuracy: 0.622
# Epoch 131, CIFAR-10 Batch 3:  Cost:     0.5339 Valid Accuracy: 0.615
# Epoch 131, CIFAR-10 Batch 4:  Cost:     0.5612 Valid Accuracy: 0.612
# Epoch 131, CIFAR-10 Batch 5:  Cost:     0.5800 Valid Accuracy: 0.615
# Epoch 132, CIFAR-10 Batch 1:  Cost:     0.5821 Valid Accuracy: 0.606
# Epoch 132, CIFAR-10 Batch 2:  Cost:     0.5838 Valid Accuracy: 0.604
# Epoch 132, CIFAR-10 Batch 3:  Cost:     0.5807 Valid Accuracy: 0.613
# Epoch 132, CIFAR-10 Batch 4:  Cost:     0.5564 Valid Accuracy: 0.614
# Epoch 132, CIFAR-10 Batch 5:  Cost:     0.5295 Valid Accuracy: 0.62
# Epoch 133, CIFAR-10 Batch 1:  Cost:     0.5190 Valid Accuracy: 0.618
# Epoch 133, CIFAR-10 Batch 2:  Cost:     0.5282 Valid Accuracy: 0.61
# Epoch 133, CIFAR-10 Batch 3:  Cost:     0.5164 Valid Accuracy: 0.614
# Epoch 133, CIFAR-10 Batch 4:  Cost:     0.5183 Valid Accuracy: 0.62
# Epoch 133, CIFAR-10 Batch 5:  Cost:     0.5140 Valid Accuracy: 0.617
# Epoch 134, CIFAR-10 Batch 1:  Cost:     0.5108 Valid Accuracy: 0.612
# Epoch 134, CIFAR-10 Batch 2:  Cost:     0.5172 Valid Accuracy: 0.613
# Epoch 134, CIFAR-10 Batch 3:  Cost:     0.5166 Valid Accuracy: 0.616
# Epoch 134, CIFAR-10 Batch 4:  Cost:     0.5248 Valid Accuracy: 0.613
# Epoch 134, CIFAR-10 Batch 5:  Cost:     0.5374 Valid Accuracy: 0.619
# Epoch 135, CIFAR-10 Batch 1:  Cost:     0.5040 Valid Accuracy: 0.614
# Epoch 135, CIFAR-10 Batch 2:  Cost:     0.5262 Valid Accuracy: 0.607
# Epoch 135, CIFAR-10 Batch 3:  Cost:     0.6527 Valid Accuracy: 0.594
# Epoch 135, CIFAR-10 Batch 4:  Cost:     0.5413 Valid Accuracy: 0.611
# Epoch 135, CIFAR-10 Batch 5:  Cost:     0.5480 Valid Accuracy: 0.597
# Epoch 136, CIFAR-10 Batch 1:  Cost:     0.6518 Valid Accuracy: 0.592
# Epoch 136, CIFAR-10 Batch 2:  Cost:     0.6039 Valid Accuracy: 0.599
# Epoch 136, CIFAR-10 Batch 3:  Cost:     0.8064 Valid Accuracy: 0.528
# Epoch 136, CIFAR-10 Batch 4:  Cost:     0.7102 Valid Accuracy: 0.584
# Epoch 136, CIFAR-10 Batch 5:  Cost:     0.9409 Valid Accuracy: 0.547
# Epoch 137, CIFAR-10 Batch 1:  Cost:     0.5900 Valid Accuracy: 0.598
# Epoch 137, CIFAR-10 Batch 2:  Cost:     0.7806 Valid Accuracy: 0.549
# Epoch 137, CIFAR-10 Batch 3:  Cost:     0.6438 Valid Accuracy: 0.579
# Epoch 137, CIFAR-10 Batch 4:  Cost:     0.6372 Valid Accuracy: 0.596
# Epoch 137, CIFAR-10 Batch 5:  Cost:     0.6830 Valid Accuracy: 0.59
# Epoch 138, CIFAR-10 Batch 1:  Cost:     0.6045 Valid Accuracy: 0.607
# Epoch 138, CIFAR-10 Batch 2:  Cost:     0.6324 Valid Accuracy: 0.601
# Epoch 138, CIFAR-10 Batch 3:  Cost:     0.5877 Valid Accuracy: 0.603
# Epoch 138, CIFAR-10 Batch 4:  Cost:     0.6103 Valid Accuracy: 0.586
# Epoch 138, CIFAR-10 Batch 5:  Cost:     0.5952 Valid Accuracy: 0.606
# Epoch 139, CIFAR-10 Batch 1:  Cost:     0.5558 Valid Accuracy: 0.616
# Epoch 139, CIFAR-10 Batch 2:  Cost:     0.5812 Valid Accuracy: 0.612
# Epoch 139, CIFAR-10 Batch 3:  Cost:     0.5666 Valid Accuracy: 0.613
# Epoch 139, CIFAR-10 Batch 4:  Cost:     0.5410 Valid Accuracy: 0.617
# Epoch 139, CIFAR-10 Batch 5:  Cost:     0.5449 Valid Accuracy: 0.607
# Epoch 140, CIFAR-10 Batch 1:  Cost:     0.5292 Valid Accuracy: 0.61
# Epoch 140, CIFAR-10 Batch 2:  Cost:     0.5077 Valid Accuracy: 0.617
# Epoch 140, CIFAR-10 Batch 3:  Cost:     0.5126 Valid Accuracy: 0.614
# Epoch 140, CIFAR-10 Batch 4:  Cost:     0.5201 Valid Accuracy: 0.618
# Epoch 140, CIFAR-10 Batch 5:  Cost:     0.4934 Valid Accuracy: 0.617
# Epoch 141, CIFAR-10 Batch 1:  Cost:     0.4853 Valid Accuracy: 0.617
# Epoch 141, CIFAR-10 Batch 2:  Cost:     0.4879 Valid Accuracy: 0.615
# ...
# Epoch 154, CIFAR-10 Batch 5:  Cost:     0.4010 Valid Accuracy: 0.618
# Epoch 155, CIFAR-10 Batch 1:  Cost:     0.4208 Valid Accuracy: 0.594
# Epoch 155, CIFAR-10 Batch 2:  Cost:     0.3900 Valid Accuracy: 0.612
# Epoch 155, CIFAR-10 Batch 3:  Cost:     0.3851 Valid Accuracy: 0.617
# Epoch 155, CIFAR-10 Batch 4:  Cost:     0.3986 Valid Accuracy: 0.616
# Epoch 155, CIFAR-10 Batch 5:  Cost:     0.3748 Valid Accuracy: 0.615
# Epoch 156, CIFAR-10 Batch 1:  Cost:     0.3685 Valid Accuracy: 0.614
# Epoch 156, CIFAR-10 Batch 2:  Cost:     0.3764 Valid Accuracy: 0.611
# Epoch 156, CIFAR-10 Batch 3:  Cost:     0.3461 Valid Accuracy: 0.614
# Epoch 156, CIFAR-10 Batch 4:  Cost:     0.3755 Valid Accuracy: 0.608
# Epoch 156, CIFAR-10 Batch 5:  Cost:     0.3373 Valid Accuracy: 0.615
# Epoch 157, CIFAR-10 Batch 1:  Cost:     0.3545 Valid Accuracy: 0.616
# Epoch 157, CIFAR-10 Batch 2:  Cost:     0.3382 Valid Accuracy: 0.613
# Epoch 157, CIFAR-10 Batch 3:  Cost:     0.3386 Valid Accuracy: 0.61
# Epoch 157, CIFAR-10 Batch 4:  Cost:     0.3370 Valid Accuracy: 0.615
# Epoch 157, CIFAR-10 Batch 5:  Cost:     0.3201 Valid Accuracy: 0.614
# Epoch 158, CIFAR-10 Batch 1:  Cost:     0.3217 Valid Accuracy: 0.611
# Epoch 158, CIFAR-10 Batch 2:  Cost:     0.3275 Valid Accuracy: 0.611
# Epoch 158, CIFAR-10 Batch 3:  Cost:     0.2971 Valid Accuracy: 0.616
# Epoch 158, CIFAR-10 Batch 4:  Cost:     0.3280 Valid Accuracy: 0.614
# Epoch 158, CIFAR-10 Batch 5:  Cost:     0.3041 Valid Accuracy: 0.616
# Epoch 159, CIFAR-10 Batch 1:  Cost:     0.3090 Valid Accuracy: 0.611
# Epoch 159, CIFAR-10 Batch 2:  Cost:     0.3112 Valid Accuracy: 0.611
# Epoch 159, CIFAR-10 Batch 3:  Cost:     0.2930 Valid Accuracy: 0.621
# Epoch 159, CIFAR-10 Batch 4:  Cost:     0.3090 Valid Accuracy: 0.609
# Epoch 159, CIFAR-10 Batch 5:  Cost:     0.2887 Valid Accuracy: 0.614
# Epoch 160, CIFAR-10 Batch 1:  Cost:     0.2924 Valid Accuracy: 0.609
# Epoch 160, CIFAR-10 Batch 2:  Cost:     0.3033 Valid Accuracy: 0.606
# Epoch 160, CIFAR-10 Batch 3:  Cost:     0.2846 Valid Accuracy: 0.621
# Epoch 160, CIFAR-10 Batch 4:  Cost:     0.3012 Valid Accuracy: 0.616
# Epoch 160, CIFAR-10 Batch 5:  Cost:     0.2828 Valid Accuracy: 0.614
# Epoch 161, CIFAR-10 Batch 1:  Cost:     0.2863 Valid Accuracy: 0.61
# Epoch 161, CIFAR-10 Batch 2:  Cost:     0.3022 Valid Accuracy: 0.611
# Epoch 161, CIFAR-10 Batch 3:  Cost:     0.2957 Valid Accuracy: 0.616
# Epoch 161, CIFAR-10 Batch 4:  Cost:     0.2886 Valid Accuracy: 0.612
# Epoch 161, CIFAR-10 Batch 5:  Cost:     0.2681 Valid Accuracy: 0.616
# Epoch 162, CIFAR-10 Batch 1:  Cost:     0.2886 Valid Accuracy: 0.609
# Epoch 162, CIFAR-10 Batch 2:  Cost:     0.2793 Valid Accuracy: 0.613
# Epoch 162, CIFAR-10 Batch 3:  Cost:     0.2670 Valid Accuracy: 0.613
# Epoch 162, CIFAR-10 Batch 4:  Cost:     0.2680 Valid Accuracy: 0.616
# Epoch 162, CIFAR-10 Batch 5:  Cost:     0.2545 Valid Accuracy: 0.616
# Epoch 163, CIFAR-10 Batch 1:  Cost:     0.2778 Valid Accuracy: 0.604
# Epoch 163, CIFAR-10 Batch 2:  Cost:     0.2748 Valid Accuracy: 0.611
# Epoch 163, CIFAR-10 Batch 3:  Cost:     0.2519 Valid Accuracy: 0.615
# Epoch 163, CIFAR-10 Batch 4:  Cost:     0.2731 Valid Accuracy: 0.611
# Epoch 163, CIFAR-10 Batch 5:  Cost:     0.2705 Valid Accuracy: 0.608
# Epoch 164, CIFAR-10 Batch 1:  Cost:     0.3384 Valid Accuracy: 0.592
# Epoch 164, CIFAR-10 Batch 2:  Cost:     0.4056 Valid Accuracy: 0.579
# Epoch 164, CIFAR-10 Batch 3:  Cost:     0.4215 Valid Accuracy: 0.585
# Epoch 164, CIFAR-10 Batch 4:  Cost:     0.5084 Valid Accuracy: 0.587
# Epoch 164, CIFAR-10 Batch 5:  Cost:     0.4495 Valid Accuracy: 0.578
# Epoch 165, CIFAR-10 Batch 1:  Cost:     0.8918 Valid Accuracy: 0.536
# Epoch 165, CIFAR-10 Batch 2:  Cost:     0.5910 Valid Accuracy: 0.546
# Epoch 165, CIFAR-10 Batch 3:  Cost:     0.7300 Valid Accuracy: 0.54
# Epoch 165, CIFAR-10 Batch 4:  Cost:     0.6547 Valid Accuracy: 0.555
# Epoch 165, CIFAR-10 Batch 5:  Cost:     1.2010 Valid Accuracy: 0.461
# Epoch 166, CIFAR-10 Batch 1:  Cost:     1.1751 Valid Accuracy: 0.472
# Epoch 166, CIFAR-10 Batch 2:  Cost:     0.8340 Valid Accuracy: 0.536
# Epoch 166, CIFAR-10 Batch 3:  Cost:     1.2346 Valid Accuracy: 0.492
# Epoch 166, CIFAR-10 Batch 4:  Cost:     0.9876 Valid Accuracy: 0.529
# Epoch 166, CIFAR-10 Batch 5:  Cost:     0.8247 Valid Accuracy: 0.534
# Epoch 167, CIFAR-10 Batch 1:  Cost:     0.7109 Valid Accuracy: 0.549
# Epoch 167, CIFAR-10 Batch 2:  Cost:     0.7297 Valid Accuracy: 0.554
# Epoch 167, CIFAR-10 Batch 3:  Cost:     0.6767 Valid Accuracy: 0.573
# Epoch 167, CIFAR-10 Batch 4:  Cost:     0.7426 Valid Accuracy: 0.575
# Epoch 167, CIFAR-10 Batch 5:  Cost:     0.7101 Valid Accuracy: 0.58
# Epoch 168, CIFAR-10 Batch 1:  Cost:     0.6899 Valid Accuracy: 0.577
# Epoch 168, CIFAR-10 Batch 2:  Cost:     0.6863 Valid Accuracy: 0.581
# Epoch 168, CIFAR-10 Batch 3:  Cost:     0.6121 Valid Accuracy: 0.593
# Epoch 168, CIFAR-10 Batch 4:  Cost:     0.6444 Valid Accuracy: 0.585
# Epoch 168, CIFAR-10 Batch 5:  Cost:     0.6129 Valid Accuracy: 0.587
# Epoch 169, CIFAR-10 Batch 1:  Cost:     0.5889 Valid Accuracy: 0.589
# Epoch 169, CIFAR-10 Batch 2:  Cost:     0.5744 Valid Accuracy: 0.598
# Epoch 169, CIFAR-10 Batch 3:  Cost:     0.5504 Valid Accuracy: 0.602
# Epoch 169, CIFAR-10 Batch 4:  Cost:     0.5293 Valid Accuracy: 0.605
# Epoch 169, CIFAR-10 Batch 5:  Cost:     0.5209 Valid Accuracy: 0.606
# Epoch 170, CIFAR-10 Batch 1:  Cost:     0.4932 Valid Accuracy: 0.605
# Epoch 170, CIFAR-10 Batch 2:  Cost:     0.4829 Valid Accuracy: 0.607
# Epoch 170, CIFAR-10 Batch 3:  Cost:     0.4611 Valid Accuracy: 0.61
# Epoch 170, CIFAR-10 Batch 4:  Cost:     0.4477 Valid Accuracy: 0.609
# Epoch 170, CIFAR-10 Batch 5:  Cost:     0.4284 Valid Accuracy: 0.607
# Epoch 171, CIFAR-10 Batch 1:  Cost:     0.4109 Valid Accuracy: 0.61
# Epoch 171, CIFAR-10 Batch 2:  Cost:     0.3912 Valid Accuracy: 0.614
# Epoch 171, CIFAR-10 Batch 3:  Cost:     0.3796 Valid Accuracy: 0.607
# Epoch 171, CIFAR-10 Batch 4:  Cost:     0.3754 Valid Accuracy: 0.612
# Epoch 171, CIFAR-10 Batch 5:  Cost:     0.3599 Valid Accuracy: 0.619
# Epoch 172, CIFAR-10 Batch 1:  Cost:     0.3478 Valid Accuracy: 0.616
# Epoch 172, CIFAR-10 Batch 2:  Cost:     0.3464 Valid Accuracy: 0.614
# Epoch 172, CIFAR-10 Batch 3:  Cost:     0.3208 Valid Accuracy: 0.611
# Epoch 172, CIFAR-10 Batch 4:  Cost:     0.3198 Valid Accuracy: 0.609
# Epoch 172, CIFAR-10 Batch 5:  Cost:     0.3086 Valid Accuracy: 0.608
# Epoch 173, CIFAR-10 Batch 1:  Cost:     0.2992 Valid Accuracy: 0.609
# Epoch 173, CIFAR-10 Batch 2:  Cost:     0.2905 Valid Accuracy: 0.615
# Epoch 173, CIFAR-10 Batch 3:  Cost:     0.2940 Valid Accuracy: 0.609
# Epoch 173, CIFAR-10 Batch 4:  Cost:     0.2812 Valid Accuracy: 0.619
# Epoch 173, CIFAR-10 Batch 5:  Cost:     0.2769 Valid Accuracy: 0.618
# Epoch 174, CIFAR-10 Batch 1:  Cost:     0.2694 Valid Accuracy: 0.619
# Epoch 174, CIFAR-10 Batch 2:  Cost:     0.2632 Valid Accuracy: 0.614
# Epoch 174, CIFAR-10 Batch 3:  Cost:     0.2625 Valid Accuracy: 0.608
# Epoch 174, CIFAR-10 Batch 4:  Cost:     0.2630 Valid Accuracy: 0.61
# Epoch 174, CIFAR-10 Batch 5:  Cost:     0.2733 Valid Accuracy: 0.611
# Epoch 175, CIFAR-10 Batch 1:  Cost:     0.2456 Valid Accuracy: 0.617
# Epoch 175, CIFAR-10 Batch 2:  Cost:     0.2436 Valid Accuracy: 0.608
# Epoch 175, CIFAR-10 Batch 3:  Cost:     0.2558 Valid Accuracy: 0.608
# Epoch 175, CIFAR-10 Batch 4:  Cost:     0.2827 Valid Accuracy: 0.609
# Epoch 175, CIFAR-10 Batch 5:  Cost:     0.3188 Valid Accuracy: 0.6
# Epoch 176, CIFAR-10 Batch 1:  Cost:     0.2322 Valid Accuracy: 0.613
# Epoch 176, CIFAR-10 Batch 2:  Cost:     0.2724 Valid Accuracy: 0.597
# Epoch 176, CIFAR-10 Batch 3:  Cost:     0.3462 Valid Accuracy: 0.585
# Epoch 176, CIFAR-10 Batch 4:  Cost:     0.3551 Valid Accuracy: 0.596
# Epoch 176, CIFAR-10 Batch 5:  Cost:     0.2784 Valid Accuracy: 0.606
# Epoch 177, CIFAR-10 Batch 1:  Cost:     0.3013 Valid Accuracy: 0.598
# Epoch 177, CIFAR-10 Batch 2:  Cost:     0.2926 Valid Accuracy: 0.596
# Epoch 177, CIFAR-10 Batch 3:  Cost:     0.2392 Valid Accuracy: 0.604
# Epoch 177, CIFAR-10 Batch 4:  Cost:     0.2661 Valid Accuracy: 0.609
# Epoch 177, CIFAR-10 Batch 5:  Cost:     0.2579 Valid Accuracy: 0.601
# Epoch 178, CIFAR-10 Batch 1:  Cost:     0.2534 Valid Accuracy: 0.615
# Epoch 178, CIFAR-10 Batch 2:  Cost:     0.2304 Valid Accuracy: 0.61
# Epoch 178, CIFAR-10 Batch 3:  Cost:     0.2553 Valid Accuracy: 0.597
# Epoch 178, CIFAR-10 Batch 4:  Cost:     0.2336 Valid Accuracy: 0.606
# Epoch 178, CIFAR-10 Batch 5:  Cost:     0.2315 Valid Accuracy: 0.61
# Epoch 179, CIFAR-10 Batch 1:  Cost:     0.2556 Valid Accuracy: 0.605
# Epoch 179, CIFAR-10 Batch 2:  Cost:     0.2168 Valid Accuracy: 0.608
# Epoch 179, CIFAR-10 Batch 3:  Cost:     0.2811 Valid Accuracy: 0.59
# Epoch 179, CIFAR-10 Batch 4:  Cost:     0.2617 Valid Accuracy: 0.597
# Epoch 179, CIFAR-10 Batch 5:  Cost:     0.2259 Valid Accuracy: 0.605
# Epoch 180, CIFAR-10 Batch 1:  Cost:     0.2657 Valid Accuracy: 0.607
# Epoch 180, CIFAR-10 Batch 2:  Cost:     0.2024 Valid Accuracy: 0.61
# Epoch 180, CIFAR-10 Batch 3:  Cost:     0.2464 Valid Accuracy: 0.593
# Epoch 180, CIFAR-10 Batch 4:  Cost:     0.2532 Valid Accuracy: 0.594
# Epoch 180, CIFAR-10 Batch 5:  Cost:     0.2220 Valid Accuracy: 0.613
# Epoch 181, CIFAR-10 Batch 1:  Cost:     0.2707 Valid Accuracy: 0.596
# Epoch 181, CIFAR-10 Batch 2:  Cost:     0.2534 Valid Accuracy: 0.604
# Epoch 181, CIFAR-10 Batch 3:  Cost:     0.2195 Valid Accuracy: 0.597
# Epoch 181, CIFAR-10 Batch 4:  Cost:     0.3361 Valid Accuracy: 0.568
# Epoch 181, CIFAR-10 Batch 5:  Cost:     0.3502 Valid Accuracy: 0.584
# Epoch 182, CIFAR-10 Batch 1:  Cost:     0.3598 Valid Accuracy: 0.578
# Epoch 182, CIFAR-10 Batch 2:  Cost:     0.3229 Valid Accuracy: 0.589
# Epoch 182, CIFAR-10 Batch 3:  Cost:     0.2528 Valid Accuracy: 0.599
# Epoch 182, CIFAR-10 Batch 4:  Cost:     0.3560 Valid Accuracy: 0.576
# Epoch 182, CIFAR-10 Batch 5:  Cost:     0.3639 Valid Accuracy: 0.573
# Epoch 183, CIFAR-10 Batch 1:  Cost:     0.2392 Valid Accuracy: 0.606
# Epoch 183, CIFAR-10 Batch 2:  Cost:     0.4068 Valid Accuracy: 0.583
# Epoch 183, CIFAR-10 Batch 3:  Cost:     0.3066 Valid Accuracy: 0.595
# Epoch 183, CIFAR-10 Batch 4:  Cost:     0.2674 Valid Accuracy: 0.596
# Epoch 183, CIFAR-10 Batch 5:  Cost:     0.2843 Valid Accuracy: 0.587
# Epoch 184, CIFAR-10 Batch 1:  Cost:     0.3405 Valid Accuracy: 0.585
# Epoch 184, CIFAR-10 Batch 2:  Cost:     0.2475 Valid Accuracy: 0.605
# Epoch 184, CIFAR-10 Batch 3:  Cost:     0.2472 Valid Accuracy: 0.604
# Epoch 184, CIFAR-10 Batch 4:  Cost:     0.2831 Valid Accuracy: 0.6
# Epoch 184, CIFAR-10 Batch 5:  Cost:     0.2580 Valid Accuracy: 0.607
# Epoch 185, CIFAR-10 Batch 1:  Cost:     0.2169 Valid Accuracy: 0.613
# Epoch 185, CIFAR-10 Batch 2:  Cost:     0.2429 Valid Accuracy: 0.595
# Epoch 185, CIFAR-10 Batch 3:  Cost:     0.2446 Valid Accuracy: 0.6
# Epoch 185, CIFAR-10 Batch 4:  Cost:     0.1971 Valid Accuracy: 0.613
# Epoch 185, CIFAR-10 Batch 5:  Cost:     0.2156 Valid Accuracy: 0.604
# Epoch 186, CIFAR-10 Batch 1:  Cost:     0.1874 Valid Accuracy: 0.609
# Epoch 186, CIFAR-10 Batch 2:  Cost:     0.1950 Valid Accuracy: 0.61
# Epoch 186, CIFAR-10 Batch 3:  Cost:     0.1935 Valid Accuracy: 0.602
# Epoch 186, CIFAR-10 Batch 4:  Cost:     0.1786 Valid Accuracy: 0.61
# Epoch 186, CIFAR-10 Batch 5:  Cost:     0.1941 Valid Accuracy: 0.599
# Epoch 187, CIFAR-10 Batch 1:  Cost:     0.1748 Valid Accuracy: 0.611
# Epoch 187, CIFAR-10 Batch 2:  Cost:     0.1737 Valid Accuracy: 0.616
# Epoch 187, CIFAR-10 Batch 3:  Cost:     0.1671 Valid Accuracy: 0.616
# Epoch 187, CIFAR-10 Batch 4:  Cost:     0.1729 Valid Accuracy: 0.615
# Epoch 187, CIFAR-10 Batch 5:  Cost:     0.1496 Valid Accuracy: 0.614
# Epoch 188, CIFAR-10 Batch 1:  Cost:     0.1650 Valid Accuracy: 0.606
# Epoch 188, CIFAR-10 Batch 2:  Cost:     0.1472 Valid Accuracy: 0.612
# Epoch 188, CIFAR-10 Batch 3:  Cost:     0.1502 Valid Accuracy: 0.612
# Epoch 188, CIFAR-10 Batch 4:  Cost:     0.1419 Valid Accuracy: 0.615
# Epoch 188, CIFAR-10 Batch 5:  Cost:     0.1429 Valid Accuracy: 0.609
# Epoch 189, CIFAR-10 Batch 1:  Cost:     0.1341 Valid Accuracy: 0.617
# Epoch 189, CIFAR-10 Batch 2:  Cost:     0.1355 Valid Accuracy: 0.611
# Epoch 189, CIFAR-10 Batch 3:  Cost:     0.1407 Valid Accuracy: 0.61
# Epoch 189, CIFAR-10 Batch 4:  Cost:     0.1343 Valid Accuracy: 0.613
# Epoch 189, CIFAR-10 Batch 5:  Cost:     0.1287 Valid Accuracy: 0.613
# Epoch 190, CIFAR-10 Batch 1:  Cost:     0.1262 Valid Accuracy: 0.614
# Epoch 190, CIFAR-10 Batch 2:  Cost:     0.1317 Valid Accuracy: 0.61
# Epoch 190, CIFAR-10 Batch 3:  Cost:     0.1310 Valid Accuracy: 0.615
# Epoch 190, CIFAR-10 Batch 4:  Cost:     0.1291 Valid Accuracy: 0.611
# Epoch 190, CIFAR-10 Batch 5:  Cost:     0.1235 Valid Accuracy: 0.612
# Epoch 191, CIFAR-10 Batch 1:  Cost:     0.1292 Valid Accuracy: 0.609
# Epoch 191, CIFAR-10 Batch 2:  Cost:     0.1187 Valid Accuracy: 0.609
# Epoch 191, CIFAR-10 Batch 3:  Cost:     0.1234 Valid Accuracy: 0.616
# Epoch 191, CIFAR-10 Batch 4:  Cost:     0.1203 Valid Accuracy: 0.611
# Epoch 191, CIFAR-10 Batch 5:  Cost:     0.1306 Valid Accuracy: 0.611
# Epoch 192, CIFAR-10 Batch 1:  Cost:     0.1221 Valid Accuracy: 0.611
# Epoch 192, CIFAR-10 Batch 2:  Cost:     0.1107 Valid Accuracy: 0.61
# Epoch 192, CIFAR-10 Batch 3:  Cost:     0.1109 Valid Accuracy: 0.615
# Epoch 192, CIFAR-10 Batch 4:  Cost:     0.1147 Valid Accuracy: 0.61
# Epoch 192, CIFAR-10 Batch 5:  Cost:     0.1278 Valid Accuracy: 0.609
# Epoch 193, CIFAR-10 Batch 1:  Cost:     0.1152 Valid Accuracy: 0.611
# Epoch 193, CIFAR-10 Batch 2:  Cost:     0.1090 Valid Accuracy: 0.61
# Epoch 193, CIFAR-10 Batch 3:  Cost:     0.1063 Valid Accuracy: 0.608
# Epoch 193, CIFAR-10 Batch 4:  Cost:     0.1290 Valid Accuracy: 0.6
# Epoch 193, CIFAR-10 Batch 5:  Cost:     0.1658 Valid Accuracy: 0.599
# Epoch 194, CIFAR-10 Batch 1:  Cost:     0.1537 Valid Accuracy: 0.602
# Epoch 194, CIFAR-10 Batch 2:  Cost:     0.1134 Valid Accuracy: 0.606
# Epoch 194, CIFAR-10 Batch 3:  Cost:     0.1045 Valid Accuracy: 0.609
# Epoch 194, CIFAR-10 Batch 4:  Cost:     0.1335 Valid Accuracy: 0.6
# Epoch 194, CIFAR-10 Batch 5:  Cost:     0.1451 Valid Accuracy: 0.606
# Epoch 195, CIFAR-10 Batch 1:  Cost:     0.1020 Valid Accuracy: 0.61
# Epoch 195, CIFAR-10 Batch 2:  Cost:     0.1181 Valid Accuracy: 0.605
# Epoch 195, CIFAR-10 Batch 3:  Cost:     0.1793 Valid Accuracy: 0.591
# Epoch 195, CIFAR-10 Batch 4:  Cost:     0.2764 Valid Accuracy: 0.574
# Epoch 195, CIFAR-10 Batch 5:  Cost:     0.3249 Valid Accuracy: 0.583
# Epoch 196, CIFAR-10 Batch 1:  Cost:     0.1389 Valid Accuracy: 0.606
# Epoch 196, CIFAR-10 Batch 2:  Cost:     0.1978 Valid Accuracy: 0.59
# Epoch 196, CIFAR-10 Batch 3:  Cost:     0.3695 Valid Accuracy: 0.572
# Epoch 196, CIFAR-10 Batch 4:  Cost:     0.2173 Valid Accuracy: 0.599
# Epoch 196, CIFAR-10 Batch 5:  Cost:     0.4081 Valid Accuracy: 0.547
# Epoch 197, CIFAR-10 Batch 1:  Cost:     0.4612 Valid Accuracy: 0.563
# Epoch 197, CIFAR-10 Batch 2:  Cost:     0.2903 Valid Accuracy: 0.587
# Epoch 197, CIFAR-10 Batch 3:  Cost:     0.3064 Valid Accuracy: 0.579
# Epoch 197, CIFAR-10 Batch 4:  Cost:     0.2866 Valid Accuracy: 0.59
# Epoch 197, CIFAR-10 Batch 5:  Cost:     0.1993 Valid Accuracy: 0.598
# Epoch 198, CIFAR-10 Batch 1:  Cost:     0.3031 Valid Accuracy: 0.575
# Epoch 198, CIFAR-10 Batch 2:  Cost:     0.2326 Valid Accuracy: 0.598
# Epoch 198, CIFAR-10 Batch 3:  Cost:     0.2098 Valid Accuracy: 0.598
# Epoch 198, CIFAR-10 Batch 4:  Cost:     0.2765 Valid Accuracy: 0.58
# Epoch 198, CIFAR-10 Batch 5:  Cost:     0.1788 Valid Accuracy: 0.606
# Epoch 199, CIFAR-10 Batch 1:  Cost:     0.2265 Valid Accuracy: 0.6
# Epoch 199, CIFAR-10 Batch 2:  Cost:     0.2150 Valid Accuracy: 0.598
# Epoch 199, CIFAR-10 Batch 3:  Cost:     0.1590 Valid Accuracy: 0.613
# Epoch 199, CIFAR-10 Batch 4:  Cost:     0.2107 Valid Accuracy: 0.597
# Epoch 199, CIFAR-10 Batch 5:  Cost:     0.1732 Valid Accuracy: 0.598
# Epoch 200, CIFAR-10 Batch 1:  Cost:     0.1675 Valid Accuracy: 0.603
# Epoch 200, CIFAR-10 Batch 2:  Cost:     0.1624 Valid Accuracy: 0.61
# Epoch 200, CIFAR-10 Batch 3:  Cost:     0.1768 Valid Accuracy: 0.601
# Epoch 200, CIFAR-10 Batch 4:  Cost:     0.1576 Valid Accuracy: 0.601
# Epoch 200, CIFAR-10 Batch 5:  Cost:     0.1629 Valid Accuracy: 0.592

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5982999205589294

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
